# %% [markdown]
# """
# Implements an RNN on a synthetic data set, following the architecture
# described in "Deep Knowledge Tracing" by Chris Piech et al.
# The RNN implementation is based on min-char-rnn.py by Andrej Karpathy (@karpathy).
# BSD License
# """

# %%
# Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import random
import sys
import csv
import time
import matplotlib.pyplot as plt
# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# our own modules
# from utils import *
# from visualize import *

import utils


import visualize

data_sets_map = {
    'synth':"syntheticDetailed/naive_c5_q50_s4000_v0.csv",
    'code_org' : "data/hoc_1-9_binary_input.csv"
}

DATA_SET = 'code_org'
# DATA_SZ = 500000
# DATA_SET = 'synth'

# if DATA_SZ = -1, use entire data set
DATA_SZ = 4000
# DATA_SZ = -1

# %%
# Read in the data set
# This function can be moved to utils.py
data_array = np.array(list(csv.reader(open(data_sets_map[DATA_SET],"rb"),delimiter=','))).astype('int')
if DATA_SZ != -1:
    data_array = data_array[:DATA_SZ]
    
np.random.shuffle(data_array)
num_samples = data_array.shape[0]
num_problems = data_array.shape[1]

# time steps is number of problems - 1 because we cannot predict on the last problem.
num_timesteps = num_problems - 1 

# Split data into train and test (half and half)

train_data = data_array[0:7*num_samples/8,:]
val_data =  data_array[7*num_samples/8: 15*num_samples/16 ,:]
test_data = data_array[15*num_samples/16:num_samples,:]

# %%
# code to see how many percent is correct
print (num_problems)
# for prob in xrange(num_problems):
#     print ('Train Prob {} : percent correct {}'.format(prob, np.mean(train_data[:,prob]) ))
#     print ('Val Prob {} : percent correct {}'.format(prob, np.mean(val_data[:,prob]) ))
#     print ('Test Prob {} : percent correct {}'.format(prob, np.mean(test_data[:,prob]) ))
print ('Train : percent correct {}'.format( np.mean(np.concatenate((np.concatenate((train_data, val_data), axis=0),test_data), axis=0 ))))
print ('Train : percent correct {}'.format( np.mean(train_data) ))
print ('Val : percent correct {}'.format( np.mean(val_data) ))
print ('Test : percent correct {}'.format( np.mean(test_data) ))
# Out:
# 9
# Train : percent correct 0.856
# Train : percent correct 0.855619047619
# Val : percent correct 0.868888888889
# Test : percent correct 0.848444444444

# %%
num_train = train_data.shape[0]
num_test = test_data.shape[0]

print('Vectorization...')
X_train, next_problem_train, truth_train = utils.vectorize_data(train_data)
X_val, next_problem_val, truth_val = utils.vectorize_data(val_data)
X_test, next_problem_test, truth_test = utils.vectorize_data(test_data)
print ("Vectorization done!")
print X_train.shape
print X_val.shape
print X_test.shape
# Out:
# Vectorization...
# Vectorization done!
# (3500, 8, 18)
# (250, 8, 18)
# (250, 8, 18)

# %%
# hyperparameters
hidden_size = 200 # size of hidden layer of neurons
learning_rate = 1e-2
lr_decay = 1.0
reg_strength = 0.0
grad_clip = 10
batchsize = 32
num_epochs = 20
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# %%
'''
Create a model using Lasagne layering system. The layers are as follows:
 - Input layer: [n_sample, n_time, n_input] -> [n_sample, n_time, n_input]
 - LSTM layer: [n_sample, n_time, n_input] -> [n_sample, n_time, n_hidden]
 - Reshape layer: [n_sample, n_time, n_hidden] -> [n_sample*n_time, n_hidden]
 - Dense layer: [n_sample*n_time, n_hidden] -> [n_sample*n_time, n_output]
 - Output reshape layer: [n_sample*n_time, n_output] -> [n_sample, n_time, n_output]
'''
l_in = lasagne.layers.InputLayer(shape=(None, num_timesteps, num_problems * 2))
l_lstm = lasagne.layers.LSTMLayer(
    l_in, hidden_size, grad_clipping=grad_clip,
    nonlinearity=lasagne.nonlinearities.tanh)
l_reshape = lasagne.layers.ReshapeLayer(l_lstm, (-1, hidden_size))
l_out = lasagne.layers.DenseLayer(l_reshape,
    num_units=num_problems,
    W = lasagne.init.Normal(),
    nonlinearity=lasagne.nonlinearities.sigmoid)
l_pred = lasagne.layers.ReshapeLayer(l_out, (-1, num_timesteps, num_problems))

''' pred:for each student, a vector that gives probability of next question being answered correctly
    y: for each student, a one-hot-encoding of shape (num_timesteps, num_problems), indicating which problem the student will do at the next timestep 
    truth: for each student, a vector that indicates for each timestep whether next problem was answered correctly
'''
pred = lasagne.layers.get_output(l_pred)
next_problem = Tensor.tensor3('next_problem')
truth = Tensor.imatrix("truth")

# pred_probs: shape(num_samples, num_timesteps)
# we reduce the three-dimensional probability tensor to two dimensions
# by only keeping the probabilities corresponding to the next problem
# we don't care about the predicted probabilities for other problems
pred_probs = Tensor.sum(pred * next_problem, axis = 2)
# loss function
loss = Tensor.nnet.binary_crossentropy(pred_probs, truth)

# TODO: why do we use both cost and loss? (naming :D)
# take average of loss per sample, makes loss more comparable when batch sizes change
cost = loss.mean()

# update function
print("Computing updates ...")
all_params = lasagne.layers.get_all_params(l_pred)
updates = lasagne.updates.adam(cost, all_params, learning_rate)

# Function to compute accuracy:
# if probability was > 0.5, we consider it a 1, and 0 otherwise.
# binary_pred: for each student, a vector of length num_timesteps indicating whether the 
# probability of getting the next problem correct is larger than 0.5.
binary_pred = Tensor.round(pred_probs)
acc = Tensor.mean(Tensor.eq(binary_pred, truth))
    
# training function
print("Compiling functions ...")
# training function, only returns loss
train_fn = theano.function([l_in.input_var, next_problem, truth], cost, updates=updates, allow_input_downcast=True)
# training function, returns loss and acc
train_acc_fn = theano.function([l_in.input_var, next_problem, truth], [cost, acc], updates=updates, allow_input_downcast=True)

compute_cost = theano.function([l_in.input_var, next_problem, truth], cost, allow_input_downcast=True)
# computes loss and accuracy
compute_cost_acc = theano.function([l_in.input_var, next_problem, truth], [cost, acc], allow_input_downcast=True)

print("Compiling done!")
# Out:
# Computing updates ...
# Compiling functions ...
# Compiling done!
# /Users/lisa1010/anaconda/lib/python2.7/site-packages/theano/scan_module/scan.py:1019: Warning: In the strict mode, all neccessary shared variables must be passed as a part of non_sequences
#   'must be passed as a part of non_sequences', Warning)

# %%
def check_val_loss_acc(X_val, next_problem_val, truth_val, batchsize):
    # a full pass over the validation data:
    val_err = 0.0
    val_acc = 0.0
    val_batches = 0
    for batch in utils.iterate_minibatches(X_val, next_problem_val, truth_val, batchsize, shuffle=False):
        X_, next_problem_, truth_ = batch
        err, acc = compute_cost_acc(X_, next_problem_, truth_)
        val_err += err
        val_acc += acc
        val_batches += 1
    val_loss = val_err/val_batches
    val_acc = val_acc/val_batches * 100
    return val_loss, val_acc

# %%
# Training!!!
print("Starting training...")
# We iterate over epochs:
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0.0
    train_acc = 0.0
    train_batches = 0
    start_time = time.time()
    for batch in utils.iterate_minibatches(X_train, next_problem_train, truth_train, batchsize, shuffle=False):
        X_, next_problem_, truth_ = batch
        err, acc = train_acc_fn(X_, next_problem_, truth_)
        train_err += err
        train_acc += acc
        train_batches += 1
        val_loss, val_acc = check_val_loss_acc(X_val, next_problem_val, truth_val, batchsize)
        print("  Epoch {} \tbatch {} \tloss {} \ttrain acc {:.2f} \tval acc {:.2f} ".format(epoch, train_batches, err, acc * 100, val_acc) )
    train_acc = train_acc/train_batches * 100
    train_accuracies.append(train_acc)
    train_loss = train_err/train_batches
    train_losses.append(train_loss)
    
    val_loss, val_acc = check_val_loss_acc(X_val, next_problem_val, truth_val, batchsize)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t\t{:.6f}".format(train_loss))
    print("  training accuracy:\t\t{:.2f} %".format(train_acc))
    print("  validation loss:\t\t{:.6f}".format(val_loss))
    print("  validation accuracy:\t\t{:.2f} %".format(val_acc))

print("Training completed.")
# Out:
# Starting training...
#   Epoch 0 	batch 1 	loss 0.69323807785 	train acc 39.45 	val acc 87.50
#   Epoch 0 	batch 2 	loss 0.667087251203 	train acc 82.81 	val acc 87.50
#   Epoch 0 	batch 3 	loss 0.605834295178 	train acc 86.33 	val acc 85.27
#   Epoch 0 	batch 4 	loss 0.529348919057 	train acc 85.55 	val acc 85.27
#   Epoch 0 	batch 5 	loss 0.507933229881 	train acc 85.94 	val acc 85.27
#   Epoch 0 	batch 6 	loss 0.43213688624 	train acc 84.38 	val acc 85.27
#   Epoch 0 	batch 7 	loss 0.437906425033 	train acc 81.64 	val acc 85.16
#   Epoch 0 	batch 8 	loss 0.381833017062 	train acc 84.38 	val acc 85.16
#   Epoch 0 	batch 9 	loss 0.365146365693 	train acc 83.59 	val acc 85.16
#   Epoch 0 	batch 10 	loss 0.44642419864 	train acc 80.86 	val acc 85.16
#   Epoch 0 	batch 11 	loss 0.364085610495 	train acc 82.42 	val acc 87.50
#   Epoch 0 	batch 12 	loss 0.406711858764 	train acc 83.59 	val acc 85.27
#   Epoch 0 	batch 13 	loss 0.360322271029 	train acc 82.03 	val acc 85.27
#   Epoch 0 	batch 14 	loss 0.412705998139 	train acc 80.08 	val acc 85.27
#   Epoch 0 	batch 15 	loss 0.334620936828 	train acc 85.55 	val acc 85.71
#   Epoch 0 	batch 16 	loss 0.305601218899 	train acc 86.72 	val acc 85.16
#   Epoch 0 	batch 17 	loss 0.267090334254 	train acc 88.67 	val acc 85.16
#   Epoch 0 	batch 18 	loss 0.26255414777 	train acc 89.84 	val acc 85.16
#   Epoch 3 	batch 74 	loss 0.23850467914 	train acc 91.41 	val acc 89.90
#   Epoch 3 	batch 75 	loss 0.307262448588 	train acc 89.45 	val acc 89.90
#   Epoch 3 	batch 76 	loss 0.275715634417 	train acc 89.06 	val acc 89.90
#   Epoch 3 	batch 77 	loss 0.261319208157 	train acc 89.84 	val acc 90.40
#   Epoch 3 	batch 78 	loss 0.242083348418 	train acc 90.62 	val acc 90.40
#   Epoch 3 	batch 79 	loss 0.236232676717 	train acc 89.45 	val acc 90.40
#   Epoch 3 	batch 80 	loss 0.298437113964 	train acc 89.45 	val acc 90.40
#   Epoch 3 	batch 81 	loss 0.272467060325 	train acc 88.67 	val acc 90.40
#   Epoch 3 	batch 82 	loss 0.241702947201 	train acc 91.02 	val acc 90.40
#   Epoch 3 	batch 83 	loss 0.277206656771 	train acc 89.45 	val acc 90.46
#   Epoch 3 	batch 84 	loss 0.294340273634 	train acc 88.28 	val acc 90.46
#   Epoch 3 	batch 85 	loss 0.260335051596 	train acc 90.62 	val acc 90.46
#   Epoch 3 	batch 86 	loss 0.242549885756 	train acc 92.58 	val acc 90.46
#   Epoch 3 	batch 87 	loss 0.233520559702 	train acc 90.62 	val acc 90.29
#   Epoch 3 	batch 88 	loss 0.316868602859 	train acc 87.11 	val acc 90.29
#   Epoch 3 	batch 89 	loss 0.182029288144 	train acc 94.14 	val acc 90.29
#   Epoch 3 	batch 90 	loss 0.230074433196 	train acc 90.23 	val acc 90.29
#   Epoch 3 	batch 91 	loss 0.241143543184 	train acc 91.02 	val acc 90.35
#   Epoch 3 	batch 92 	loss 0.21060239045 	train acc 91.41 	val acc 90.35
#   Epoch 3 	batch 93 	loss 0.24969129085 	train acc 90.23 	val acc 90.35
#   Epoch 3 	batch 94 	loss 0.319248618814 	train acc 89.06 	val acc 90.35
#   Epoch 3 	batch 95 	loss 0.281367504235 	train acc 90.23 	val acc 90.35
#   Epoch 3 	batch 96 	loss 0.241826528999 	train acc 91.41 	val acc 90.35
#   Epoch 3 	batch 97 	loss 0.294956823935 	train acc 89.45 	val acc 90.35
#   Epoch 3 	batch 98 	loss 0.278588267593 	train acc 88.67 	val acc 90.35
#   Epoch 3 	batch 99 	loss 0.287081978623 	train acc 90.23 	val acc 90.35
#   Epoch 3 	batch 100 	loss 0.290481783188 	train acc 89.84 	val acc 90.40
#   Epoch 3 	batch 101 	loss 0.344063717123 	train acc 86.72 	val acc 90.57
#   Epoch 3 	batch 102 	loss 0.276293038417 	train acc 90.23 	val acc 90.51
#   Epoch 3 	batch 103 	loss 0.285708444768 	train acc 89.45 	val acc 90.51
#   Epoch 3 	batch 104 	loss 0.276942518056 	train acc 88.67 	val acc 90.57
#   Epoch 3 	batch 105 	loss 0.298465756968 	train acc 89.06 	val acc 90.57
#   Epoch 3 	batch 106 	loss 0.293859360088 	train acc 88.67 	val acc 90.62
#   Epoch 3 	batch 107 	loss 0.228190871738 	train acc 91.80 	val acc 90.62
#   Epoch 3 	batch 108 	loss 0.267614627992 	train acc 90.23 	val acc 90.62
#   Epoch 18 	batch 50 	loss 0.213088226882 	train acc 92.19 	val acc 90.57
#   Epoch 18 	batch 51 	loss 0.217513190191 	train acc 91.02 	val acc 90.62
#   Epoch 18 	batch 52 	loss 0.275802361332 	train acc 90.62 	val acc 90.62
#   Epoch 18 	batch 53 	loss 0.226536287192 	train acc 89.84 	val acc 90.62
#   Epoch 18 	batch 54 	loss 0.240126036534 	train acc 89.84 	val acc 90.62
#   Epoch 18 	batch 55 	loss 0.231308450708 	train acc 91.02 	val acc 90.62
#   Epoch 18 	batch 56 	loss 0.292559627249 	train acc 87.89 	val acc 90.62
#   Epoch 18 	batch 57 	loss 0.225337177254 	train acc 91.41 	val acc 90.62
#   Epoch 18 	batch 58 	loss 0.272771099283 	train acc 90.23 	val acc 90.62
#   Epoch 18 	batch 59 	loss 0.243877120626 	train acc 92.19 	val acc 90.57
#   Epoch 18 	batch 60 	loss 0.259390319166 	train acc 91.41 	val acc 90.57
#   Epoch 18 	batch 61 	loss 0.235730470956 	train acc 89.45 	val acc 90.57
#   Epoch 18 	batch 62 	loss 0.210162267318 	train acc 92.58 	val acc 90.57
#   Epoch 18 	batch 63 	loss 0.245922430857 	train acc 90.62 	val acc 90.51
#   Epoch 18 	batch 64 	loss 0.296374647929 	train acc 87.89 	val acc 90.51
#   Epoch 18 	batch 65 	loss 0.25314837966 	train acc 90.23 	val acc 90.51
#   Epoch 18 	batch 66 	loss 0.317550454329 	train acc 87.50 	val acc 90.51
#   Epoch 18 	batch 67 	loss 0.258506460112 	train acc 92.19 	val acc 90.51
#   Epoch 18 	batch 68 	loss 0.221143918331 	train acc 90.62 	val acc 90.51
#   Epoch 18 	batch 69 	loss 0.1943862183 	train acc 94.14 	val acc 90.51
#   Epoch 18 	batch 70 	loss 0.253427449897 	train acc 89.06 	val acc 90.51
#   Epoch 18 	batch 71 	loss 0.208871215485 	train acc 93.75 	val acc 90.51
#   Epoch 18 	batch 72 	loss 0.251323823782 	train acc 91.41 	val acc 90.51
#   Epoch 18 	batch 73 	loss 0.314411404643 	train acc 89.45 	val acc 90.51
#   Epoch 18 	batch 74 	loss 0.235105864936 	train acc 91.41 	val acc 90.51
#   Epoch 18 	batch 75 	loss 0.297152901349 	train acc 90.62 	val acc 90.57
#   Epoch 18 	batch 76 	loss 0.2698561995 	train acc 88.67 	val acc 90.57
#   Epoch 18 	batch 77 	loss 0.254421374634 	train acc 90.62 	val acc 90.57
#   Epoch 18 	batch 78 	loss 0.235491134841 	train acc 90.62 	val acc 90.57
#   Epoch 18 	batch 79 	loss 0.239011958508 	train acc 89.84 	val acc 90.57
#   Epoch 18 	batch 80 	loss 0.297295171449 	train acc 89.45 	val acc 90.57
#   Epoch 18 	batch 81 	loss 0.270913916774 	train acc 89.45 	val acc 90.57
#   Epoch 18 	batch 82 	loss 0.236868282636 	train acc 91.02 	val acc 90.57
#   Epoch 18 	batch 83 	loss 0.282692202611 	train acc 89.45 	val acc 90.57
#   Epoch 18 	batch 84 	loss 0.293281046538 	train acc 88.28 	val acc 90.57
#   Epoch 19 	batch 80 	loss 0.296690250648 	train acc 89.45 	val acc 90.57
#   Epoch 19 	batch 81 	loss 0.270793161374 	train acc 89.45 	val acc 90.57
#   Epoch 19 	batch 82 	loss 0.236629999984 	train acc 91.02 	val acc 90.57
#   Epoch 19 	batch 83 	loss 0.282407666009 	train acc 89.45 	val acc 90.57
#   Epoch 19 	batch 84 	loss 0.293281351806 	train acc 88.28 	val acc 90.57
#   Epoch 19 	batch 85 	loss 0.25838781223 	train acc 90.62 	val acc 90.57
#   Epoch 19 	batch 86 	loss 0.236525479114 	train acc 92.58 	val acc 90.57
#   Epoch 19 	batch 87 	loss 0.229216280977 	train acc 91.41 	val acc 90.57
#   Epoch 19 	batch 88 	loss 0.307329021282 	train acc 88.28 	val acc 90.57
#   Epoch 19 	batch 89 	loss 0.170795384708 	train acc 94.53 	val acc 90.57
#   Epoch 19 	batch 90 	loss 0.224651666431 	train acc 90.23 	val acc 90.62
#   Epoch 19 	batch 91 	loss 0.24111091713 	train acc 91.02 	val acc 90.62
#   Epoch 19 	batch 92 	loss 0.215034679774 	train acc 91.41 	val acc 90.62
#   Epoch 19 	batch 93 	loss 0.250358266111 	train acc 90.23 	val acc 90.62
#   Epoch 19 	batch 94 	loss 0.309742581138 	train acc 89.45 	val acc 90.62
#   Epoch 19 	batch 95 	loss 0.276523182127 	train acc 89.84 	val acc 90.62
#   Epoch 19 	batch 96 	loss 0.241910962925 	train acc 91.02 	val acc 90.62
#   Epoch 19 	batch 97 	loss 0.28640239318 	train acc 89.84 	val acc 90.62
#   Epoch 19 	batch 98 	loss 0.278677874356 	train acc 89.45 	val acc 90.62
#   Epoch 19 	batch 99 	loss 0.275517187019 	train acc 91.02 	val acc 90.62
#   Epoch 19 	batch 100 	loss 0.284195498781 	train acc 90.62 	val acc 90.62
#   Epoch 19 	batch 101 	loss 0.336241009016 	train acc 86.72 	val acc 90.62
#   Epoch 19 	batch 102 	loss 0.277132137473 	train acc 89.84 	val acc 90.62
#   Epoch 19 	batch 103 	loss 0.279747386159 	train acc 89.06 	val acc 90.62
#   Epoch 19 	batch 104 	loss 0.280368625932 	train acc 89.06 	val acc 90.62
#   Epoch 19 	batch 105 	loss 0.293547560716 	train acc 89.06 	val acc 90.62
#   Epoch 19 	batch 106 	loss 0.285090421629 	train acc 89.45 	val acc 90.62
#   Epoch 19 	batch 107 	loss 0.216528697609 	train acc 91.80 	val acc 90.62
#   Epoch 19 	batch 108 	loss 0.26222301196 	train acc 90.23 	val acc 90.62
#   Epoch 19 	batch 109 	loss 0.26065096166 	train acc 89.45 	val acc 90.62
# Epoch 20 of 20 took 15.914s
#   training loss:		0.258469
#   training accuracy:		90.25 %
#   validation loss:		0.266593
#   validation accuracy:		90.62 %
# Training completed.
# Testing...
# Final results:
#   test loss:			0.252768
#   test accuracy:		90.01 %

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
visualize.plot_loss_acc(DATA_SET + '_train', train_losses, train_accuracies, val_accuracies, learning_rate, reg_strength, num_epochs, num_train)
