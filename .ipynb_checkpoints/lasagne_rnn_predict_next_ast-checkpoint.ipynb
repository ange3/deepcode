# %% [markdown]
# # Deep Knowledge Tracing
# Authors: Lisa Wang, Angela Sy
#
# Task: Predict what the student is going to code next.
#
# Input: For each of the N students, we have a time series of Abstract Syntax Trees (ASTs), which represent the student's code at that time step.
# - input shape (num_students, num_timesteps, num_asts)
#     - num_timesteps is the max sequence length of asts that we are taking into account.
#     - num_asts is the total number of asts for that problem.
#
# Output: At each timestep, we are predicting the next AST.
# - Output shape (num_students, num_timesteps). The values will be in the range (0, num_asts).
#
# The truth matrix contains the desired output for a given input, and is used to compute the loss as well as train/val/test accuracies.
# - Truth shape (num_students, num_timesteps)

# %%
# Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import random
import sys
import csv
import time
import matplotlib.pyplot as plt
# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# our own modules
# from utils import *
# from visualize import *

import utils


import visualize

data_sets_map = {
    'synth':"syntheticDetailed/naive_c5_q50_s4000_v0.csv",
    'code_org' : "data/hoc_1-9_binary_input.csv"
}

TRAJ_MAP = {
    'hoc1': 'processed_data/hoc1_trajectories.npy'
}

DATA_SET = 'code_org'
# DATA_SZ = 500000
# DATA_SET = 'synth'

# if DATA_SZ = -1, use entire data set
DATA_SZ = 4000
# DATA_SZ = -1
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
trajectories_matrix = np.load(TRAJ_MAP['hoc1'])
print trajectories_matrix.shape
print trajectories_matrix[:10, :10, :10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b41aa5cf57ca> in <module>()
# ----> 1 trajectories_matrix = np.load(TRAJ_MAP['hoc1'])
#       2 print trajectories_matrix.shape
#       3 print trajectories_matrix[:10, :10, :10]
#
# /Library/Python/2.7/site-packages/numpy/lib/npyio.pyc in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     404             else:
#     405                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 406                                          pickle_kwargs=pickle_kwargs)
#     407         else:
#     408             # Try a pickle
#
# /Library/Python/2.7/site-packages/numpy/lib/format.pyc in read_array(fp, allow_pickle, pickle_kwargs)
#     671             array = array.transpose()
#     672         else:
# --> 673             array.shape = shape
#     674
#     675     return array
#
# ValueError: total size of new array must be unchanged

# %%
# Read in the data set
# This function can be moved to utils.py
data_array = np.array(list(csv.reader(open(data_sets_map[DATA_SET],"rb"),delimiter=','))).astype('int')
if DATA_SZ != -1:
    data_array = data_array[:DATA_SZ]
    
np.random.shuffle(data_array)
num_samples = data_array.shape[0]
num_problems = data_array.shape[1]

# time steps is number of problems - 1 because we cannot predict on the last problem.
num_timesteps = num_problems - 1 

# Split data into train and test (half and half)

train_data = data_array[0:7*num_samples/8,:]
val_data =  data_array[7*num_samples/8: 15*num_samples/16 ,:]
test_data = data_array[15*num_samples/16:num_samples,:]

# %%
num_train = train_data.shape[0]
num_test = test_data.shape[0]

print('Vectorization...')
X_train, next_problem_train, truth_train = utils.vectorize_data(train_data)
X_val, next_problem_val, truth_val = utils.vectorize_data(val_data)
X_test, next_problem_test, truth_test = utils.vectorize_data(test_data)
print ("Vectorization done!")
print X_train.shape
print X_val.shape
print X_test.shape
# Out:
# Vectorization...
# Vectorization done!
# (3500, 8, 18)
# (250, 8, 18)
# (250, 8, 18)

# %%
# hyperparameters
hidden_size = 200 # size of hidden layer of neurons
learning_rate = 1e-2
lr_decay = 1.0
reg_strength = 0.0
grad_clip = 10
batchsize = 32
num_epochs = 20
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# %%
'''
Create a model using Lasagne layering system. The layers are as follows:
 - Input layer: [n_sample, n_time, n_input] -> [n_sample, n_time, n_input]
 - LSTM layer: [n_sample, n_time, n_input] -> [n_sample, n_time, n_hidden]
 - Reshape layer: [n_sample, n_time, n_hidden] -> [n_sample*n_time, n_hidden]
 - Dense layer: [n_sample*n_time, n_hidden] -> [n_sample*n_time, n_output]
 - Output reshape layer: [n_sample*n_time, n_output] -> [n_sample, n_time, n_output]
'''
l_in = lasagne.layers.InputLayer(shape=(None, num_timesteps, num_asts))
l_lstm = lasagne.layers.LSTMLayer(
    l_in, hidden_size, grad_clipping=grad_clip,
    nonlinearity=lasagne.nonlinearities.tanh)
l_reshape = lasagne.layers.ReshapeLayer(l_lstm, (-1, hidden_size))
l_out = lasagne.layers.DenseLayer(l_reshape,
    num_units=num_problems,
    W = lasagne.init.Normal(),
    nonlinearity=lasagne.nonlinearities.sigmoid)
l_pred = lasagne.layers.ReshapeLayer(l_out, (-1, num_timesteps, num_problems))

''' pred:for each student, a vector that gives probability of next question being answered correctly
    y: for each student, a one-hot-encoding of shape (num_timesteps, num_problems), indicating which problem the student will do at the next timestep 
    truth: for each student, a vector that indicates for each timestep whether next problem was answered correctly
'''
pred = lasagne.layers.get_output(l_pred)
next_problem = Tensor.tensor3('next_problem')
truth = Tensor.imatrix("truth")

# pred_probs: shape(num_samples, num_timesteps)
# we reduce the three-dimensional probability tensor to two dimensions
# by only keeping the probabilities corresponding to the next problem
# we don't care about the predicted probabilities for other problems
pred_probs = Tensor.sum(pred * next_problem, axis = 2)
# loss function
loss = Tensor.nnet.binary_crossentropy(pred_probs, truth)

# TODO: why do we use both cost and loss? (naming :D)
# take average of loss per sample, makes loss more comparable when batch sizes change
cost = loss.mean()

# update function
print("Computing updates ...")
all_params = lasagne.layers.get_all_params(l_pred)
updates = lasagne.updates.adam(cost, all_params, learning_rate)

# Function to compute accuracy:
# if probability was > 0.5, we consider it a 1, and 0 otherwise.
# binary_pred: for each student, a vector of length num_timesteps indicating whether the 
# probability of getting the next problem correct is larger than 0.5.
binary_pred = Tensor.round(pred_probs)
acc = Tensor.mean(Tensor.eq(binary_pred, truth))
    
# training function
print("Compiling functions ...")
# training function, only returns loss
train_fn = theano.function([l_in.input_var, next_problem, truth], cost, updates=updates, allow_input_downcast=True)
# training function, returns loss and acc
train_acc_fn = theano.function([l_in.input_var, next_problem, truth], [cost, acc], updates=updates, allow_input_downcast=True)

compute_cost = theano.function([l_in.input_var, next_problem, truth], cost, allow_input_downcast=True)
# computes loss and accuracy
compute_cost_acc = theano.function([l_in.input_var, next_problem, truth], [cost, acc], allow_input_downcast=True)

print("Compiling done!")
# Out:
# Computing updates ...
# Compiling functions ...
# Compiling done!

# %%
def check_val_loss_acc(X_val, next_problem_val, truth_val, batchsize):
    # a full pass over the validation data:
    val_err = 0.0
    val_acc = 0.0
    val_batches = 0
    for batch in utils.iterate_minibatches(X_val, next_problem_val, truth_val, batchsize, shuffle=False):
        X_, next_problem_, truth_ = batch
        err, acc = compute_cost_acc(X_, next_problem_, truth_)
        val_err += err
        val_acc += acc
        val_batches += 1
    val_loss = val_err/val_batches
    val_acc = val_acc/val_batches * 100
    return val_loss, val_acc

# %%
# Training!!!
print("Starting training...")
# We iterate over epochs:
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0.0
    train_acc = 0.0
    train_batches = 0
    start_time = time.time()
    for batch in utils.iterate_minibatches(X_train, next_problem_train, truth_train, batchsize, shuffle=False):
        X_, next_problem_, truth_ = batch
        err, acc = train_acc_fn(X_, next_problem_, truth_)
        train_err += err
        train_acc += acc
        train_batches += 1
        val_loss, val_acc = check_val_loss_acc(X_val, next_problem_val, truth_val, batchsize)
        print("  Epoch {} \tbatch {} \tloss {} \ttrain acc {:.2f} \tval acc {:.2f} ".format(epoch, train_batches, err, acc * 100, val_acc) )
    train_acc = train_acc/train_batches * 100
    train_accuracies.append(train_acc)
    train_loss = train_err/train_batches
    train_losses.append(train_loss)
    
    val_loss, val_acc = check_val_loss_acc(X_val, next_problem_val, truth_val, batchsize)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t\t{:.6f}".format(train_loss))
    print("  training accuracy:\t\t{:.2f} %".format(train_acc))
    print("  validation loss:\t\t{:.6f}".format(val_loss))
    print("  validation accuracy:\t\t{:.2f} %".format(val_acc))

print("Training completed.")

print("Testing...")
# After training, we compute and print the test error:
test_err = 0
test_acc = 0
test_batches = 0
for batch in utils.iterate_minibatches(X_test, next_problem_test, truth_test, batchsize, shuffle=False):
    X_, next_problem_, truth_ = batch
    err, acc = compute_cost_acc(X_, next_problem_, truth_)
    test_err += err
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))
# Out:
# Starting training...
#   Epoch 0 	batch 1 	loss 0.694265286517 	train acc 25.00 	val acc 86.50
#   Epoch 0 	batch 2 	loss 0.667516080261 	train acc 81.64 	val acc 86.22
#   Epoch 0 	batch 3 	loss 0.606432573194 	train acc 87.11 	val acc 83.48
#   Epoch 0 	batch 4 	loss 0.533029325764 	train acc 78.91 	val acc 83.59
#   Epoch 0 	batch 5 	loss 0.583199474011 	train acc 80.08 	val acc 83.59
#   Epoch 0 	batch 6 	loss 0.563837148583 	train acc 77.73 	val acc 87.28
#   Epoch 0 	batch 7 	loss 0.40411138023 	train acc 86.33 	val acc 84.88
#   Epoch 0 	batch 8 	loss 0.430634958489 	train acc 82.81 	val acc 84.93
#   Epoch 0 	batch 9 	loss 0.345343106301 	train acc 87.11 	val acc 83.43
#   Epoch 0 	batch 10 	loss 0.403218949552 	train acc 83.59 	val acc 86.16
#   Epoch 0 	batch 11 	loss 0.406879319156 	train acc 83.59 	val acc 86.16
#   Epoch 0 	batch 12 	loss 0.349379465609 	train acc 85.55 	val acc 86.16
#   Epoch 0 	batch 13 	loss 0.354544448919 	train acc 85.16 	val acc 83.37
#   Epoch 0 	batch 14 	loss 0.346979721646 	train acc 85.16 	val acc 83.71
#   Epoch 0 	batch 15 	loss 0.259553273976 	train acc 88.67 	val acc 83.71
#   Epoch 0 	batch 16 	loss 0.288214534386 	train acc 86.72 	val acc 83.71
#   Epoch 0 	batch 17 	loss 0.394495278327 	train acc 82.03 	val acc 84.65
#   Epoch 0 	batch 18 	loss 0.328947751483 	train acc 83.59 	val acc 88.62
#   Epoch 0 	batch 19 	loss 0.430101899783 	train acc 84.38 	val acc 90.23
#   Epoch 0 	batch 20 	loss 0.345425240322 	train acc 89.06 	val acc 89.45
#   Epoch 0 	batch 21 	loss 0.273485997843 	train acc 88.28 	val acc 89.01
#   Epoch 0 	batch 22 	loss 0.325917750709 	train acc 87.89 	val acc 88.56
#   Epoch 0 	batch 23 	loss 0.261982854975 	train acc 89.06 	val acc 88.45
#   Epoch 0 	batch 24 	loss 0.200586524818 	train acc 92.58 	val acc 88.39
#   Epoch 0 	batch 25 	loss 0.341653932355 	train acc 86.72 	val acc 88.39
#   Epoch 0 	batch 26 	loss 0.337493232076 	train acc 84.77 	val acc 89.12
#   Epoch 0 	batch 27 	loss 0.304082825301 	train acc 86.72 	val acc 89.51
#   Epoch 0 	batch 28 	loss 0.290891018815 	train acc 86.72 	val acc 90.40
#   Epoch 0 	batch 29 	loss 0.232525540601 	train acc 91.80 	val acc 90.40
#   Epoch 0 	batch 30 	loss 0.265398975066 	train acc 91.80 	val acc 90.46
#   Epoch 0 	batch 31 	loss 0.235021892864 	train acc 91.02 	val acc 90.46
#   Epoch 0 	batch 32 	loss 0.33775274448 	train acc 85.94 	val acc 90.40
#   Epoch 0 	batch 33 	loss 0.279134911164 	train acc 89.06 	val acc 87.50
#   Epoch 0 	batch 34 	loss 0.300432766541 	train acc 87.89 	val acc 87.33
#   Epoch 0 	batch 35 	loss 0.271363596375 	train acc 89.45 	val acc 87.50
#   Epoch 0 	batch 36 	loss 0.259570877581 	train acc 87.89 	val acc 87.56
#   Epoch 0 	batch 37 	loss 0.252336425683 	train acc 87.89 	val acc 87.72
#   Epoch 0 	batch 38 	loss 0.307073145048 	train acc 86.33 	val acc 90.51
#   Epoch 0 	batch 39 	loss 0.284320237489 	train acc 89.06 	val acc 90.40
#   Epoch 0 	batch 40 	loss 0.278973182269 	train acc 90.23 	val acc 90.57
#   Epoch 0 	batch 41 	loss 0.33005460645 	train acc 87.89 	val acc 90.57
#   Epoch 0 	batch 42 	loss 0.244119250915 	train acc 90.62 	val acc 90.51
#   Epoch 0 	batch 43 	loss 0.333683428296 	train acc 87.50 	val acc 90.51
#   Epoch 0 	batch 44 	loss 0.268304363906 	train acc 89.45 	val acc 90.62
#   Epoch 0 	batch 45 	loss 0.309092898103 	train acc 87.89 	val acc 90.68
#   Epoch 3 	batch 105 	loss 0.32616960178 	train acc 87.50 	val acc 90.46
#   Epoch 3 	batch 106 	loss 0.285024947379 	train acc 88.28 	val acc 90.46
#   Epoch 3 	batch 107 	loss 0.191309721203 	train acc 93.36 	val acc 90.46
#   Epoch 3 	batch 108 	loss 0.243393052906 	train acc 91.41 	val acc 90.51
#   Epoch 3 	batch 109 	loss 0.239448736944 	train acc 91.02 	val acc 90.51
# Epoch 4 of 20 took 18.098s
#   training loss:		0.261050
#   training accuracy:		90.23 %
#   validation loss:		0.259914
#   validation accuracy:		90.51 %
#   Epoch 4 	batch 1 	loss 0.216718916734 	train acc 91.80 	val acc 90.51
#   Epoch 4 	batch 2 	loss 0.26919011634 	train acc 91.02 	val acc 90.51
#   Epoch 4 	batch 3 	loss 0.238332465126 	train acc 89.84 	val acc 90.51
#   Epoch 4 	batch 4 	loss 0.292201604418 	train acc 90.23 	val acc 90.57
#   Epoch 4 	batch 5 	loss 0.274614607123 	train acc 90.23 	val acc 90.57
#   Epoch 4 	batch 6 	loss 0.300249467723 	train acc 90.23 	val acc 90.57
#   Epoch 4 	batch 7 	loss 0.25686962507 	train acc 89.45 	val acc 90.57
#   Epoch 4 	batch 8 	loss 0.354921913374 	train acc 88.28 	val acc 90.57
#   Epoch 4 	batch 9 	loss 0.23342989102 	train acc 90.23 	val acc 90.57
#   Epoch 4 	batch 10 	loss 0.323791780677 	train acc 88.28 	val acc 90.57
#   Epoch 4 	batch 11 	loss 0.29654363138 	train acc 88.28 	val acc 90.51
#   Epoch 4 	batch 12 	loss 0.27711848562 	train acc 89.45 	val acc 90.51
#   Epoch 4 	batch 13 	loss 0.275269370967 	train acc 89.06 	val acc 90.51
#   Epoch 4 	batch 14 	loss 0.283979298982 	train acc 89.45 	val acc 90.51
#   Epoch 4 	batch 15 	loss 0.2092195832 	train acc 92.58 	val acc 90.51
#   Epoch 4 	batch 16 	loss 0.256917592795 	train acc 89.84 	val acc 90.51
#   Epoch 4 	batch 17 	loss 0.303123021109 	train acc 88.67 	val acc 90.57
#   Epoch 4 	batch 18 	loss 0.288726868307 	train acc 88.67 	val acc 90.57
#   Epoch 4 	batch 19 	loss 0.268851247496 	train acc 91.02 	val acc 90.51
#   Epoch 4 	batch 20 	loss 0.272039017837 	train acc 91.02 	val acc 90.51
#   Epoch 4 	batch 21 	loss 0.235055471901 	train acc 90.62 	val acc 90.51
#   Epoch 4 	batch 22 	loss 0.270090106495 	train acc 91.02 	val acc 90.51
#   Epoch 4 	batch 23 	loss 0.247838332732 	train acc 90.62 	val acc 90.51
#   Epoch 4 	batch 24 	loss 0.184327456564 	train acc 93.36 	val acc 90.51
#   Epoch 4 	batch 25 	loss 0.320732064659 	train acc 87.89 	val acc 90.51
#   Epoch 4 	batch 26 	loss 0.251202371498 	train acc 90.23 	val acc 90.51
#   Epoch 4 	batch 27 	loss 0.28348867329 	train acc 87.89 	val acc 90.51
#   Epoch 4 	batch 28 	loss 0.290080800219 	train acc 86.72 	val acc 90.51
#   Epoch 4 	batch 29 	loss 0.218689696796 	train acc 92.19 	val acc 90.51
#   Epoch 18 	batch 48 	loss 0.217765774364 	train acc 93.75 	val acc 90.51
#   Epoch 18 	batch 49 	loss 0.207579761022 	train acc 92.58 	val acc 90.51
#   Epoch 18 	batch 50 	loss 0.272199430484 	train acc 90.23 	val acc 90.51
#   Epoch 18 	batch 51 	loss 0.235638852223 	train acc 93.36 	val acc 90.51
#   Epoch 18 	batch 52 	loss 0.266655615215 	train acc 89.45 	val acc 90.51
#   Epoch 18 	batch 53 	loss 0.270586479506 	train acc 88.67 	val acc 90.46
#   Epoch 18 	batch 54 	loss 0.248042677772 	train acc 91.80 	val acc 90.46
#   Epoch 18 	batch 55 	loss 0.251795746193 	train acc 89.06 	val acc 90.51
#   Epoch 18 	batch 56 	loss 0.239047723872 	train acc 92.19 	val acc 90.51
#   Epoch 18 	batch 57 	loss 0.254817891132 	train acc 91.02 	val acc 90.51
#   Epoch 18 	batch 58 	loss 0.17547662422 	train acc 92.58 	val acc 90.51
#   Epoch 18 	batch 59 	loss 0.238537584704 	train acc 90.62 	val acc 90.51
#   Epoch 18 	batch 60 	loss 0.244841146472 	train acc 92.19 	val acc 90.51
#   Epoch 18 	batch 61 	loss 0.230276483905 	train acc 91.41 	val acc 90.51
#   Epoch 18 	batch 62 	loss 0.309768544756 	train acc 88.67 	val acc 90.51
#   Epoch 18 	batch 63 	loss 0.287329285443 	train acc 90.62 	val acc 90.51
#   Epoch 18 	batch 64 	loss 0.248543584892 	train acc 91.80 	val acc 90.51
#   Epoch 18 	batch 65 	loss 0.288743797792 	train acc 88.67 	val acc 90.51
#   Epoch 18 	batch 66 	loss 0.27734853063 	train acc 89.06 	val acc 90.51
#   Epoch 18 	batch 67 	loss 0.202336203572 	train acc 92.58 	val acc 90.51
#   Epoch 18 	batch 68 	loss 0.295756216833 	train acc 86.33 	val acc 90.51
#   Epoch 18 	batch 69 	loss 0.300364847425 	train acc 89.06 	val acc 90.51
#   Epoch 18 	batch 70 	loss 0.22853117827 	train acc 90.62 	val acc 90.51
#   Epoch 18 	batch 71 	loss 0.274384646804 	train acc 90.23 	val acc 90.51
#   Epoch 18 	batch 72 	loss 0.242415049716 	train acc 91.02 	val acc 90.51
#   Epoch 18 	batch 73 	loss 0.235437586276 	train acc 91.41 	val acc 90.51
#   Epoch 18 	batch 74 	loss 0.219950069236 	train acc 92.58 	val acc 90.46
#   Epoch 18 	batch 75 	loss 0.302196679906 	train acc 87.11 	val acc 90.40
#   Epoch 18 	batch 76 	loss 0.234944069205 	train acc 91.80 	val acc 90.40
#   Epoch 18 	batch 77 	loss 0.313516167835 	train acc 88.28 	val acc 90.40
#   Epoch 18 	batch 78 	loss 0.263570502275 	train acc 89.45 	val acc 90.40
#   Epoch 18 	batch 79 	loss 0.277370784369 	train acc 89.45 	val acc 90.40
#   Epoch 18 	batch 80 	loss 0.279510758436 	train acc 87.89 	val acc 90.40
#   Epoch 18 	batch 81 	loss 0.261871852826 	train acc 89.84 	val acc 90.40
#   Epoch 18 	batch 82 	loss 0.223014180463 	train acc 91.41 	val acc 90.40
#   Epoch 18 	batch 83 	loss 0.208462025952 	train acc 90.62 	val acc 90.40
#   Epoch 18 	batch 84 	loss 0.207993769797 	train acc 92.58 	val acc 90.40
#   Epoch 18 	batch 85 	loss 0.303653927727 	train acc 88.28 	val acc 90.40
#   Epoch 18 	batch 86 	loss 0.220507787768 	train acc 92.19 	val acc 90.40
#   Epoch 18 	batch 87 	loss 0.269757392667 	train acc 89.84 	val acc 90.40
#   Epoch 18 	batch 88 	loss 0.274938899793 	train acc 89.84 	val acc 90.40
#   Epoch 18 	batch 89 	loss 0.190688190232 	train acc 93.75 	val acc 90.46
#   Epoch 18 	batch 90 	loss 0.276765715256 	train acc 90.62 	val acc 90.40
#   Epoch 18 	batch 91 	loss 0.299136585375 	train acc 92.19 	val acc 90.40
#   Epoch 18 	batch 92 	loss 0.231431173432 	train acc 90.62 	val acc 90.46
#   Epoch 18 	batch 93 	loss 0.21202675407 	train acc 91.41 	val acc 90.46
#   Epoch 18 	batch 94 	loss 0.252652914129 	train acc 90.23 	val acc 90.46
#   Epoch 18 	batch 95 	loss 0.274180818863 	train acc 87.50 	val acc 90.40
#   Epoch 18 	batch 96 	loss 0.260668403073 	train acc 91.80 	val acc 90.40
#   Epoch 18 	batch 97 	loss 0.271931104229 	train acc 91.02 	val acc 90.40
#   Epoch 18 	batch 98 	loss 0.273592122414 	train acc 87.89 	val acc 90.40
#   Epoch 18 	batch 99 	loss 0.214891896442 	train acc 93.36 	val acc 90.40
#   Epoch 18 	batch 100 	loss 0.303183856196 	train acc 88.67 	val acc 90.40
#   Epoch 18 	batch 101 	loss 0.212245945842 	train acc 94.14 	val acc 90.40
#   Epoch 18 	batch 102 	loss 0.199032533557 	train acc 92.19 	val acc 90.46
#   Epoch 18 	batch 103 	loss 0.274253311966 	train acc 89.45 	val acc 90.46
#   Epoch 18 	batch 104 	loss 0.234270090743 	train acc 91.41 	val acc 90.46
#   Epoch 18 	batch 105 	loss 0.321624348665 	train acc 87.50 	val acc 90.46
#   Epoch 18 	batch 106 	loss 0.27860036008 	train acc 88.28 	val acc 90.40
#   Epoch 18 	batch 107 	loss 0.194433919173 	train acc 93.36 	val acc 90.40
#   Epoch 18 	batch 108 	loss 0.239919860029 	train acc 91.41 	val acc 90.40
#   Epoch 18 	batch 109 	loss 0.241019183223 	train acc 91.02 	val acc 90.40
# Epoch 19 of 20 took 21.162s
#   training loss:		0.257896
#   training accuracy:		90.31 %
#   validation loss:		0.259678
#   validation accuracy:		90.40 %
#   Epoch 19 	batch 1 	loss 0.216572563021 	train acc 91.80 	val acc 90.40
#   Epoch 19 	batch 2 	loss 0.266645199685 	train acc 91.02 	val acc 90.40
#   Epoch 19 	batch 3 	loss 0.239360400103 	train acc 90.23 	val acc 90.40
#   Epoch 19 	batch 4 	loss 0.289014942487 	train acc 90.23 	val acc 90.40
#   Epoch 19 	batch 5 	loss 0.268339186761 	train acc 90.23 	val acc 90.40
#   Epoch 19 	batch 6 	loss 0.287039786392 	train acc 90.23 	val acc 90.40
#   Epoch 19 	batch 7 	loss 0.258445196805 	train acc 89.84 	val acc 90.40
#   Epoch 19 	batch 79 	loss 0.278630613194 	train acc 89.45 	val acc 90.40
#   Epoch 19 	batch 80 	loss 0.279143459081 	train acc 87.89 	val acc 90.40
#   Epoch 19 	batch 81 	loss 0.261381532834 	train acc 89.84 	val acc 90.40
#   Epoch 19 	batch 82 	loss 0.222926794282 	train acc 91.41 	val acc 90.40
#   Epoch 19 	batch 83 	loss 0.208345705904 	train acc 90.62 	val acc 90.40
#   Epoch 19 	batch 84 	loss 0.208031583989 	train acc 92.58 	val acc 90.40
#   Epoch 19 	batch 85 	loss 0.303515597781 	train acc 88.28 	val acc 90.46
#   Epoch 19 	batch 86 	loss 0.234256296031 	train acc 91.41 	val acc 90.46
#   Epoch 19 	batch 87 	loss 0.270384141112 	train acc 89.84 	val acc 90.46
#   Epoch 19 	batch 88 	loss 0.275069843025 	train acc 89.84 	val acc 90.46
#   Epoch 19 	batch 89 	loss 0.190645442031 	train acc 93.75 	val acc 90.46
#   Epoch 19 	batch 90 	loss 0.277077072314 	train acc 90.62 	val acc 90.46
#   Epoch 19 	batch 91 	loss 0.298790414121 	train acc 92.19 	val acc 90.46
#   Epoch 19 	batch 92 	loss 0.231542691473 	train acc 90.62 	val acc 90.46
#   Epoch 19 	batch 93 	loss 0.212062271466 	train acc 91.41 	val acc 90.46
#   Epoch 19 	batch 94 	loss 0.253445139846 	train acc 90.23 	val acc 90.46
#   Epoch 19 	batch 95 	loss 0.273926127651 	train acc 87.11 	val acc 90.46
#   Epoch 19 	batch 96 	loss 0.26037936044 	train acc 91.80 	val acc 90.46
#   Epoch 19 	batch 97 	loss 0.271750289243 	train acc 91.02 	val acc 90.40
#   Epoch 19 	batch 98 	loss 0.274427791484 	train acc 87.89 	val acc 90.40
#   Epoch 19 	batch 99 	loss 0.214631937425 	train acc 93.36 	val acc 90.40
#   Epoch 19 	batch 100 	loss 0.303589801331 	train acc 88.67 	val acc 90.40
#   Epoch 19 	batch 101 	loss 0.211979436212 	train acc 94.14 	val acc 90.40
#   Epoch 19 	batch 102 	loss 0.199773411668 	train acc 92.19 	val acc 90.40
#   Epoch 19 	batch 103 	loss 0.273904905937 	train acc 89.45 	val acc 90.40
#   Epoch 19 	batch 104 	loss 0.23612215404 	train acc 91.41 	val acc 90.40
#   Epoch 19 	batch 105 	loss 0.322913966372 	train acc 87.50 	val acc 90.40
#   Epoch 19 	batch 106 	loss 0.280655547313 	train acc 88.28 	val acc 90.40
#   Epoch 19 	batch 107 	loss 0.194502965815 	train acc 93.36 	val acc 90.40
#   Epoch 19 	batch 108 	loss 0.24010783019 	train acc 91.41 	val acc 90.40
#   Epoch 19 	batch 109 	loss 0.24153736045 	train acc 91.02 	val acc 90.40
# Epoch 20 of 20 took 21.699s
#   training loss:		0.257918
#   training accuracy:		90.33 %
#   validation loss:		0.259908
#   validation accuracy:		90.40 %
# Training completed.
# Testing...
# Final results:
#   test loss:			0.273940
#   test accuracy:		89.45 %

# %%
# Visualize the loss and the accuracies for both training and validation sets for each epoch
visualize.plot_loss_acc(DATA_SET + '_train', train_losses, train_accuracies, val_accuracies, learning_rate, reg_strength, num_epochs, num_train)
