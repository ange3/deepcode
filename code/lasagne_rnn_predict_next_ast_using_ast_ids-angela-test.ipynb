# %% [markdown]
# # Deep Knowledge Tracing
# Authors: Lisa Wang, Angela Sy
#
# ### Task: Predict what the student is going to code next.
#
# Input: For each of the N students, we have a time series of Abstract Syntax Trees (ASTs), which represent the student's code at that time step.
# - input shape (num_students, num_timesteps, num_asts)
#     - num_timesteps is the max sequence length of asts that we are taking into account.
#     - num_asts is the total number of asts for that problem.
#
# Output: At each timestep, we are predicting the next AST.
# - Output shape (num_students, num_timesteps, num_asts). (one-hot encoding)
#
# The truth matrix contains the desired output for a given input, and is used to compute the loss as well as train/val/test accuracies.
# - Truth shape (num_students, num_timesteps) Values are in range (0, num_asts)
#
# Accuracy:
# - Raw Accuracy: For all predictions at all timesteps, we get the percentage of predictions we got correct.
# - Corrected Accuracy: Since many trajectories contain fewer asts than max_traj_len, we fill the empty asts with our dummy ast token at row 0. However, predicting on end tokens is to simple of a task and might bias our results. The corrected accuracy ignores all predictions on the end token.
#
# ### Current Issues:
# AST IDs are not consistent across different HOCs. Hence, we can only train and run this model on each HOC individually.

# %%
# Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import random
import sys
import csv
import time
import matplotlib.pyplot as plt
import pickle
# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Import our own modules
import utils
import model_predict_ast as model
import visualize
from constants import *

# %%
# hyperparameters
hidden_size = 256 # size of hidden layer of neurons
learning_rate = 1e-2
lr_decay = 0.995
reg_strength = 2e-2
grad_clip = 10
batchsize = 32
num_epochs = 4
dropout_p = 0.5
num_lstm_layers = 1
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# %%
def full_train_test_run(hoc_num):
    X, y, ast_maps, num_asts = utils.load_dataset_predict_ast(hoc_num, use_embeddings=False)
    num_traj, num_timesteps, embed_dim = X.shape
    # make train, val, test split
    train_data, val_data, test_data = utils.get_train_val_test_split((X,y))
    # create model
    train_loss_acc, compute_loss_acc, probs, l_out = model.create_model(num_timesteps, num_asts, \
               hidden_size, learning_rate, embed_dim=-1, grad_clip=grad_clip, dropout_p=dropout_p, num_lstm_layers=num_lstm_layers)
    # Training!
    train_losses, train_accs, train_corrected_accs, val_losses, val_accs, val_corrected_accs = \
        model.train(train_data, val_data, train_loss_acc, compute_loss_acc, num_epochs=num_epochs, batchsize=batchsize, record_per_iter=True)
    # Evaluate on test set
    test_loss, test_raw_acc, test_corrected_acc, test_corrected_acc_per_timestep, pred_test = \
        model.check_accuracy(test_data, compute_loss_acc, dataset_name='test', compute_acc_per_timestep_bool=True)
 
    num_train = train_data[0].shape[0]
    visualize.plot_loss_acc('hoc'+ str(hoc_num) + '_train', train_losses, train_corrected_accs, val_corrected_accs, \
                            learning_rate, reg_strength, num_epochs, num_train, xlabel='iterations')  
    np.savez('../saved_models/predict_ast_with_astid_model_' + str(hoc_num) + '.npz', lasagne.layers.get_all_param_values(l_out))
    return train_corrected_accs[-1], val_corrected_accs[-1], test_corrected_acc, test_corrected_acc_per_timestep

# %%
last_train_corrected_acc = {}
last_val_corrected_acc = {}
test_corrected_acc = {}
test_corrected_acc_per_timestep = {}

hoc_num = 1
print ('Training and testing predict_next_ast rnn on Hour of Code problem #{}'.format(hoc_num))
last_train_corrected_acc[hoc_num], last_val_corrected_acc[hoc_num], test_corrected_acc[hoc_num], test_corrected_acc_per_timestep[hoc_num] = full_train_test_run(hoc_num) 
print ('='*100)

# for hoc_num in xrange(HOC_MIN, HOC_MAX+1):
#     print ('Training and testing predict_next_ast rnn on Hour of Code problem #{}'.format(hoc_num))
#     last_train_corrected_acc[hoc_num], last_val_corrected_acc[hoc_num], test_corrected_acc[hoc_num], test_corrected_acc_per_timestep[hoc_num] = full_train_test_run(hoc_num) 
#     print ('='*100)
# Out:
# Training and testing predict_next_ast rnn on Hour of Code problem #1
# Preparing network inputs and targets, and the ast maps...
# Inputs and targets done!
# Building network ...
# Computing updates ...
# Compiling functions ...
# Compiling done!
# Starting training...
# Total training iterations: 144
# Ep 0 	iter 1  	loss 5.27348, train acc 0.00, train corr acc 0.00, val acc 68.07, val corr acc 29.65
# Ep 0 	iter 2  	loss 5.12689, train acc 67.19, train corr acc 25.88, val acc 73.29, val corr acc 41.15
# Ep 0 	iter 3  	loss 4.58716, train acc 70.31, train corr acc 35.23, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 4  	loss 2.96079, train acc 73.44, train corr acc 39.29, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 5  	loss 1.72613, train acc 72.40, train corr acc 37.65, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 6  	loss 1.30930, train acc 73.96, train corr acc 39.02, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 7  	loss 2.01915, train acc 64.58, train corr acc 32.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 8  	loss 1.51252, train acc 69.79, train corr acc 35.56, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 9  	loss 1.19092, train acc 74.48, train corr acc 38.75, val acc 68.47, val corr acc 36.73
# Ep 0 	iter 10  	loss 1.35620, train acc 68.75, train corr acc 35.37, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 11  	loss 1.28947, train acc 71.35, train corr acc 36.78, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 12  	loss 1.43136, train acc 73.44, train corr acc 38.55, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 13  	loss 1.06251, train acc 75.00, train corr acc 40.00, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 14  	loss 1.23795, train acc 71.88, train corr acc 37.93, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 15  	loss 1.33181, train acc 71.35, train corr acc 36.78, val acc 71.29, val corr acc 37.17
# Ep 0 	iter 16  	loss 1.16856, train acc 71.88, train corr acc 37.21, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 17  	loss 1.27439, train acc 68.75, train corr acc 35.48, val acc 72.29, val corr acc 39.38
# Ep 0 	iter 18  	loss 1.34341, train acc 70.31, train corr acc 37.21, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 19  	loss 1.04969, train acc 76.04, train corr acc 43.90, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 20  	loss 1.24511, train acc 69.79, train corr acc 34.09, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 21  	loss 1.41446, train acc 68.23, train corr acc 34.41, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 22  	loss 1.12661, train acc 74.48, train corr acc 40.24, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 23  	loss 1.08528, train acc 70.31, train corr acc 36.67, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 24  	loss 1.13770, train acc 68.75, train corr acc 38.54, val acc 69.88, val corr acc 34.51
# Ep 0 	iter 25  	loss 1.00438, train acc 73.96, train corr acc 37.50, val acc 72.69, val corr acc 39.82
# Ep 0 	iter 26  	loss 1.03505, train acc 75.00, train corr acc 38.46, val acc 70.48, val corr acc 34.96
# Ep 0 	iter 27  	loss 1.26785, train acc 66.15, train corr acc 35.00, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 28  	loss 0.90433, train acc 77.60, train corr acc 44.87, val acc 72.69, val corr acc 39.82
# Ep 0 	iter 29  	loss 0.92573, train acc 74.48, train corr acc 38.75, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 30  	loss 1.15163, train acc 67.19, train corr acc 35.05, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 31  	loss 0.97170, train acc 74.48, train corr acc 40.96, val acc 71.89, val corr acc 38.05
# Ep 0 	iter 32  	loss 1.17167, train acc 66.15, train corr acc 35.00, val acc 72.69, val corr acc 40.27
# Ep 0 	iter 33  	loss 0.96544, train acc 74.48, train corr acc 40.51, val acc 70.48, val corr acc 37.17
# Ep 0 	iter 34  	loss 1.25569, train acc 65.10, train corr acc 32.65, val acc 70.88, val corr acc 35.84
# Ep 0 	iter 35  	loss 1.02987, train acc 73.44, train corr acc 43.96, val acc 71.69, val corr acc 38.05
# Ep 0 	iter 36  	loss 1.01202, train acc 71.35, train corr acc 34.52, val acc 72.09, val corr acc 38.50
#
# Epoch 1 of 4 took 8.073s
#   training loss:		0.994581
#   training raw accuracy:		72.38 %
#   training corrected acc:		38.98 %
#   validation loss:		0.962171
#   validation raw accuracy:		72.09 %
#   validation corrected acc:		38.50 %
#
# Ep 1 	iter 37  	loss 1.05339, train acc 73.44, train corr acc 40.70, val acc 72.49, val corr acc 39.38
# Ep 1 	iter 38  	loss 0.97236, train acc 75.00, train corr acc 43.53, val acc 70.88, val corr acc 35.84
# Ep 1 	iter 39  	loss 1.01526, train acc 71.88, train corr acc 38.64, val acc 72.29, val corr acc 38.94
# Ep 1 	iter 40  	loss 0.97504, train acc 71.88, train corr acc 35.71, val acc 73.29, val corr acc 41.15
# Ep 1 	iter 41  	loss 0.95289, train acc 76.56, train corr acc 47.06, val acc 73.29, val corr acc 41.15
# Ep 1 	iter 42  	loss 0.87954, train acc 76.04, train corr acc 43.90, val acc 74.30, val corr acc 43.36
# Ep 1 	iter 43  	loss 1.12894, train acc 70.31, train corr acc 43.00, val acc 72.09, val corr acc 38.50
# Ep 1 	iter 44  	loss 1.04915, train acc 69.79, train corr acc 35.56, val acc 72.49, val corr acc 39.38
# Ep 1 	iter 45  	loss 0.93722, train acc 76.56, train corr acc 43.75, val acc 72.09, val corr acc 38.50
# Ep 1 	iter 46  	loss 0.85329, train acc 76.56, train corr acc 45.12, val acc 72.49, val corr acc 39.38
# Ep 1 	iter 47  	loss 0.91962, train acc 72.40, train corr acc 39.08, val acc 71.08, val corr acc 36.28
# Ep 1 	iter 48  	loss 1.10286, train acc 73.44, train corr acc 38.55, val acc 72.49, val corr acc 39.38
# Ep 1 	iter 49  	loss 0.84896, train acc 76.56, train corr acc 43.75, val acc 70.68, val corr acc 35.40
# Ep 1 	iter 50  	loss 1.01060, train acc 70.31, train corr acc 34.48, val acc 71.89, val corr acc 38.50
# Ep 1 	iter 51  	loss 0.93560, train acc 72.40, train corr acc 40.23, val acc 71.29, val corr acc 36.73
# Ep 1 	iter 52  	loss 0.93654, train acc 72.92, train corr acc 39.53, val acc 72.09, val corr acc 38.50
# Ep 1 	iter 53  	loss 1.04999, train acc 69.27, train corr acc 36.56, val acc 71.69, val corr acc 37.61
# Ep 1 	iter 54  	loss 1.06372, train acc 71.35, train corr acc 36.05, val acc 71.69, val corr acc 37.61
# Ep 1 	iter 55  	loss 0.86372, train acc 76.56, train corr acc 45.12, val acc 72.29, val corr acc 38.94
# Ep 1 	iter 56  	loss 1.02743, train acc 69.27, train corr acc 32.95, val acc 72.09, val corr acc 38.50
# Ep 1 	iter 57  	loss 1.12466, train acc 70.31, train corr acc 38.71, val acc 73.09, val corr acc 40.71
# Ep 1 	iter 58  	loss 0.91574, train acc 76.04, train corr acc 43.90, val acc 72.69, val corr acc 39.82
# Ep 1 	iter 59  	loss 1.00572, train acc 73.96, train corr acc 44.44, val acc 74.70, val corr acc 44.25
# Ep 1 	iter 60  	loss 1.03048, train acc 70.83, train corr acc 41.67, val acc 73.29, val corr acc 41.15
# Ep 1 	iter 61  	loss 0.81823, train acc 76.04, train corr acc 42.50, val acc 72.89, val corr acc 40.27
# Ep 1 	iter 62  	loss 0.85322, train acc 78.65, train corr acc 47.44, val acc 72.89, val corr acc 40.27
# Ep 1 	iter 63  	loss 1.11478, train acc 65.62, train corr acc 34.00, val acc 72.89, val corr acc 40.27
# Ep 1 	iter 64  	loss 0.77546, train acc 78.12, train corr acc 46.15, val acc 73.09, val corr acc 40.71
# Ep 1 	iter 65  	loss 0.81872, train acc 77.60, train corr acc 46.25, val acc 73.69, val corr acc 42.04
# Ep 1 	iter 66  	loss 0.93900, train acc 72.40, train corr acc 45.36, val acc 72.89, val corr acc 40.27
# Ep 1 	iter 67  	loss 0.85843, train acc 76.04, train corr acc 44.58, val acc 74.70, val corr acc 44.25
# Ep 1 	iter 68  	loss 0.98488, train acc 69.79, train corr acc 42.00, val acc 74.10, val corr acc 42.92
# Ep 1 	iter 69  	loss 0.86751, train acc 76.56, train corr acc 43.04, val acc 74.30, val corr acc 43.36
# Ep 1 	iter 70  	loss 1.09550, train acc 70.83, train corr acc 42.86, val acc 74.50, val corr acc 43.81
# Ep 1 	iter 71  	loss 0.93415, train acc 73.44, train corr acc 43.96, val acc 74.30, val corr acc 43.36
# Ep 1 	iter 72  	loss 0.89364, train acc 75.00, train corr acc 42.86, val acc 73.49, val corr acc 41.59
#
# Epoch 2 of 4 took 7.976s
#   training loss:		0.893581
#   training raw accuracy:		75.10 %
#   training corrected acc:		45.00 %
#   validation loss:		0.872429
#   validation raw accuracy:		73.49 %
#   validation corrected acc:		41.59 %
#
# Ep 2 	iter 73  	loss 0.93477, train acc 75.00, train corr acc 44.19, val acc 73.29, val corr acc 41.15
# Ep 2 	iter 74  	loss 0.83307, train acc 80.21, train corr acc 55.29, val acc 73.69, val corr acc 42.04
# Ep 2 	iter 75  	loss 0.89905, train acc 72.92, train corr acc 40.91, val acc 73.29, val corr acc 41.15
# Ep 2 	iter 76  	loss 0.87840, train acc 75.52, train corr acc 44.05, val acc 72.89, val corr acc 40.27
# Ep 2 	iter 77  	loss 0.86263, train acc 76.56, train corr acc 47.06, val acc 73.29, val corr acc 41.15
# Ep 2 	iter 78  	loss 0.80913, train acc 77.08, train corr acc 46.34, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 79  	loss 1.02550, train acc 70.31, train corr acc 43.00, val acc 73.49, val corr acc 41.59
# Ep 2 	iter 80  	loss 0.96338, train acc 74.48, train corr acc 45.56, val acc 74.10, val corr acc 42.92
# Ep 2 	iter 81  	loss 0.86134, train acc 78.65, train corr acc 48.75, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 82  	loss 0.78702, train acc 76.56, train corr acc 45.12, val acc 73.49, val corr acc 41.59
# Ep 2 	iter 83  	loss 0.84693, train acc 73.44, train corr acc 41.38, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 84  	loss 0.95853, train acc 76.04, train corr acc 44.58, val acc 72.89, val corr acc 40.27
# Ep 2 	iter 85  	loss 0.76839, train acc 77.60, train corr acc 46.25, val acc 73.49, val corr acc 41.59
# Ep 2 	iter 86  	loss 0.91467, train acc 75.00, train corr acc 44.83, val acc 73.90, val corr acc 42.48
# Ep 2 	iter 87  	loss 0.87024, train acc 75.52, train corr acc 45.98, val acc 73.69, val corr acc 42.04
# Ep 2 	iter 88  	loss 0.84768, train acc 76.56, train corr acc 47.67, val acc 72.69, val corr acc 39.82
# Ep 2 	iter 89  	loss 0.92660, train acc 75.00, train corr acc 48.39, val acc 73.90, val corr acc 42.48
# Ep 2 	iter 90  	loss 1.01010, train acc 71.88, train corr acc 37.21, val acc 73.90, val corr acc 42.48
# Ep 2 	iter 91  	loss 0.80579, train acc 79.69, train corr acc 52.44, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 92  	loss 0.95145, train acc 71.35, train corr acc 37.50, val acc 74.10, val corr acc 42.92
# Ep 2 	iter 93  	loss 1.06681, train acc 72.40, train corr acc 43.01, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 94  	loss 0.80907, train acc 76.56, train corr acc 45.12, val acc 74.90, val corr acc 44.69
# Ep 2 	iter 95  	loss 0.94976, train acc 73.96, train corr acc 44.44, val acc 73.49, val corr acc 42.04
# Ep 2 	iter 96  	loss 0.98183, train acc 73.96, train corr acc 47.92, val acc 73.90, val corr acc 42.48
# Ep 2 	iter 97  	loss 0.84116, train acc 75.52, train corr acc 41.25, val acc 73.69, val corr acc 42.04
# Ep 2 	iter 98  	loss 0.81856, train acc 80.73, train corr acc 52.56, val acc 73.90, val corr acc 42.48
# Ep 2 	iter 99  	loss 1.04306, train acc 70.31, train corr acc 43.00, val acc 74.50, val corr acc 43.81
# Ep 2 	iter 100  	loss 0.75481, train acc 79.17, train corr acc 48.72, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 101  	loss 0.75478, train acc 76.56, train corr acc 43.75, val acc 73.90, val corr acc 42.48
# Ep 2 	iter 102  	loss 0.88382, train acc 72.40, train corr acc 45.36, val acc 74.30, val corr acc 43.36
# Ep 2 	iter 103  	loss 0.80776, train acc 76.56, train corr acc 45.78, val acc 73.69, val corr acc 42.04
# Ep 2 	iter 104  	loss 0.96937, train acc 70.31, train corr acc 43.00, val acc 73.69, val corr acc 42.04
# Ep 2 	iter 105  	loss 0.78398, train acc 79.69, train corr acc 50.63, val acc 74.10, val corr acc 42.92
# Ep 2 	iter 106  	loss 1.05579, train acc 72.92, train corr acc 46.94, val acc 74.90, val corr acc 44.69
# Ep 2 	iter 107  	loss 0.86719, train acc 76.04, train corr acc 49.45, val acc 74.70, val corr acc 44.25
# Ep 2 	iter 108  	loss 0.82404, train acc 77.60, train corr acc 48.81, val acc 74.10, val corr acc 42.92
#
# Epoch 3 of 4 took 7.301s
#   training loss:		0.860032
#   training raw accuracy:		75.59 %
#   training corrected acc:		46.08 %
#   validation loss:		0.878813
#   validation raw accuracy:		74.10 %
#   validation corrected acc:		42.92 %
#
# Ep 3 	iter 109  	loss 0.90940, train acc 75.52, train corr acc 45.35, val acc 72.29, val corr acc 38.94
# Ep 3 	iter 110  	loss 0.80659, train acc 77.08, train corr acc 48.24, val acc 73.69, val corr acc 42.04
# Ep 3 	iter 111  	loss 0.88910, train acc 73.44, train corr acc 42.05, val acc 74.90, val corr acc 44.69
# Ep 3 	iter 112  	loss 0.84899, train acc 76.04, train corr acc 45.24, val acc 74.90, val corr acc 44.69
# Ep 3 	iter 113  	loss 0.82285, train acc 76.56, train corr acc 47.06, val acc 74.10, val corr acc 42.92
# Ep 3 	iter 114  	loss 0.80351, train acc 77.60, train corr acc 47.56, val acc 74.30, val corr acc 43.36
# Ep 3 	iter 115  	loss 0.96803, train acc 71.88, train corr acc 46.00, val acc 73.69, val corr acc 42.04
# Ep 3 	iter 116  	loss 0.88053, train acc 75.52, train corr acc 47.78, val acc 74.50, val corr acc 43.81
# Ep 3 	iter 117  	loss 0.80409, train acc 79.69, train corr acc 51.25, val acc 74.90, val corr acc 44.69
# Ep 3 	iter 118  	loss 0.74655, train acc 78.65, train corr acc 50.00, val acc 74.50, val corr acc 43.81
# Ep 3 	iter 119  	loss 0.80111, train acc 73.96, train corr acc 42.53, val acc 75.10, val corr acc 45.13
# Ep 3 	iter 120  	loss 0.88497, train acc 78.65, train corr acc 50.60, val acc 74.70, val corr acc 44.25
# Ep 3 	iter 121  	loss 0.75873, train acc 78.12, train corr acc 47.50, val acc 74.70, val corr acc 44.25
# Ep 3 	iter 122  	loss 0.88676, train acc 76.56, train corr acc 48.28, val acc 74.10, val corr acc 42.92
# Ep 3 	iter 123  	loss 0.83664, train acc 76.56, train corr acc 48.28, val acc 73.90, val corr acc 42.48
# Ep 3 	iter 124  	loss 0.81561, train acc 80.73, train corr acc 56.98, val acc 74.50, val corr acc 43.81
# Ep 3 	iter 125  	loss 0.88811, train acc 76.56, train corr acc 51.61, val acc 74.10, val corr acc 42.92
# Ep 3 	iter 126  	loss 0.98636, train acc 71.88, train corr acc 37.21, val acc 74.90, val corr acc 44.69
# Ep 3 	iter 127  	loss 0.74975, train acc 79.69, train corr acc 52.44, val acc 73.69, val corr acc 42.04
# Ep 3 	iter 128  	loss 0.93610, train acc 73.44, train corr acc 42.05, val acc 74.50, val corr acc 43.81
# Ep 3 	iter 129  	loss 0.90247, train acc 73.96, train corr acc 46.24, val acc 73.49, val corr acc 41.59
# Ep 3 	iter 130  	loss 0.78072, train acc 75.52, train corr acc 42.68, val acc 75.30, val corr acc 45.58
# Ep 3 	iter 131  	loss 0.87076, train acc 75.00, train corr acc 46.67, val acc 74.50, val corr acc 43.81
# Ep 3 	iter 132  	loss 0.96317, train acc 70.83, train corr acc 41.67, val acc 74.30, val corr acc 43.36
# Ep 3 	iter 133  	loss 0.75361, train acc 77.08, train corr acc 45.00, val acc 74.90, val corr acc 44.69
# Ep 3 	iter 134  	loss 0.77174, train acc 80.73, train corr acc 52.56, val acc 74.50, val corr acc 43.81
# Ep 3 	iter 135  	loss 0.96034, train acc 75.52, train corr acc 53.00, val acc 75.30, val corr acc 45.58
# Ep 3 	iter 136  	loss 0.69566, train acc 80.21, train corr acc 51.28, val acc 75.70, val corr acc 46.46
# Ep 3 	iter 137  	loss 0.75276, train acc 80.73, train corr acc 53.75, val acc 75.30, val corr acc 45.58
# Ep 3 	iter 138  	loss 0.80319, train acc 77.60, train corr acc 55.67, val acc 74.90, val corr acc 44.69
# Ep 3 	iter 139  	loss 0.79641, train acc 77.60, train corr acc 48.19, val acc 75.10, val corr acc 45.13
# Ep 3 	iter 140  	loss 0.82356, train acc 72.40, train corr acc 47.00, val acc 75.30, val corr acc 45.58
# Ep 3 	iter 141  	loss 0.75929, train acc 79.17, train corr acc 49.37, val acc 75.30, val corr acc 45.58
# Ep 3 	iter 142  	loss 0.99276, train acc 74.48, train corr acc 50.00, val acc 74.10, val corr acc 42.92
# Ep 3 	iter 143  	loss 0.85269, train acc 76.56, train corr acc 50.55, val acc 75.10, val corr acc 45.13
# Ep 3 	iter 144  	loss 0.77019, train acc 78.12, train corr acc 50.00, val acc 75.10, val corr acc 45.13
#
# Epoch 4 of 4 took 8.851s
#   training loss:		0.809167
#   training raw accuracy:		77.52 %
#   training corrected acc:		50.35 %
#   validation loss:		0.860181
#   validation raw accuracy:		75.10 %
#   validation corrected acc:		45.13 %
#
# Training completed.
# Testing...
# correct and total counts from timestep_accuracies: [(18, 83), (37, 76), (41, 53), (16, 19), (3, 3), (0, 0)]
# [0.21686746987951808, 0.4868421052631579, 0.7735849056603774, 0.8421052631578947, 1.0, -1.0]
# Final results:
#   test loss:			0.884785
#   test raw accuracy:		76.10 %
#   test corrected accuracy:	49.15 %
#   test corrected accuracy time series
#   		 Timestep 0:	21.69 %
#   		 Timestep 1:	48.68 %
#   		 Timestep 2:	77.36 %
#   		 Timestep 3:	84.21 %
#   		 Timestep 4:	100.00 %
#   		 Timestep 5:	-100.00 %
# ====================================================================================================

# %%
for hoc_num in xrange(HOC_MIN, HOC_MAX+1):
    print ('Accuracies for HOC {}:'.format(hoc_num))
    print ('last train acc: {:.2f} %'.format(last_train_corrected_acc[hoc_num] * 100))
    print ('last val acc: {:.2f} %'.format(last_val_corrected_acc[hoc_num] * 100))
    print ('overall test acc: {:.2f} %'.format(test_corrected_acc[hoc_num] * 100))
    print ('test accs time series: {}'.format(test_corrected_acc_per_timestep[hoc_num]))
# Out:
# Accuracies for HOC 1:
# last train acc: 53.57 %
# last val acc: 46.02 %
# overall test acc: 47.01 %
# test accs time series: [0.24096385542168675, 0.3815789473684211, 0.7547169811320755, 0.9473684210526315, 1.0, -1.0]
# Accuracies for HOC 2:
# last train acc: 56.73 %
# last val acc: 52.61 %
# overall test acc: 53.59 %
# test accs time series: [0.1597222222222222, 0.5481481481481482, 0.8736842105263158, 1.0, 1.0, -1.0, -1.0]
# Accuracies for HOC 3:
# last train acc: 53.33 %
# last val acc: 52.58 %
# overall test acc: 52.56 %
# test accs time series: [0.21223021582733814, 0.3258426966292135, 0.6919831223628692, 0.8875, 0.9871794871794872, 1.0]
# Accuracies for HOC 4:
# last train acc: 54.10 %
# last val acc: 55.37 %
# overall test acc: 53.43 %
# test accs time series: [0.18333333333333332, 0.4067796610169492, 0.6677018633540373, 0.8551401869158879, 0.9797979797979798, 1.0, 1.0, 1.0]
# Accuracies for HOC 5:
# last train acc: 62.18 %
# last val acc: 55.31 %
# overall test acc: 56.51 %
# test accs time series: [0.17647058823529413, 0.48514851485148514, 0.7686567164179104, 0.9357798165137615, 0.9545454545454546, 0.875, 0.25, 1.0, 1.0, -1.0]
# Accuracies for HOC 6:
# last train acc: 57.14 %
# last val acc: 55.74 %
# overall test acc: 54.81 %
# test accs time series: [0.3333333333333333, 0.5949367088607594, 0.7608695652173914, 0.9411764705882353, 1.0]
# Accuracies for HOC 7:
# last train acc: 56.38 %
# last val acc: 52.02 %
# overall test acc: 50.49 %
# test accs time series: [0.19771863117870722, 0.4880952380952381, 0.7166666666666667, 0.8735632183908046, 1.0, 1.0]
# Accuracies for HOC 8:
# last train acc: 62.37 %
# last val acc: 50.00 %
# overall test acc: 52.63 %
# test accs time series: [0.2119700748129676, 0.5162162162162162, 0.8226415094339623, 0.9333333333333333, 0.95]
# Accuracies for HOC 9:
# last train acc: 61.96 %
# last val acc: 53.65 %
# overall test acc: 51.42 %
# test accs time series: [0.15304798962386512, 0.5575221238938053, 0.8613445378151261, 0.9620253164556962, 0.9655172413793104]
