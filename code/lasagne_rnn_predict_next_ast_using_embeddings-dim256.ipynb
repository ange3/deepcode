# %% [markdown]
# # Deep Knowledge Tracing
# Authors: Lisa Wang, Angela Sy
#
# ### Task: Predict what the student is going to code next.
#
# Input: For each of the N students, we have a time series of Abstract Syntax Trees (ASTs), which represent the student's code at that time step.
# - input shape (num_students, num_timesteps, num_asts)
#     - num_timesteps is the max sequence length of asts that we are taking into account.
#     - num_asts is the total number of asts for that problem.
#
# Output: At each timestep, we are predicting the next AST.
# - Output shape (num_students, num_timesteps, num_asts). (one-hot encoding)
#
# The truth matrix contains the desired output for a given input, and is used to compute the loss as well as train/val/test accuracies.
# - Truth shape (num_students, num_timesteps) Values are in range (0, num_asts)
#
# Accuracy:
# - Raw Accuracy: For all predictions at all timesteps, we get the percentage of predictions we got correct.
# - Corrected Accuracy: Since many trajectories contain fewer asts than max_traj_len, we fill the empty asts with our dummy ast token at row 0. However, predicting on end tokens is to simple of a task and might bias our results. The corrected accuracy ignores all predictions on the end token.
#
# ### Current Issues:
# AST IDs are not consistent across different HOCs. Hence, we can only train and run this model on each HOC individually.

# %%
# Python libraries
import numpy as np
import theano
import theano.tensor as Tensor
import lasagne
import random
import sys
import csv
import time
import matplotlib.pyplot as plt
import pickle
from pprint import pprint
# allows plots to show inline in ipython notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Import our own modules
import utils
import model_predict_ast as model
import visualize
from constants import *

# %%
# hyperparameters
hidden_size = 256 # size of hidden layer of neurons
learning_rate = 3e-3
lr_decay = 0.995
reg_strength = 1e-2
grad_clip = 10
batchsize = 8
num_epochs = 1
dropout_p = 0.5
num_lstm_layers = 1
theano.config.optimizer='fast_compile'
theano.config.exception_verbosity='high'

# %%
def full_train_test_run(hoc_num):
    X, y, ast_maps, num_asts = utils.load_dataset_predict_ast(hoc_num, use_embeddings=True)
    num_traj, num_timesteps, embed_dim = X.shape
    # make train, val, test split
    train_data, val_data, test_data = utils.get_train_val_test_split((X,y))
    # create model
    train_loss_acc, compute_loss_acc, probs, l_out = model.create_model(num_timesteps, num_asts, \
               hidden_size, learning_rate, embed_dim, grad_clip, dropout_p, num_lstm_layers)
    # Training!
    train_losses, train_accs, train_corrected_accs, val_losses, val_accs, val_corrected_accs = \
        model.train(train_data, val_data, train_loss_acc, compute_loss_acc, num_epochs=num_epochs, batchsize=batchsize, record_per_iter=True)
    # Evaluate on test set
    test_loss, test_raw_acc, test_corrected_acc, test_corrected_acc_per_timestep, pred_test = \
        model.check_accuracy(test_data, compute_loss_acc, dataset_name='test', compute_acc_per_timestep_bool=True)
 
    num_train = train_data[0].shape[0]
    visualize.plot_loss_acc('hoc'+ str(hoc_num) + '_train', train_losses, train_corrected_accs, val_corrected_accs, \
                            learning_rate, reg_strength, num_epochs, num_train, xlabel='iterations')  
    np.savez('../saved_models/predict_ast_with_embed_model_' + str(hoc_num) + '.npz', lasagne.layers.get_all_param_values(l_out))
    return train_corrected_accs[-1], val_corrected_accs[-1], test_corrected_acc, test_corrected_acc_per_timestep

# %%
last_train_corrected_acc = {}
last_val_corrected_acc = {}
test_corrected_acc = {}
test_corrected_acc_per_timestep = {}

for hoc_num in xrange(HOC_MIN, HOC_MAX):
    print ('Training and testing predict_next_ast rnn on Hour of Code problem #{}'.format(hoc_num))
    last_train_corrected_acc[hoc_num], last_val_corrected_acc[hoc_num], test_corrected_acc[hoc_num], test_corrected_acc_per_timestep[hoc_num] = full_train_test_run(hoc_num) 
    print ('='*100)
# Out:
# Training and testing predict_next_ast rnn on Hour of Code problem #1
# Preparing network inputs and targets, and the ast maps...
# 195
# 2561
# Inputs and targets done!
# (1156, 6, 128)
# (1156, 6)
# (83, 6, 128)
# (83, 6)
# (83, 6, 128)
# (83, 6)
# Building network ...
# Computing updates ...
# Compiling functions ...
# Compiling done!
# Starting training...
# Total training iterations: 144
# Ep 0 	iter 1  	loss 5.27187, train acc 0.00, train corr acc 0.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 2  	loss 5.18975, train acc 75.00, train corr acc 40.00, val acc 71.89, val corr acc 38.05
# Ep 0 	iter 3  	loss 5.04831, train acc 70.83, train corr acc 36.36, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 4  	loss 4.80132, train acc 75.00, train corr acc 40.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 5  	loss 4.26198, train acc 72.92, train corr acc 38.10, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 6  	loss 3.55662, train acc 68.75, train corr acc 34.78, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 7  	loss 2.72417, train acc 72.92, train corr acc 38.10, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 8  	loss 2.01201, train acc 75.00, train corr acc 40.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 9  	loss 1.39120, train acc 79.17, train corr acc 44.44, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 10  	loss 1.15763, train acc 77.08, train corr acc 42.11, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 11  	loss 1.45458, train acc 68.75, train corr acc 34.78, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 12  	loss 1.99401, train acc 58.33, train corr acc 28.57, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 13  	loss 1.23421, train acc 72.92, train corr acc 38.10, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 14  	loss 1.12293, train acc 75.00, train corr acc 40.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 15  	loss 1.68938, train acc 68.75, train corr acc 34.78, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 16  	loss 1.31117, train acc 75.00, train corr acc 40.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 17  	loss 0.88195, train acc 79.17, train corr acc 44.44, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 18  	loss 1.64519, train acc 68.75, train corr acc 34.78, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 19  	loss 1.53898, train acc 68.75, train corr acc 34.78, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 20  	loss 1.13112, train acc 72.92, train corr acc 38.10, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 21  	loss 1.16982, train acc 75.00, train corr acc 40.00, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 22  	loss 1.11453, train acc 77.08, train corr acc 42.11, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 23  	loss 0.96794, train acc 72.92, train corr acc 38.10, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 24  	loss 1.01158, train acc 72.92, train corr acc 40.91, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 25  	loss 1.06784, train acc 68.75, train corr acc 34.78, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 26  	loss 1.99570, train acc 54.17, train corr acc 26.67, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 27  	loss 1.84555, train acc 58.33, train corr acc 28.57, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 28  	loss 0.90949, train acc 77.08, train corr acc 42.11, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 29  	loss 1.31567, train acc 66.67, train corr acc 33.33, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 30  	loss 1.10456, train acc 72.92, train corr acc 38.10, val acc 70.88, val corr acc 35.84
# Ep 0 	iter 31  	loss 0.97289, train acc 70.83, train corr acc 36.36, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 32  	loss 1.23092, train acc 68.75, train corr acc 34.78, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 33  	loss 0.94587, train acc 70.83, train corr acc 33.33, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 34  	loss 1.17565, train acc 70.83, train corr acc 33.33, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 35  	loss 0.74602, train acc 77.08, train corr acc 38.89, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 36  	loss 1.01707, train acc 75.00, train corr acc 40.00, val acc 70.68, val corr acc 35.40
# Ep 0 	iter 37  	loss 0.49494, train acc 89.58, train corr acc 64.29, val acc 70.28, val corr acc 34.51
# Ep 0 	iter 38  	loss 1.02345, train acc 66.67, train corr acc 36.00, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 39  	loss 1.69261, train acc 60.42, train corr acc 29.63, val acc 70.88, val corr acc 35.84
# Ep 0 	iter 40  	loss 0.66541, train acc 81.25, train corr acc 43.75, val acc 70.68, val corr acc 35.40
# Ep 0 	iter 41  	loss 1.42396, train acc 68.75, train corr acc 37.50, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 42  	loss 0.90228, train acc 72.92, train corr acc 38.10, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 43  	loss 0.88446, train acc 70.83, train corr acc 36.36, val acc 70.88, val corr acc 36.28
# Ep 0 	iter 44  	loss 0.95770, train acc 70.83, train corr acc 30.00, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 45  	loss 1.02993, train acc 72.92, train corr acc 38.10, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 46  	loss 0.77223, train acc 81.25, train corr acc 50.00, val acc 71.89, val corr acc 38.05
# Ep 0 	iter 47  	loss 1.61479, train acc 68.75, train corr acc 37.50, val acc 70.88, val corr acc 35.84
# Ep 0 	iter 48  	loss 0.98819, train acc 70.83, train corr acc 30.00, val acc 70.68, val corr acc 35.84
# Ep 0 	iter 49  	loss 0.75873, train acc 72.92, train corr acc 40.00, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 50  	loss 1.10591, train acc 70.83, train corr acc 33.33, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 51  	loss 0.88305, train acc 79.17, train corr acc 50.00, val acc 71.08, val corr acc 36.73
# Ep 0 	iter 52  	loss 0.87133, train acc 72.92, train corr acc 31.58, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 53  	loss 0.92270, train acc 72.92, train corr acc 38.10, val acc 71.89, val corr acc 38.05
# Ep 0 	iter 54  	loss 1.42150, train acc 60.42, train corr acc 29.63, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 55  	loss 0.95953, train acc 77.08, train corr acc 45.00, val acc 70.68, val corr acc 35.40
# Ep 0 	iter 56  	loss 0.80921, train acc 77.08, train corr acc 42.11, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 57  	loss 1.14816, train acc 77.08, train corr acc 47.62, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 58  	loss 1.14575, train acc 68.75, train corr acc 34.78, val acc 71.49, val corr acc 37.17
# Ep 0 	iter 59  	loss 0.95830, train acc 72.92, train corr acc 40.91, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 60  	loss 0.97690, train acc 75.00, train corr acc 42.86, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 61  	loss 0.96691, train acc 66.67, train corr acc 30.43, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 62  	loss 0.92368, train acc 75.00, train corr acc 42.86, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 63  	loss 1.09601, train acc 72.92, train corr acc 43.48, val acc 70.68, val corr acc 35.40
# Ep 0 	iter 64  	loss 1.00438, train acc 72.92, train corr acc 31.58, val acc 71.29, val corr acc 36.73
# Ep 0 	iter 65  	loss 1.10147, train acc 66.67, train corr acc 36.00, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 66  	loss 1.52763, train acc 66.67, train corr acc 36.00, val acc 71.89, val corr acc 38.05
# Ep 0 	iter 67  	loss 0.92453, train acc 72.92, train corr acc 43.48, val acc 70.28, val corr acc 34.51
# Ep 0 	iter 68  	loss 0.74584, train acc 79.17, train corr acc 50.00, val acc 73.09, val corr acc 40.71
# Ep 0 	iter 69  	loss 0.96742, train acc 77.08, train corr acc 35.29, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 70  	loss 1.08012, train acc 64.58, train corr acc 26.09, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 71  	loss 1.08087, train acc 70.83, train corr acc 39.13, val acc 72.49, val corr acc 39.38
# Ep 0 	iter 72  	loss 1.20580, train acc 68.75, train corr acc 34.78, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 73  	loss 0.82794, train acc 79.17, train corr acc 50.00, val acc 72.49, val corr acc 39.38
# Ep 0 	iter 74  	loss 1.18271, train acc 64.58, train corr acc 32.00, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 75  	loss 0.87123, train acc 77.08, train corr acc 52.17, val acc 72.49, val corr acc 39.38
# Ep 0 	iter 76  	loss 0.65358, train acc 83.33, train corr acc 42.86, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 77  	loss 0.99874, train acc 72.92, train corr acc 43.48, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 78  	loss 1.09612, train acc 66.67, train corr acc 23.81, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 79  	loss 1.02355, train acc 70.83, train corr acc 39.13, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 80  	loss 1.18828, train acc 72.92, train corr acc 38.10, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 81  	loss 1.01492, train acc 79.17, train corr acc 47.37, val acc 72.49, val corr acc 39.38
# Ep 0 	iter 82  	loss 1.38231, train acc 60.42, train corr acc 32.14, val acc 73.09, val corr acc 40.71
# Ep 0 	iter 83  	loss 1.54529, train acc 62.50, train corr acc 33.33, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 84  	loss 0.97787, train acc 72.92, train corr acc 31.58, val acc 71.29, val corr acc 37.17
# Ep 0 	iter 85  	loss 0.85818, train acc 79.17, train corr acc 41.18, val acc 71.08, val corr acc 36.28
# Ep 0 	iter 86  	loss 1.11228, train acc 70.83, train corr acc 39.13, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 87  	loss 1.14782, train acc 68.75, train corr acc 34.78, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 88  	loss 1.09457, train acc 70.83, train corr acc 26.32, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 89  	loss 1.28160, train acc 66.67, train corr acc 23.81, val acc 73.09, val corr acc 40.71
# Ep 0 	iter 90  	loss 0.95171, train acc 77.08, train corr acc 50.00, val acc 71.89, val corr acc 38.05
# Ep 0 	iter 91  	loss 1.09184, train acc 70.83, train corr acc 44.00, val acc 73.29, val corr acc 41.15
# Ep 0 	iter 92  	loss 0.92401, train acc 75.00, train corr acc 45.45, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 93  	loss 1.40252, train acc 58.33, train corr acc 31.03, val acc 72.69, val corr acc 39.82
# Ep 0 	iter 94  	loss 0.90460, train acc 77.08, train corr acc 50.00, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 95  	loss 1.13016, train acc 68.75, train corr acc 40.00, val acc 72.29, val corr acc 38.94
# Ep 0 	iter 96  	loss 0.96832, train acc 72.92, train corr acc 35.00, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 97  	loss 0.82084, train acc 77.08, train corr acc 47.62, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 98  	loss 0.71502, train acc 77.08, train corr acc 42.11, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 99  	loss 1.02966, train acc 70.83, train corr acc 36.36, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 100  	loss 0.81368, train acc 81.25, train corr acc 50.00, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 101  	loss 1.15618, train acc 72.92, train corr acc 38.10, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 102  	loss 0.74637, train acc 72.92, train corr acc 31.58, val acc 73.09, val corr acc 40.71
# Ep 0 	iter 103  	loss 0.79260, train acc 77.08, train corr acc 45.00, val acc 71.69, val corr acc 37.61
# Ep 0 	iter 104  	loss 0.70393, train acc 79.17, train corr acc 44.44, val acc 73.09, val corr acc 40.71
# Ep 0 	iter 105  	loss 1.17212, train acc 62.50, train corr acc 33.33, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 106  	loss 1.17651, train acc 70.83, train corr acc 46.15, val acc 75.10, val corr acc 45.13
# Ep 0 	iter 107  	loss 1.17672, train acc 68.75, train corr acc 40.00, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 108  	loss 1.02173, train acc 68.75, train corr acc 31.82, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 109  	loss 0.67958, train acc 79.17, train corr acc 41.18, val acc 73.29, val corr acc 41.15
# Ep 0 	iter 110  	loss 0.86915, train acc 81.25, train corr acc 52.63, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 111  	loss 1.01485, train acc 75.00, train corr acc 47.83, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 112  	loss 0.73106, train acc 79.17, train corr acc 47.37, val acc 74.10, val corr acc 42.92
# Ep 0 	iter 113  	loss 0.84060, train acc 72.92, train corr acc 45.83, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 114  	loss 0.78006, train acc 75.00, train corr acc 33.33, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 115  	loss 0.95568, train acc 75.00, train corr acc 40.00, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 116  	loss 0.85820, train acc 79.17, train corr acc 44.44, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 117  	loss 0.94958, train acc 70.83, train corr acc 44.00, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 118  	loss 0.85427, train acc 72.92, train corr acc 45.83, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 119  	loss 1.05928, train acc 72.92, train corr acc 43.48, val acc 73.69, val corr acc 42.04
# Ep 0 	iter 120  	loss 1.01337, train acc 68.75, train corr acc 40.00, val acc 73.29, val corr acc 41.15
# Ep 0 	iter 121  	loss 0.91518, train acc 70.83, train corr acc 33.33, val acc 72.49, val corr acc 39.38
# Ep 0 	iter 122  	loss 0.91047, train acc 81.25, train corr acc 52.63, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 123  	loss 0.81220, train acc 83.33, train corr acc 57.89, val acc 74.30, val corr acc 43.36
# Ep 0 	iter 124  	loss 0.96828, train acc 68.75, train corr acc 37.50, val acc 72.89, val corr acc 40.27
# Ep 0 	iter 125  	loss 1.08301, train acc 72.92, train corr acc 48.00, val acc 72.09, val corr acc 38.50
# Ep 0 	iter 126  	loss 0.96239, train acc 70.83, train corr acc 41.67, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 127  	loss 0.92649, train acc 70.83, train corr acc 44.00, val acc 73.69, val corr acc 42.04
# Ep 0 	iter 128  	loss 1.05463, train acc 64.58, train corr acc 34.62, val acc 74.30, val corr acc 43.36
# Ep 0 	iter 129  	loss 0.88259, train acc 79.17, train corr acc 47.37, val acc 74.70, val corr acc 44.25
# Ep 0 	iter 130  	loss 0.85963, train acc 68.75, train corr acc 28.57, val acc 73.29, val corr acc 41.15
# Ep 0 	iter 131  	loss 0.90659, train acc 81.25, train corr acc 47.06, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 132  	loss 1.01081, train acc 66.67, train corr acc 27.27, val acc 74.70, val corr acc 44.25
# Ep 0 	iter 133  	loss 1.30747, train acc 64.58, train corr acc 34.62, val acc 74.30, val corr acc 43.36
# Ep 0 	iter 134  	loss 1.14147, train acc 77.08, train corr acc 50.00, val acc 74.90, val corr acc 44.69
# Ep 0 	iter 135  	loss 1.05808, train acc 70.83, train corr acc 46.15, val acc 73.90, val corr acc 42.48
# Ep 0 	iter 136  	loss 0.98479, train acc 77.08, train corr acc 54.17, val acc 74.10, val corr acc 42.92
# Ep 0 	iter 137  	loss 1.28876, train acc 66.67, train corr acc 36.00, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 138  	loss 0.84584, train acc 70.83, train corr acc 36.36, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 139  	loss 0.92254, train acc 75.00, train corr acc 40.00, val acc 74.10, val corr acc 42.92
# Ep 0 	iter 140  	loss 0.85596, train acc 70.83, train corr acc 41.67, val acc 73.49, val corr acc 41.59
# Ep 0 	iter 141  	loss 0.99222, train acc 64.58, train corr acc 26.09, val acc 74.50, val corr acc 43.81
# Ep 0 	iter 142  	loss 0.82990, train acc 77.08, train corr acc 45.00, val acc 73.69, val corr acc 42.04
# Ep 0 	iter 143  	loss 0.93890, train acc 70.83, train corr acc 26.32, val acc 74.90, val corr acc 44.69
# Ep 0 	iter 144  	loss 0.90832, train acc 68.75, train corr acc 31.82, val acc 73.69, val corr acc 42.04
#
# Epoch 1 of 1 took 34.757s
#   training loss:		0.918407
#   training raw accuracy:		74.68 %
#   training corrected acc:		44.08 %
#   validation loss:		0.910671
#   validation raw accuracy:		73.69 %
#   validation corrected acc:		42.04 %
#
# Training completed.
# Testing...
# [(23, 83), (33, 76), (39, 53), (17, 19), (3, 3), (0, 0)]
# [0.27710843373493976, 0.4342105263157895, 0.7358490566037735, 0.8947368421052632, 1.0, 0]
# Final results:
#   test loss:			0.944942
#   test raw accuracy:		76.10 %
#   test corrected accuracy:	49.15 %
#   test corrected accuracy time series
#   		 Timestep 0:	27.71 %
#   		 Timestep 1:	43.42 %
#   		 Timestep 2:	73.58 %
#   		 Timestep 3:	89.47 %
#   		 Timestep 4:	100.00 %
#   		 Timestep 5:	0.00 %
# ====================================================================================================
# Training and testing predict_next_ast rnn on Hour of Code problem #2
# Preparing network inputs and targets, and the ast maps...
# 220
# 2314
# Inputs and targets done!
# (2011, 7, 128)
# (2011, 7)
# (144, 7, 128)
# (144, 7)
# (144, 7, 128)
# (144, 7)
# Building network ...
# Computing updates ...
# Compiling functions ...
# Compiling done!
# Starting training...
# Total training iterations: 251
# Ep 0 	iter 1  	loss 5.39518, train acc 0.00, train corr acc 0.00, val acc 70.44, val corr acc 31.75
# Ep 0 	iter 2  	loss 5.31343, train acc 76.79, train corr acc 38.10, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 3  	loss 5.14720, train acc 69.64, train corr acc 34.62, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 4  	loss 4.83559, train acc 71.43, train corr acc 33.33, val acc 72.52, val corr acc 34.36
# Ep 0 	iter 5  	loss 4.37253, train acc 80.36, train corr acc 45.00, val acc 72.32, val corr acc 33.89
# Ep 0 	iter 6  	loss 3.60340, train acc 78.57, train corr acc 40.00, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 7  	loss 2.70093, train acc 71.43, train corr acc 33.33, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 8  	loss 1.91730, train acc 71.43, train corr acc 33.33, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 9  	loss 1.41760, train acc 75.00, train corr acc 36.36, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 10  	loss 1.29885, train acc 75.00, train corr acc 36.36, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 11  	loss 1.01025, train acc 76.79, train corr acc 38.10, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 12  	loss 1.87511, train acc 62.50, train corr acc 27.59, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 13  	loss 1.18888, train acc 71.43, train corr acc 33.33, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 14  	loss 1.29254, train acc 75.00, train corr acc 36.36, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 15  	loss 1.58098, train acc 75.00, train corr acc 36.36, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 16  	loss 1.63296, train acc 66.07, train corr acc 29.63, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 17  	loss 1.14633, train acc 71.43, train corr acc 33.33, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 18  	loss 0.73818, train acc 76.79, train corr acc 38.10, val acc 72.32, val corr acc 33.89
# Ep 0 	iter 19  	loss 0.92697, train acc 78.57, train corr acc 40.00, val acc 72.52, val corr acc 34.36
# Ep 0 	iter 20  	loss 1.35045, train acc 67.86, train corr acc 30.77, val acc 73.21, val corr acc 36.02
# Ep 0 	iter 21  	loss 0.91635, train acc 82.14, train corr acc 50.00, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 22  	loss 0.89868, train acc 73.21, train corr acc 37.50, val acc 72.52, val corr acc 34.36
# Ep 0 	iter 23  	loss 1.83139, train acc 66.07, train corr acc 26.92, val acc 72.82, val corr acc 35.07
# Ep 0 	iter 24  	loss 0.88373, train acc 75.00, train corr acc 30.00, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 25  	loss 1.12034, train acc 71.43, train corr acc 36.00, val acc 72.72, val corr acc 34.83
# Ep 0 	iter 26  	loss 1.09991, train acc 71.43, train corr acc 30.43, val acc 72.42, val corr acc 34.12
# Ep 0 	iter 27  	loss 0.64276, train acc 78.57, train corr acc 40.00, val acc 72.72, val corr acc 34.83
# Ep 0 	iter 28  	loss 1.39249, train acc 71.43, train corr acc 36.00, val acc 73.02, val corr acc 35.55
# Ep 0 	iter 29  	loss 0.89074, train acc 73.21, train corr acc 31.82, val acc 73.02, val corr acc 35.55
# Ep 0 	iter 30  	loss 0.81885, train acc 80.36, train corr acc 52.17, val acc 73.12, val corr acc 35.78
# Ep 0 	iter 31  	loss 1.34695, train acc 67.86, train corr acc 30.77, val acc 73.51, val corr acc 36.73
# Ep 0 	iter 32  	loss 0.95113, train acc 76.79, train corr acc 38.10, val acc 73.91, val corr acc 37.68
# Ep 0 	iter 33  	loss 0.85010, train acc 76.79, train corr acc 40.91, val acc 72.92, val corr acc 35.31
# Ep 0 	iter 34  	loss 1.38714, train acc 67.86, train corr acc 30.77, val acc 73.91, val corr acc 37.68
# Ep 0 	iter 35  	loss 1.13779, train acc 69.64, train corr acc 32.00, val acc 73.61, val corr acc 36.97
# Ep 0 	iter 36  	loss 1.20925, train acc 73.21, train corr acc 37.50, val acc 74.21, val corr acc 38.39
# Ep 0 	iter 37  	loss 1.05198, train acc 75.00, train corr acc 39.13, val acc 75.50, val corr acc 41.47
# Ep 0 	iter 38  	loss 0.89343, train acc 75.00, train corr acc 44.00, val acc 74.21, val corr acc 38.39
# Ep 0 	iter 39  	loss 0.92904, train acc 71.43, train corr acc 36.00, val acc 74.40, val corr acc 38.86
# Ep 0 	iter 40  	loss 0.75936, train acc 76.79, train corr acc 45.83, val acc 74.40, val corr acc 38.86
# Ep 0 	iter 41  	loss 1.02971, train acc 75.00, train corr acc 36.36, val acc 74.60, val corr acc 39.57
# Ep 0 	iter 42  	loss 0.43119, train acc 87.50, train corr acc 53.85, val acc 74.50, val corr acc 39.10
# Ep 0 	iter 43  	loss 1.06139, train acc 76.79, train corr acc 48.00, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 44  	loss 1.02883, train acc 75.00, train corr acc 33.33, val acc 73.91, val corr acc 37.68
# Ep 0 	iter 45  	loss 1.12903, train acc 67.86, train corr acc 28.00, val acc 74.01, val corr acc 37.91
# Ep 0 	iter 46  	loss 0.66814, train acc 78.57, train corr acc 42.86, val acc 74.31, val corr acc 38.63
# Ep 0 	iter 47  	loss 1.20828, train acc 71.43, train corr acc 33.33, val acc 74.21, val corr acc 38.39
# Ep 0 	iter 48  	loss 1.14949, train acc 73.21, train corr acc 37.50, val acc 74.31, val corr acc 38.63
# Ep 0 	iter 49  	loss 1.09908, train acc 67.86, train corr acc 30.77, val acc 74.80, val corr acc 39.81
# Ep 0 	iter 50  	loss 1.45687, train acc 67.86, train corr acc 33.33, val acc 75.50, val corr acc 41.47
# Ep 0 	iter 51  	loss 1.68067, train acc 64.29, train corr acc 25.93, val acc 75.10, val corr acc 40.52
# Ep 0 	iter 52  	loss 1.04892, train acc 85.71, train corr acc 63.64, val acc 74.70, val corr acc 40.05
# Ep 0 	iter 53  	loss 1.74089, train acc 69.64, train corr acc 39.29, val acc 74.70, val corr acc 40.05
# Ep 0 	iter 54  	loss 0.70202, train acc 83.93, train corr acc 52.63, val acc 74.21, val corr acc 39.10
# Ep 0 	iter 55  	loss 0.87772, train acc 76.79, train corr acc 42.86, val acc 75.10, val corr acc 41.00
# Ep 0 	iter 56  	loss 1.09619, train acc 75.00, train corr acc 39.13, val acc 75.60, val corr acc 41.94
# Ep 0 	iter 57  	loss 0.91560, train acc 76.79, train corr acc 38.10, val acc 76.19, val corr acc 43.13
# Ep 0 	iter 58  	loss 1.08298, train acc 75.00, train corr acc 30.00, val acc 75.10, val corr acc 40.52
# Ep 0 	iter 59  	loss 1.37413, train acc 69.64, train corr acc 29.17, val acc 73.91, val corr acc 37.68
# Ep 0 	iter 60  	loss 0.95923, train acc 76.79, train corr acc 43.48, val acc 74.50, val corr acc 39.10
# Ep 0 	iter 61  	loss 0.98202, train acc 73.21, train corr acc 34.78, val acc 73.51, val corr acc 36.73
# Ep 0 	iter 62  	loss 0.93196, train acc 73.21, train corr acc 37.50, val acc 73.02, val corr acc 35.55
# Ep 0 	iter 63  	loss 0.81784, train acc 82.14, train corr acc 50.00, val acc 74.11, val corr acc 38.15
# Ep 0 	iter 64  	loss 0.74768, train acc 80.36, train corr acc 47.62, val acc 73.31, val corr acc 36.26
# Ep 0 	iter 65  	loss 0.75817, train acc 73.21, train corr acc 34.78, val acc 72.92, val corr acc 35.31
# Ep 0 	iter 66  	loss 1.13209, train acc 73.21, train corr acc 37.50, val acc 74.31, val corr acc 38.63
# Ep 0 	iter 67  	loss 0.98110, train acc 75.00, train corr acc 36.36, val acc 73.71, val corr acc 37.20
# Ep 0 	iter 68  	loss 1.11868, train acc 76.79, train corr acc 45.83, val acc 74.01, val corr acc 37.91
# Ep 0 	iter 69  	loss 1.21882, train acc 69.64, train corr acc 32.00, val acc 74.21, val corr acc 38.39
# Ep 0 	iter 70  	loss 0.85512, train acc 75.00, train corr acc 39.13, val acc 74.21, val corr acc 38.39
# Ep 0 	iter 71  	loss 1.04619, train acc 66.07, train corr acc 32.14, val acc 74.50, val corr acc 39.10
# Ep 0 	iter 72  	loss 1.00188, train acc 66.07, train corr acc 24.00, val acc 74.21, val corr acc 38.86
# Ep 0 	iter 73  	loss 0.76766, train acc 78.57, train corr acc 33.33, val acc 74.40, val corr acc 39.10
# Ep 0 	iter 74  	loss 0.87836, train acc 76.79, train corr acc 40.91, val acc 74.50, val corr acc 39.57
# Ep 0 	iter 75  	loss 0.93274, train acc 71.43, train corr acc 37.50, val acc 74.40, val corr acc 38.86
# Ep 0 	iter 76  	loss 1.60341, train acc 60.71, train corr acc 29.03, val acc 74.50, val corr acc 39.10
# Ep 0 	iter 77  	loss 0.96414, train acc 73.21, train corr acc 31.82, val acc 74.11, val corr acc 38.15
# Ep 0 	iter 78  	loss 0.75682, train acc 80.36, train corr acc 47.62, val acc 74.60, val corr acc 39.57
# Ep 0 	iter 79  	loss 0.92356, train acc 75.00, train corr acc 44.00, val acc 75.40, val corr acc 41.23
# Ep 0 	iter 80  	loss 0.70370, train acc 78.57, train corr acc 40.00, val acc 75.10, val corr acc 40.52
# Ep 0 	iter 81  	loss 0.94940, train acc 78.57, train corr acc 53.85, val acc 75.30, val corr acc 41.00
# Ep 0 	iter 82  	loss 0.85624, train acc 82.14, train corr acc 54.55, val acc 74.50, val corr acc 39.10
# Ep 0 	iter 83  	loss 0.84287, train acc 71.43, train corr acc 27.27, val acc 74.80, val corr acc 39.81
# Ep 0 	iter 84  	loss 1.12564, train acc 76.79, train corr acc 43.48, val acc 74.90, val corr acc 40.05
# Ep 0 	iter 85  	loss 0.80957, train acc 78.57, train corr acc 47.83, val acc 73.91, val corr acc 37.68
# Ep 0 	iter 86  	loss 1.31500, train acc 69.64, train corr acc 37.04, val acc 74.01, val corr acc 37.91
# Ep 0 	iter 87  	loss 1.21261, train acc 69.64, train corr acc 29.17, val acc 74.90, val corr acc 40.05
# Ep 0 	iter 88  	loss 0.92025, train acc 78.57, train corr acc 47.83, val acc 73.91, val corr acc 37.68
# Ep 0 	iter 89  	loss 0.76709, train acc 82.14, train corr acc 47.37, val acc 75.40, val corr acc 41.23
# Ep 0 	iter 90  	loss 0.87915, train acc 78.57, train corr acc 47.83, val acc 75.40, val corr acc 41.23
# Ep 0 	iter 91  	loss 0.83997, train acc 83.93, train corr acc 55.00, val acc 75.50, val corr acc 41.47
# Ep 0 	iter 92  	loss 0.60667, train acc 89.29, train corr acc 62.50, val acc 75.60, val corr acc 41.71
# Ep 0 	iter 93  	loss 0.95990, train acc 73.21, train corr acc 40.00, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 94  	loss 0.94810, train acc 71.43, train corr acc 33.33, val acc 74.90, val corr acc 40.05
# Ep 0 	iter 95  	loss 1.00393, train acc 71.43, train corr acc 33.33, val acc 75.00, val corr acc 40.28
# Ep 0 	iter 96  	loss 0.71000, train acc 80.36, train corr acc 38.89, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 97  	loss 0.78947, train acc 78.57, train corr acc 40.00, val acc 74.90, val corr acc 40.05
# Ep 0 	iter 98  	loss 1.07637, train acc 64.29, train corr acc 25.93, val acc 74.70, val corr acc 39.57
# Ep 0 	iter 99  	loss 0.79486, train acc 75.00, train corr acc 39.13, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 100  	loss 1.16097, train acc 69.64, train corr acc 34.62, val acc 75.30, val corr acc 41.00
# Ep 0 	iter 101  	loss 1.04384, train acc 73.21, train corr acc 40.00, val acc 75.30, val corr acc 41.00
# Ep 0 	iter 102  	loss 1.01749, train acc 67.86, train corr acc 28.00, val acc 76.39, val corr acc 43.60
# Ep 0 	iter 103  	loss 1.02214, train acc 73.21, train corr acc 37.50, val acc 75.89, val corr acc 42.42
# Ep 0 	iter 104  	loss 0.86311, train acc 82.14, train corr acc 56.52, val acc 75.79, val corr acc 42.18
# Ep 0 	iter 105  	loss 1.07209, train acc 75.00, train corr acc 36.36, val acc 75.69, val corr acc 41.94
# Ep 0 	iter 106  	loss 0.91957, train acc 75.00, train corr acc 36.36, val acc 75.69, val corr acc 41.94
# Ep 0 	iter 107  	loss 1.06044, train acc 73.21, train corr acc 42.31, val acc 76.29, val corr acc 43.36
# Ep 0 	iter 108  	loss 0.70184, train acc 83.93, train corr acc 47.06, val acc 76.39, val corr acc 43.60
# Ep 0 	iter 109  	loss 0.96821, train acc 69.64, train corr acc 39.29, val acc 75.69, val corr acc 41.94
# Ep 0 	iter 110  	loss 0.89328, train acc 80.36, train corr acc 56.00, val acc 76.09, val corr acc 42.89
# Ep 0 	iter 111  	loss 0.97607, train acc 71.43, train corr acc 38.46, val acc 76.19, val corr acc 43.13
# Ep 0 	iter 112  	loss 0.81975, train acc 78.57, train corr acc 47.83, val acc 75.89, val corr acc 42.42
# Ep 0 	iter 113  	loss 1.07057, train acc 78.57, train corr acc 52.00, val acc 75.50, val corr acc 41.47
# Ep 0 	iter 114  	loss 0.74699, train acc 82.14, train corr acc 50.00, val acc 75.79, val corr acc 42.18
# Ep 0 	iter 115  	loss 1.02267, train acc 73.21, train corr acc 34.78, val acc 75.79, val corr acc 42.18
# Ep 0 	iter 116  	loss 1.15626, train acc 75.00, train corr acc 41.67, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 117  	loss 0.69013, train acc 82.14, train corr acc 50.00, val acc 75.60, val corr acc 41.71
# Ep 0 	iter 118  	loss 1.22991, train acc 67.86, train corr acc 33.33, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 119  	loss 0.90202, train acc 75.00, train corr acc 44.00, val acc 75.40, val corr acc 41.23
# Ep 0 	iter 120  	loss 1.27164, train acc 69.64, train corr acc 39.29, val acc 76.09, val corr acc 42.89
# Ep 0 	iter 121  	loss 0.70112, train acc 82.14, train corr acc 47.37, val acc 76.09, val corr acc 42.89
# Ep 0 	iter 122  	loss 0.87951, train acc 78.57, train corr acc 45.45, val acc 75.69, val corr acc 41.94
# Ep 0 	iter 123  	loss 0.82773, train acc 76.79, train corr acc 40.91, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 124  	loss 0.58047, train acc 83.93, train corr acc 57.14, val acc 76.49, val corr acc 43.84
# Ep 0 	iter 125  	loss 0.82685, train acc 82.14, train corr acc 58.33, val acc 76.49, val corr acc 43.84
# Ep 0 	iter 126  	loss 1.05533, train acc 80.36, train corr acc 56.00, val acc 76.79, val corr acc 44.55
# Ep 0 	iter 127  	loss 0.93658, train acc 75.00, train corr acc 48.15, val acc 76.19, val corr acc 43.13
# Ep 0 	iter 128  	loss 0.98924, train acc 73.21, train corr acc 46.43, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 129  	loss 0.97398, train acc 76.79, train corr acc 45.83, val acc 75.30, val corr acc 41.00
# Ep 0 	iter 130  	loss 0.71698, train acc 80.36, train corr acc 47.62, val acc 75.60, val corr acc 41.71
# Ep 0 	iter 131  	loss 0.76426, train acc 76.79, train corr acc 43.48, val acc 75.20, val corr acc 40.76
# Ep 0 	iter 132  	loss 1.01481, train acc 76.79, train corr acc 45.83, val acc 75.69, val corr acc 41.94
# Ep 0 	iter 133  	loss 0.78637, train acc 82.14, train corr acc 60.00, val acc 75.60, val corr acc 41.71
# Ep 0 	iter 134  	loss 0.69871, train acc 80.36, train corr acc 52.17, val acc 76.09, val corr acc 42.89
# Ep 0 	iter 135  	loss 1.01863, train acc 73.21, train corr acc 34.78, val acc 75.99, val corr acc 42.65
# Ep 0 	iter 136  	loss 0.82788, train acc 76.79, train corr acc 45.83, val acc 77.38, val corr acc 45.97
# Ep 0 	iter 137  	loss 1.04183, train acc 73.21, train corr acc 46.43, val acc 76.49, val corr acc 43.84
# Ep 0 	iter 138  	loss 0.78170, train acc 75.00, train corr acc 44.00, val acc 76.79, val corr acc 44.55
# Ep 0 	iter 139  	loss 0.55843, train acc 87.50, train corr acc 66.67, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 140  	loss 0.98004, train acc 67.86, train corr acc 35.71, val acc 76.59, val corr acc 44.08
# Ep 0 	iter 141  	loss 0.76918, train acc 78.57, train corr acc 47.83, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 142  	loss 1.13142, train acc 73.21, train corr acc 42.31, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 143  	loss 1.25334, train acc 69.64, train corr acc 37.04, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 144  	loss 1.03258, train acc 73.21, train corr acc 40.00, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 145  	loss 0.94165, train acc 75.00, train corr acc 39.13, val acc 77.28, val corr acc 45.73
# Ep 0 	iter 146  	loss 0.89193, train acc 82.14, train corr acc 54.55, val acc 76.39, val corr acc 43.60
# Ep 0 	iter 147  	loss 1.03760, train acc 76.79, train corr acc 45.83, val acc 76.29, val corr acc 43.36
# Ep 0 	iter 148  	loss 0.84883, train acc 73.21, train corr acc 40.00, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 149  	loss 1.00468, train acc 73.21, train corr acc 34.78, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 150  	loss 1.20172, train acc 67.86, train corr acc 33.33, val acc 76.39, val corr acc 43.60
# Ep 0 	iter 151  	loss 0.98225, train acc 73.21, train corr acc 40.00, val acc 76.19, val corr acc 43.13
# Ep 0 	iter 152  	loss 1.10018, train acc 75.00, train corr acc 46.15, val acc 75.99, val corr acc 42.65
# Ep 0 	iter 153  	loss 0.98331, train acc 80.36, train corr acc 54.17, val acc 77.88, val corr acc 47.16
# Ep 0 	iter 154  	loss 0.94743, train acc 78.57, train corr acc 52.00, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 155  	loss 0.97124, train acc 75.00, train corr acc 41.67, val acc 77.68, val corr acc 46.68
# Ep 0 	iter 156  	loss 1.33302, train acc 71.43, train corr acc 44.83, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 157  	loss 0.95587, train acc 76.79, train corr acc 50.00, val acc 77.98, val corr acc 47.39
# Ep 0 	iter 158  	loss 0.86646, train acc 75.00, train corr acc 39.13, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 159  	loss 0.99933, train acc 69.64, train corr acc 34.62, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 160  	loss 0.58436, train acc 87.50, train corr acc 66.67, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 161  	loss 0.87428, train acc 80.36, train corr acc 57.69, val acc 76.98, val corr acc 45.02
# Ep 0 	iter 162  	loss 1.00860, train acc 73.21, train corr acc 31.82, val acc 76.49, val corr acc 43.84
# Ep 0 	iter 163  	loss 0.70156, train acc 78.57, train corr acc 47.83, val acc 76.98, val corr acc 45.02
# Ep 0 	iter 164  	loss 1.01061, train acc 71.43, train corr acc 40.74, val acc 76.59, val corr acc 44.08
# Ep 0 	iter 165  	loss 1.20725, train acc 71.43, train corr acc 33.33, val acc 76.29, val corr acc 43.36
# Ep 0 	iter 166  	loss 0.86332, train acc 80.36, train corr acc 47.62, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 167  	loss 0.61928, train acc 80.36, train corr acc 50.00, val acc 76.09, val corr acc 42.89
# Ep 0 	iter 168  	loss 0.92531, train acc 76.79, train corr acc 45.83, val acc 76.39, val corr acc 43.60
# Ep 0 	iter 169  	loss 0.70448, train acc 82.14, train corr acc 54.55, val acc 76.79, val corr acc 44.55
# Ep 0 	iter 170  	loss 0.68136, train acc 83.93, train corr acc 57.14, val acc 76.98, val corr acc 45.02
# Ep 0 	iter 171  	loss 1.25742, train acc 67.86, train corr acc 37.93, val acc 76.79, val corr acc 44.55
# Ep 0 	iter 172  	loss 0.69478, train acc 78.57, train corr acc 45.45, val acc 75.50, val corr acc 41.47
# Ep 0 	iter 173  	loss 1.01316, train acc 73.21, train corr acc 44.44, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 174  	loss 0.79681, train acc 76.79, train corr acc 45.83, val acc 77.28, val corr acc 45.73
# Ep 0 	iter 175  	loss 0.79747, train acc 82.14, train corr acc 54.55, val acc 77.88, val corr acc 47.16
# Ep 0 	iter 176  	loss 0.95512, train acc 78.57, train corr acc 57.14, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 177  	loss 1.14438, train acc 71.43, train corr acc 36.00, val acc 76.79, val corr acc 44.55
# Ep 0 	iter 178  	loss 0.72752, train acc 80.36, train corr acc 47.62, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 179  	loss 1.06110, train acc 67.86, train corr acc 33.33, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 180  	loss 0.86685, train acc 82.14, train corr acc 54.55, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 181  	loss 0.89445, train acc 80.36, train corr acc 54.17, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 182  	loss 0.85241, train acc 76.79, train corr acc 48.00, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 183  	loss 0.80205, train acc 78.57, train corr acc 36.84, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 184  	loss 0.84740, train acc 82.14, train corr acc 56.52, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 185  	loss 1.23468, train acc 75.00, train corr acc 48.15, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 186  	loss 0.81135, train acc 82.14, train corr acc 56.52, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 187  	loss 0.66070, train acc 82.14, train corr acc 56.52, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 188  	loss 0.85126, train acc 80.36, train corr acc 50.00, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 189  	loss 0.91387, train acc 80.36, train corr acc 59.26, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 190  	loss 0.78106, train acc 78.57, train corr acc 33.33, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 191  	loss 0.87379, train acc 80.36, train corr acc 52.17, val acc 77.28, val corr acc 45.73
# Ep 0 	iter 192  	loss 0.76848, train acc 82.14, train corr acc 54.55, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 193  	loss 0.95753, train acc 75.00, train corr acc 36.36, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 194  	loss 0.74681, train acc 78.57, train corr acc 47.83, val acc 76.29, val corr acc 43.36
# Ep 0 	iter 195  	loss 1.12041, train acc 78.57, train corr acc 53.85, val acc 76.79, val corr acc 44.55
# Ep 0 	iter 196  	loss 0.90017, train acc 75.00, train corr acc 44.00, val acc 77.68, val corr acc 46.68
# Ep 0 	iter 197  	loss 1.01889, train acc 76.79, train corr acc 48.00, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 198  	loss 0.93826, train acc 73.21, train corr acc 48.28, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 199  	loss 0.61722, train acc 85.71, train corr acc 46.67, val acc 77.38, val corr acc 45.97
# Ep 0 	iter 200  	loss 1.17486, train acc 73.21, train corr acc 37.50, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 201  	loss 0.85866, train acc 78.57, train corr acc 47.83, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 202  	loss 1.02756, train acc 75.00, train corr acc 39.13, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 203  	loss 0.99689, train acc 69.64, train corr acc 45.16, val acc 77.78, val corr acc 46.92
# Ep 0 	iter 204  	loss 0.68986, train acc 83.93, train corr acc 57.14, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 205  	loss 1.14447, train acc 76.79, train corr acc 45.83, val acc 78.08, val corr acc 47.63
# Ep 0 	iter 206  	loss 0.76372, train acc 80.36, train corr acc 50.00, val acc 78.57, val corr acc 48.82
# Ep 0 	iter 207  	loss 0.89453, train acc 80.36, train corr acc 54.17, val acc 77.98, val corr acc 47.39
# Ep 0 	iter 208  	loss 0.96198, train acc 83.93, train corr acc 59.09, val acc 77.68, val corr acc 46.68
# Ep 0 	iter 209  	loss 0.93053, train acc 80.36, train corr acc 56.00, val acc 77.38, val corr acc 45.97
# Ep 0 	iter 210  	loss 1.00719, train acc 73.21, train corr acc 40.00, val acc 76.98, val corr acc 45.02
# Ep 0 	iter 211  	loss 0.87333, train acc 75.00, train corr acc 41.67, val acc 77.38, val corr acc 45.97
# Ep 0 	iter 212  	loss 1.09859, train acc 80.36, train corr acc 56.00, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 213  	loss 0.98494, train acc 67.86, train corr acc 41.94, val acc 77.08, val corr acc 45.26
# Ep 0 	iter 214  	loss 1.02077, train acc 71.43, train corr acc 42.86, val acc 76.88, val corr acc 44.79
# Ep 0 	iter 215  	loss 0.92041, train acc 76.79, train corr acc 45.83, val acc 77.38, val corr acc 45.97
# Ep 0 	iter 216  	loss 0.80103, train acc 76.79, train corr acc 31.58, val acc 77.78, val corr acc 46.92
# Ep 0 	iter 217  	loss 0.89432, train acc 76.79, train corr acc 35.00, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 218  	loss 0.94817, train acc 80.36, train corr acc 54.17, val acc 76.69, val corr acc 44.31
# Ep 0 	iter 219  	loss 0.91786, train acc 73.21, train corr acc 37.50, val acc 76.98, val corr acc 45.02
# Ep 0 	iter 220  	loss 0.81177, train acc 76.79, train corr acc 50.00, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 221  	loss 0.72823, train acc 78.57, train corr acc 36.84, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 222  	loss 0.84647, train acc 82.14, train corr acc 56.52, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 223  	loss 0.91054, train acc 78.57, train corr acc 53.85, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 224  	loss 1.12150, train acc 78.57, train corr acc 52.00, val acc 77.18, val corr acc 45.50
# Ep 0 	iter 225  	loss 0.97290, train acc 78.57, train corr acc 52.00, val acc 78.17, val corr acc 47.87
# Ep 0 	iter 226  	loss 0.96778, train acc 73.21, train corr acc 40.00, val acc 78.08, val corr acc 47.63
# Ep 0 	iter 227  	loss 0.62853, train acc 83.93, train corr acc 52.63, val acc 78.27, val corr acc 48.10
# Ep 0 	iter 228  	loss 1.42514, train acc 64.29, train corr acc 28.57, val acc 77.98, val corr acc 47.39
# Ep 0 	iter 229  	loss 1.15872, train acc 71.43, train corr acc 38.46, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 230  	loss 0.92266, train acc 75.00, train corr acc 36.36, val acc 78.08, val corr acc 47.63
# Ep 0 	iter 231  	loss 0.83314, train acc 80.36, train corr acc 54.17, val acc 77.88, val corr acc 47.16
# Ep 0 	iter 232  	loss 1.14088, train acc 71.43, train corr acc 48.39, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 233  	loss 0.88086, train acc 82.14, train corr acc 58.33, val acc 77.78, val corr acc 46.92
# Ep 0 	iter 234  	loss 0.82236, train acc 80.36, train corr acc 56.00, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 235  	loss 0.65269, train acc 82.14, train corr acc 54.55, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 236  	loss 0.89203, train acc 76.79, train corr acc 48.00, val acc 77.68, val corr acc 46.68
# Ep 0 	iter 237  	loss 0.85967, train acc 83.93, train corr acc 60.87, val acc 77.58, val corr acc 46.45
# Ep 0 	iter 238  	loss 0.92447, train acc 76.79, train corr acc 43.48, val acc 78.08, val corr acc 47.63
# Ep 0 	iter 239  	loss 1.09046, train acc 75.00, train corr acc 44.00, val acc 77.98, val corr acc 47.39
# Ep 0 	iter 240  	loss 0.79429, train acc 80.36, train corr acc 52.17, val acc 77.98, val corr acc 47.39
# Ep 0 	iter 241  	loss 1.02577, train acc 73.21, train corr acc 44.44, val acc 78.08, val corr acc 47.63
# Ep 0 	iter 242  	loss 1.40354, train acc 66.07, train corr acc 40.62, val acc 78.37, val corr acc 48.34
# Ep 0 	iter 243  	loss 0.89810, train acc 80.36, train corr acc 38.89, val acc 79.37, val corr acc 50.71
# Ep 0 	iter 244  	loss 0.88240, train acc 76.79, train corr acc 51.85, val acc 78.77, val corr acc 49.29
# Ep 0 	iter 245  	loss 1.01599, train acc 78.57, train corr acc 53.85, val acc 79.76, val corr acc 51.66
# Ep 0 	iter 246  	loss 0.79281, train acc 80.36, train corr acc 54.17, val acc 77.98, val corr acc 47.39
# Ep 0 	iter 247  	loss 1.30568, train acc 73.21, train corr acc 48.28, val acc 78.57, val corr acc 48.82
# Ep 0 	iter 248  	loss 0.88418, train acc 82.14, train corr acc 60.00, val acc 78.08, val corr acc 47.63
# Ep 0 	iter 249  	loss 0.71160, train acc 80.36, train corr acc 50.00, val acc 77.38, val corr acc 45.97
# Ep 0 	iter 250  	loss 1.02017, train acc 80.36, train corr acc 52.17, val acc 77.48, val corr acc 46.21
# Ep 0 	iter 251  	loss 0.54271, train acc 87.50, train corr acc 61.11, val acc 77.08, val corr acc 45.26
#
# Epoch 1 of 1 took 83.353s
#   training loss:		0.867758
#   training raw accuracy:		76.76 %
#   training corrected acc:		45.01 %
#   validation loss:		0.894932
#   validation raw accuracy:		77.08 %
#   validation corrected acc:		45.26 %
#
# Training completed.
# Testing...
# [(31, 144), (61, 135), (68, 95), (30, 36), (8, 8), (0, 0), (0, 0)]
# [0.2152777777777778, 0.45185185185185184, 0.7157894736842105, 0.8333333333333334, 1.0, 0, 0]
# Final results:
#   test loss:			0.871056
#   test raw accuracy:		78.17 %
#   test corrected accuracy:	47.37 %
#   test corrected accuracy time series
#   		 Timestep 0:	21.53 %
#   		 Timestep 1:	45.19 %
#   		 Timestep 2:	71.58 %
#   		 Timestep 3:	83.33 %
#   		 Timestep 4:	100.00 %
#   		 Timestep 5:	0.00 %
#   		 Timestep 6:	0.00 %
# ====================================================================================================
# Training and testing predict_next_ast rnn on Hour of Code problem #3
# Preparing network inputs and targets, and the ast maps...
# 218
# 3899
# Inputs and targets done!
# (3881, 6, 128)
# (3881, 6)
# (277, 6, 128)
# (277, 6)
# (278, 6, 128)
# (278, 6)
# Building network ...
# Computing updates ...
# Compiling functions ...
# Compiling done!
# Starting training...
# Total training iterations: 485
# Ep 0 	iter 1  	loss 5.38563, train acc 0.00, train corr acc 0.00, val acc 58.12, val corr acc 31.08
# Ep 0 	iter 2  	loss 5.30545, train acc 62.50, train corr acc 37.93, val acc 57.16, val corr acc 29.38
# Ep 0 	iter 3  	loss 5.16806, train acc 58.33, train corr acc 28.57, val acc 56.74, val corr acc 28.49
# Ep 0 	iter 4  	loss 4.91718, train acc 64.58, train corr acc 34.62, val acc 56.86, val corr acc 28.59
# Ep 0 	iter 5  	loss 4.42232, train acc 62.50, train corr acc 33.33, val acc 57.22, val corr acc 29.28
# Ep 0 	iter 6  	loss 3.85397, train acc 45.83, train corr acc 23.53, val acc 56.56, val corr acc 28.29
# Ep 0 	iter 7  	loss 3.08746, train acc 58.33, train corr acc 31.03, val acc 57.04, val corr acc 28.98
# Ep 0 	iter 8  	loss 2.66114, train acc 52.08, train corr acc 23.33, val acc 56.38, val corr acc 27.89
# Ep 0 	iter 9  	loss 1.87311, train acc 58.33, train corr acc 28.57, val acc 56.20, val corr acc 27.59
# Ep 0 	iter 10  	loss 1.76046, train acc 58.33, train corr acc 28.57, val acc 56.20, val corr acc 27.59
# Ep 0 	iter 11  	loss 1.35747, train acc 64.58, train corr acc 32.00, val acc 56.08, val corr acc 27.39
# Ep 0 	iter 12  	loss 2.13734, train acc 58.33, train corr acc 28.57, val acc 56.08, val corr acc 27.39
# Ep 0 	iter 13  	loss 1.86252, train acc 56.25, train corr acc 27.59, val acc 56.08, val corr acc 27.39
# Ep 0 	iter 14  	loss 2.65266, train acc 41.67, train corr acc 22.22, val acc 55.96, val corr acc 27.19
# Ep 0 	iter 15  	loss 2.12647, train acc 52.08, train corr acc 25.81, val acc 56.20, val corr acc 27.69
# Ep 0 	iter 16  	loss 2.23809, train acc 47.92, train corr acc 24.24, val acc 57.40, val corr acc 30.38
# Ep 0 	iter 17  	loss 2.53043, train acc 45.83, train corr acc 23.53, val acc 58.00, val corr acc 32.47
# Ep 0 	iter 18  	loss 2.13110, train acc 43.75, train corr acc 27.03, val acc 55.35, val corr acc 30.88
# Ep 0 	iter 19  	loss 1.45997, train acc 64.58, train corr acc 33.33, val acc 59.51, val corr acc 33.96
# Ep 0 	iter 20  	loss 1.67026, train acc 60.42, train corr acc 29.63, val acc 59.03, val corr acc 32.57
# Ep 0 	iter 21  	loss 1.83549, train acc 64.58, train corr acc 32.00, val acc 58.60, val corr acc 31.57
# Ep 0 	iter 22  	loss 1.48411, train acc 68.75, train corr acc 40.00, val acc 57.70, val corr acc 30.08
# Ep 0 	iter 23  	loss 1.62288, train acc 50.00, train corr acc 27.27, val acc 57.58, val corr acc 29.88
# Ep 0 	iter 24  	loss 1.72603, train acc 60.42, train corr acc 32.14, val acc 58.06, val corr acc 30.68
# Ep 0 	iter 25  	loss 1.28827, train acc 62.50, train corr acc 33.33, val acc 57.28, val corr acc 29.38
# Ep 0 	iter 26  	loss 1.43821, train acc 58.33, train corr acc 33.33, val acc 57.46, val corr acc 29.68
# Ep 0 	iter 27  	loss 1.46233, train acc 56.25, train corr acc 27.59, val acc 57.94, val corr acc 30.38
# Ep 0 	iter 28  	loss 1.69327, train acc 56.25, train corr acc 30.00, val acc 58.30, val corr acc 31.18
# Ep 0 	iter 29  	loss 1.85156, train acc 47.92, train corr acc 26.47, val acc 59.21, val corr acc 32.77
# Ep 0 	iter 30  	loss 1.32188, train acc 58.33, train corr acc 33.33, val acc 59.63, val corr acc 33.47
# Ep 0 	iter 31  	loss 1.62506, train acc 50.00, train corr acc 17.24, val acc 60.35, val corr acc 34.66
# Ep 0 	iter 32  	loss 1.58447, train acc 60.42, train corr acc 36.67, val acc 60.65, val corr acc 35.36
# Ep 0 	iter 33  	loss 2.10127, train acc 54.17, train corr acc 29.03, val acc 60.71, val corr acc 35.56
# Ep 0 	iter 34  	loss 1.03603, train acc 68.75, train corr acc 37.50, val acc 60.17, val corr acc 34.56
# Ep 0 	iter 35  	loss 1.22183, train acc 66.67, train corr acc 40.74, val acc 60.71, val corr acc 35.36
# Ep 0 	iter 36  	loss 1.57595, train acc 60.42, train corr acc 29.63, val acc 60.71, val corr acc 35.36
# Ep 0 	iter 37  	loss 1.64767, train acc 56.25, train corr acc 34.38, val acc 60.47, val corr acc 35.06
# Ep 0 	iter 38  	loss 1.67107, train acc 50.00, train corr acc 27.27, val acc 61.13, val corr acc 36.06
# Ep 0 	iter 39  	loss 0.89513, train acc 83.33, train corr acc 63.16, val acc 61.01, val corr acc 35.86
# Ep 0 	iter 40  	loss 1.62611, train acc 54.17, train corr acc 29.03, val acc 61.07, val corr acc 36.16
# Ep 0 	iter 41  	loss 1.50223, train acc 60.42, train corr acc 36.67, val acc 61.25, val corr acc 36.75
# Ep 0 	iter 42  	loss 1.46044, train acc 52.08, train corr acc 18.52, val acc 61.25, val corr acc 37.25
# ...
# Ep 0 	iter 555  	loss 1.86127, train acc 62.50, train corr acc 44.44, val acc 67.25, val corr acc 41.31
# Ep 0 	iter 556  	loss 1.20859, train acc 67.50, train corr acc 38.10, val acc 67.30, val corr acc 41.40
# Ep 0 	iter 557  	loss 1.55727, train acc 60.00, train corr acc 40.74, val acc 67.30, val corr acc 41.40
# Ep 0 	iter 558  	loss 1.64311, train acc 60.00, train corr acc 40.74, val acc 67.00, val corr acc 40.86
# Ep 0 	iter 559  	loss 1.64907, train acc 60.00, train corr acc 36.00, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 560  	loss 1.60098, train acc 67.50, train corr acc 31.58, val acc 68.15, val corr acc 42.92
# Ep 0 	iter 561  	loss 1.66324, train acc 67.50, train corr acc 43.48, val acc 67.20, val corr acc 41.22
# Ep 0 	iter 562  	loss 1.34335, train acc 72.50, train corr acc 45.00, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 563  	loss 1.54322, train acc 57.50, train corr acc 32.00, val acc 66.80, val corr acc 40.50
# Ep 0 	iter 564  	loss 1.48033, train acc 67.50, train corr acc 45.83, val acc 67.30, val corr acc 41.40
# Ep 0 	iter 565  	loss 1.26407, train acc 72.50, train corr acc 50.00, val acc 67.40, val corr acc 41.58
# Ep 0 	iter 566  	loss 1.54820, train acc 65.00, train corr acc 41.67, val acc 67.25, val corr acc 41.31
# Ep 0 	iter 567  	loss 1.31357, train acc 77.50, train corr acc 52.63, val acc 66.75, val corr acc 40.41
# Ep 0 	iter 568  	loss 1.28354, train acc 70.00, train corr acc 50.00, val acc 66.90, val corr acc 40.68
# Ep 0 	iter 569  	loss 1.75736, train acc 65.00, train corr acc 36.36, val acc 67.30, val corr acc 41.40
# Ep 0 	iter 570  	loss 1.51296, train acc 60.00, train corr acc 38.46, val acc 67.50, val corr acc 41.76
# Ep 0 	iter 571  	loss 1.28812, train acc 65.00, train corr acc 30.00, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 572  	loss 1.04758, train acc 80.00, train corr acc 55.56, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 573  	loss 1.71016, train acc 65.00, train corr acc 36.36, val acc 67.85, val corr acc 42.38
# Ep 0 	iter 574  	loss 2.10216, train acc 50.00, train corr acc 31.03, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 575  	loss 1.70712, train acc 60.00, train corr acc 33.33, val acc 67.75, val corr acc 42.20
# Ep 0 	iter 576  	loss 2.11745, train acc 57.50, train corr acc 34.62, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 577  	loss 1.67848, train acc 62.50, train corr acc 42.31, val acc 67.35, val corr acc 41.49
# Ep 0 	iter 578  	loss 1.23953, train acc 65.00, train corr acc 36.36, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 579  	loss 1.37808, train acc 62.50, train corr acc 34.78, val acc 68.25, val corr acc 43.10
# Ep 0 	iter 580  	loss 1.59550, train acc 62.50, train corr acc 44.44, val acc 68.55, val corr acc 43.64
# Ep 0 	iter 581  	loss 1.37263, train acc 67.50, train corr acc 43.48, val acc 68.85, val corr acc 44.18
# Ep 0 	iter 582  	loss 1.56233, train acc 50.00, train corr acc 31.03, val acc 68.15, val corr acc 42.92
# Ep 0 	iter 583  	loss 1.47162, train acc 67.50, train corr acc 45.83, val acc 68.70, val corr acc 43.91
# Ep 0 	iter 584  	loss 1.28219, train acc 70.00, train corr acc 47.83, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 585  	loss 1.45218, train acc 65.00, train corr acc 41.67, val acc 68.15, val corr acc 42.92
# Ep 0 	iter 586  	loss 1.46627, train acc 62.50, train corr acc 37.50, val acc 68.65, val corr acc 43.82
# Ep 0 	iter 587  	loss 1.84553, train acc 47.50, train corr acc 30.00, val acc 68.15, val corr acc 42.92
# Ep 0 	iter 588  	loss 1.11134, train acc 67.50, train corr acc 43.48, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 589  	loss 1.47235, train acc 70.00, train corr acc 47.83, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 590  	loss 1.26012, train acc 77.50, train corr acc 57.14, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 591  	loss 0.94800, train acc 70.00, train corr acc 36.84, val acc 68.45, val corr acc 43.46
# Ep 0 	iter 592  	loss 1.82590, train acc 67.50, train corr acc 40.91, val acc 67.75, val corr acc 42.20
# Ep 0 	iter 593  	loss 1.44338, train acc 70.00, train corr acc 52.00, val acc 67.75, val corr acc 42.20
# Ep 0 	iter 594  	loss 1.04320, train acc 72.50, train corr acc 38.89, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 595  	loss 2.58395, train acc 50.00, train corr acc 28.57, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 596  	loss 1.76962, train acc 65.00, train corr acc 41.67, val acc 67.95, val corr acc 42.56
# Ep 0 	iter 597  	loss 1.71322, train acc 55.00, train corr acc 25.00, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 598  	loss 1.30299, train acc 75.00, train corr acc 54.55, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 599  	loss 1.38447, train acc 67.50, train corr acc 45.83, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 600  	loss 1.48148, train acc 62.50, train corr acc 34.78, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 601  	loss 1.45383, train acc 57.50, train corr acc 34.62, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 602  	loss 1.06650, train acc 70.00, train corr acc 40.00, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 603  	loss 1.34326, train acc 65.00, train corr acc 36.36, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 604  	loss 1.99750, train acc 50.00, train corr acc 28.57, val acc 68.30, val corr acc 43.19
# Ep 0 	iter 605  	loss 1.04923, train acc 77.50, train corr acc 50.00, val acc 67.70, val corr acc 42.11
# Ep 0 	iter 606  	loss 1.48790, train acc 62.50, train corr acc 34.78, val acc 68.45, val corr acc 43.46
# Ep 0 	iter 607  	loss 1.44201, train acc 65.00, train corr acc 36.36, val acc 68.25, val corr acc 43.10
# Ep 0 	iter 608  	loss 1.20840, train acc 67.50, train corr acc 40.91, val acc 68.25, val corr acc 43.10
# Ep 0 	iter 609  	loss 1.57531, train acc 65.00, train corr acc 36.36, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 610  	loss 1.30379, train acc 77.50, train corr acc 55.00, val acc 68.25, val corr acc 43.10
# Ep 0 	iter 611  	loss 1.62789, train acc 65.00, train corr acc 44.00, val acc 67.20, val corr acc 41.22
# Ep 0 	iter 612  	loss 1.60278, train acc 57.50, train corr acc 26.09, val acc 67.30, val corr acc 41.40
# Ep 0 	iter 613  	loss 1.70365, train acc 65.00, train corr acc 41.67, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 614  	loss 1.36044, train acc 65.00, train corr acc 44.00, val acc 68.60, val corr acc 43.73
# Ep 0 	iter 615  	loss 1.63788, train acc 72.50, train corr acc 52.17, val acc 67.20, val corr acc 41.22
# Ep 0 	iter 616  	loss 1.93122, train acc 55.00, train corr acc 33.33, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 617  	loss 1.59474, train acc 67.50, train corr acc 48.00, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 618  	loss 1.91464, train acc 52.50, train corr acc 26.92, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 619  	loss 1.65139, train acc 67.50, train corr acc 50.00, val acc 67.60, val corr acc 41.94
# Ep 0 	iter 620  	loss 1.42172, train acc 72.50, train corr acc 50.00, val acc 67.15, val corr acc 41.13
# Ep 0 	iter 621  	loss 1.64546, train acc 62.50, train corr acc 42.31, val acc 67.40, val corr acc 41.58
# Ep 0 	iter 622  	loss 1.30507, train acc 75.00, train corr acc 52.38, val acc 67.00, val corr acc 40.86
# Ep 0 	iter 623  	loss 1.82008, train acc 60.00, train corr acc 44.83, val acc 67.15, val corr acc 41.13
# Ep 0 	iter 624  	loss 1.65278, train acc 67.50, train corr acc 48.00, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 625  	loss 1.02510, train acc 75.00, train corr acc 56.52, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 626  	loss 1.39513, train acc 77.50, train corr acc 57.14, val acc 67.75, val corr acc 42.20
# Ep 0 	iter 627  	loss 1.47827, train acc 67.50, train corr acc 38.10, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 628  	loss 1.20725, train acc 77.50, train corr acc 55.00, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 629  	loss 1.29345, train acc 72.50, train corr acc 38.89, val acc 67.55, val corr acc 41.85
# Ep 0 	iter 630  	loss 1.54877, train acc 65.00, train corr acc 36.36, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 631  	loss 1.52175, train acc 65.00, train corr acc 41.67, val acc 67.40, val corr acc 41.58
# Ep 0 	iter 632  	loss 1.92841, train acc 60.00, train corr acc 40.74, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 633  	loss 1.34867, train acc 67.50, train corr acc 45.83, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 634  	loss 2.05936, train acc 50.00, train corr acc 31.03, val acc 67.60, val corr acc 41.94
# Ep 0 	iter 635  	loss 2.15993, train acc 47.50, train corr acc 30.00, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 636  	loss 1.42689, train acc 65.00, train corr acc 44.00, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 637  	loss 1.66661, train acc 65.00, train corr acc 39.13, val acc 67.60, val corr acc 41.94
# Ep 0 	iter 638  	loss 1.47432, train acc 65.00, train corr acc 44.00, val acc 66.40, val corr acc 39.78
# Ep 0 	iter 639  	loss 1.37308, train acc 65.00, train corr acc 33.33, val acc 66.20, val corr acc 39.52
# Ep 0 	iter 640  	loss 1.24837, train acc 62.50, train corr acc 28.57, val acc 65.95, val corr acc 38.98
# Ep 0 	iter 641  	loss 1.05916, train acc 75.00, train corr acc 52.38, val acc 66.05, val corr acc 39.16
# Ep 0 	iter 642  	loss 1.58690, train acc 67.50, train corr acc 45.83, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 643  	loss 1.65156, train acc 70.00, train corr acc 52.00, val acc 67.40, val corr acc 41.58
# Ep 0 	iter 644  	loss 1.62010, train acc 67.50, train corr acc 45.83, val acc 67.60, val corr acc 41.94
# Ep 0 	iter 645  	loss 1.24127, train acc 72.50, train corr acc 45.00, val acc 68.20, val corr acc 43.01
# Ep 0 	iter 646  	loss 1.24629, train acc 67.50, train corr acc 48.00, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 647  	loss 1.14117, train acc 75.00, train corr acc 50.00, val acc 68.35, val corr acc 43.28
# Ep 0 	iter 648  	loss 1.34734, train acc 77.50, train corr acc 55.00, val acc 68.20, val corr acc 43.01
# Ep 0 	iter 649  	loss 1.49501, train acc 67.50, train corr acc 35.00, val acc 68.30, val corr acc 43.19
# Ep 0 	iter 650  	loss 1.91123, train acc 67.50, train corr acc 45.83, val acc 67.75, val corr acc 42.20
# Ep 0 	iter 651  	loss 1.34197, train acc 62.50, train corr acc 42.31, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 652  	loss 1.47767, train acc 72.50, train corr acc 42.11, val acc 67.30, val corr acc 41.40
# Ep 0 	iter 653  	loss 0.96685, train acc 72.50, train corr acc 42.11, val acc 67.85, val corr acc 42.38
# Ep 0 	iter 654  	loss 1.32719, train acc 70.00, train corr acc 45.45, val acc 67.85, val corr acc 42.38
# Ep 0 	iter 655  	loss 1.86148, train acc 65.00, train corr acc 44.00, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 656  	loss 1.24787, train acc 70.00, train corr acc 42.86, val acc 68.70, val corr acc 43.91
# Ep 0 	iter 657  	loss 1.98026, train acc 62.50, train corr acc 37.50, val acc 67.95, val corr acc 42.56
# Ep 0 	iter 658  	loss 1.51028, train acc 67.50, train corr acc 45.83, val acc 67.70, val corr acc 42.11
# Ep 0 	iter 659  	loss 1.31458, train acc 77.50, train corr acc 55.00, val acc 68.15, val corr acc 42.92
# Ep 0 	iter 660  	loss 1.65243, train acc 67.50, train corr acc 43.48, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 661  	loss 1.74383, train acc 62.50, train corr acc 31.82, val acc 67.25, val corr acc 41.31
# Ep 0 	iter 662  	loss 1.52860, train acc 65.00, train corr acc 39.13, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 663  	loss 1.64617, train acc 62.50, train corr acc 40.00, val acc 67.35, val corr acc 41.49
# Ep 0 	iter 664  	loss 1.52364, train acc 62.50, train corr acc 40.00, val acc 68.35, val corr acc 43.28
# Ep 0 	iter 665  	loss 1.34748, train acc 67.50, train corr acc 40.91, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 666  	loss 1.71880, train acc 62.50, train corr acc 37.50, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 667  	loss 1.32682, train acc 67.50, train corr acc 40.91, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 668  	loss 1.15125, train acc 70.00, train corr acc 52.00, val acc 68.60, val corr acc 43.73
# Ep 0 	iter 669  	loss 1.40959, train acc 75.00, train corr acc 54.55, val acc 68.20, val corr acc 43.01
# Ep 0 	iter 670  	loss 1.29171, train acc 72.50, train corr acc 52.17, val acc 67.70, val corr acc 42.11
# Ep 0 	iter 671  	loss 1.45842, train acc 60.00, train corr acc 40.74, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 672  	loss 1.84213, train acc 60.00, train corr acc 38.46, val acc 67.90, val corr acc 42.47
# Ep 0 	iter 673  	loss 1.27739, train acc 72.50, train corr acc 47.62, val acc 68.40, val corr acc 43.37
# Ep 0 	iter 674  	loss 1.31146, train acc 70.00, train corr acc 36.84, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 675  	loss 1.23633, train acc 72.50, train corr acc 45.00, val acc 67.95, val corr acc 42.56
# Ep 0 	iter 676  	loss 1.38994, train acc 70.00, train corr acc 47.83, val acc 67.95, val corr acc 42.56
# Ep 0 	iter 677  	loss 1.31690, train acc 67.50, train corr acc 40.91, val acc 68.35, val corr acc 43.28
# Ep 0 	iter 678  	loss 1.07297, train acc 72.50, train corr acc 45.00, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 679  	loss 1.18353, train acc 75.00, train corr acc 54.55, val acc 67.70, val corr acc 42.11
# Ep 0 	iter 680  	loss 1.28963, train acc 72.50, train corr acc 47.62, val acc 67.60, val corr acc 41.94
# Ep 0 	iter 681  	loss 1.95040, train acc 55.00, train corr acc 33.33, val acc 67.85, val corr acc 42.38
# Ep 0 	iter 682  	loss 1.62555, train acc 60.00, train corr acc 40.74, val acc 68.15, val corr acc 42.92
# Ep 0 	iter 683  	loss 1.32710, train acc 70.00, train corr acc 42.86, val acc 67.60, val corr acc 41.94
# Ep 0 	iter 684  	loss 1.52762, train acc 67.50, train corr acc 38.10, val acc 68.35, val corr acc 43.28
# Ep 0 	iter 685  	loss 1.41244, train acc 67.50, train corr acc 48.00, val acc 67.65, val corr acc 42.03
# Ep 0 	iter 686  	loss 1.82534, train acc 62.50, train corr acc 42.31, val acc 68.10, val corr acc 42.83
# Ep 0 	iter 687  	loss 1.56558, train acc 65.00, train corr acc 46.15, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 688  	loss 1.35170, train acc 65.00, train corr acc 39.13, val acc 67.85, val corr acc 42.38
# Ep 0 	iter 689  	loss 1.24057, train acc 77.50, train corr acc 55.00, val acc 66.75, val corr acc 40.41
# Ep 0 	iter 690  	loss 1.63501, train acc 62.50, train corr acc 37.50, val acc 66.65, val corr acc 40.23
# Ep 0 	iter 691  	loss 1.43021, train acc 62.50, train corr acc 42.31, val acc 67.45, val corr acc 41.67
# Ep 0 	iter 692  	loss 2.01083, train acc 57.50, train corr acc 32.00, val acc 68.00, val corr acc 42.65
# Ep 0 	iter 693  	loss 1.55483, train acc 62.50, train corr acc 34.78, val acc 67.80, val corr acc 42.29
# Ep 0 	iter 694  	loss 1.59137, train acc 57.50, train corr acc 29.17, val acc 68.45, val corr acc 43.46
# Ep 0 	iter 695  	loss 1.61360, train acc 70.00, train corr acc 53.85, val acc 68.45, val corr acc 43.46
# Ep 0 	iter 696  	loss 1.61419, train acc 62.50, train corr acc 42.31, val acc 67.50, val corr acc 41.76
# Ep 0 	iter 697  	loss 1.97989, train acc 57.50, train corr acc 34.62, val acc 68.30, val corr acc 43.28
# Ep 0 	iter 698  	loss 1.59203, train acc 62.50, train corr acc 31.82, val acc 68.05, val corr acc 42.74
# Ep 0 	iter 699  	loss 1.19065, train acc 70.00, train corr acc 40.00, val acc 68.65, val corr acc 43.82
# Ep 0 	iter 700  	loss 1.55334, train acc 67.50, train corr acc 48.00, val acc 68.65, val corr acc 43.82
#
# Epoch 1 of 1 took 334.130s
#   training loss:		1.463082
#   training raw accuracy:		66.86 %
#   training corrected acc:		43.00 %
#   validation loss:		1.465439
#   validation raw accuracy:		68.65 %
#   validation corrected acc:		43.82 %
#
# Training completed.
# Testing...
# [(56, 401), (156, 370), (179, 265), (86, 105), (19, 20)]
# [0.1396508728179551, 0.42162162162162165, 0.6754716981132075, 0.819047619047619, 0.95]
# Final results:
#   test loss:			1.476997
#   test raw accuracy:		66.83 %
#   test corrected accuracy:	42.72 %
#   test corrected accuracy time series
#   		 Timestep 0:	13.97 %
#   		 Timestep 1:	42.16 %
#   		 Timestep 2:	67.55 %
#   		 Timestep 3:	81.90 %
#   		 Timestep 4:	95.00 %
# ====================================================================================================

# %%
for hoc_num in xrange(HOC_MIN + 1, HOC_MAX):
    print ('Accuracies for HOC {}:'.format(hoc_num))
    print ('last train acc: {:.2f} %'.format(last_train_corrected_acc[hoc_num] * 100))
    print ('last val acc: {:.2f} %'.format(last_val_corrected_acc[hoc_num] * 100))
    print ('overall test acc: {:.2f} %'.format(test_corrected_acc[hoc_num] * 100))
    print ('test accs time series: {}'.format(test_corrected_acc_per_timestep[hoc_num]))
# Out:
# Accuracies for HOC 2:
# last train acc: 38.89 %
# last val acc: 41.71 %
# overall test acc: 44.02 %
# test accs time series: [0.1597222222222222, 0.3851851851851852, 0.7263157894736842, 0.8888888888888888, 1.0, 0, 0]
# Accuracies for HOC 3:
# last train acc: 48.48 %
# last val acc: 45.53 %
# overall test acc: 44.06 %
# test accs time series: [0.1366906474820144, 0.29213483146067415, 0.6244725738396625, 0.7, 0.8461538461538461, 0.9333333333333333]
# Accuracies for HOC 4:
# last train acc: 45.45 %
# last val acc: 50.41 %
# overall test acc: 49.75 %
# test accs time series: [0.14166666666666666, 0.3192090395480226, 0.6614906832298136, 0.8598130841121495, 0.9494949494949495, 0.9655172413793104, 1.0, 1.0]
# Accuracies for HOC 5:
# last train acc: 30.30 %
# last val acc: 45.08 %
# overall test acc: 47.45 %
# test accs time series: [0.08267090620031796, 0.38283828382838286, 0.6753731343283582, 0.8318042813455657, 0.9318181818181818, 0.90625, 0.5, 1.0, 1.0, 0]
# Accuracies for HOC 6:
# last train acc: 52.63 %
# last val acc: 39.75 %
# overall test acc: 37.66 %
# test accs time series: [0.13541666666666666, 0.3924050632911392, 0.6304347826086957, 0.9411764705882353, 1.0]
# Accuracies for HOC 7:
# last train acc: 40.91 %
# last val acc: 35.46 %
# overall test acc: 32.02 %
# test accs time series: [0.09125475285171103, 0.21825396825396826, 0.5222222222222223, 0.6896551724137931, 0.8888888888888888, 1.0]
# Accuracies for HOC 8:
# last train acc: 44.00 %
# last val acc: 36.65 %
# overall test acc: 35.69 %
# test accs time series: [0.06982543640897755, 0.3170731707317073, 0.6188679245283019, 0.819047619047619, 0.95]
