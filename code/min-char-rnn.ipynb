# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('data/rnn_inputs.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in xrange(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(xrange(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in xrange(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print '----\n %s \n----' % (txt, )

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print 'iter %d, loss: %f' % (n, smooth_loss) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 100351 characters, 67 unique.
# ----
#  eR-dc1;b,V&)1sE;h[b
# pONemn-x6.3T1hPa:[)'W,
# FFBfuOxaYm?CCuu]
# ,FtzyLovh2pSKM
# kca(!LvhR[FeeNdxp 3Ob0]& FENd]mlwN0rnLkHEmGnr'VSmFeVnKmWn-FRu2[.kle-b-ACbKfgR
# 0F:Ft2fRi[-ez2Pb[aW:uyTice'lk?kq?N[oC kizITpR2e
# ----
# iter 0, loss: 105.117313
# ----
#  ecim auG c rfl
# G: cs
#   Gc db a
# er m r   a,hG h g  ep rr boc ,uefh
# r
# ehg
# WwMau
# oegysBla
#
# G dGyGim hGtG ela
# lafdg
# (f
#
# G lri
#  rhmcheGf m,  s G Gtce fwafnsnm ea
# flalc
#  e b G   f ocu c
# radrt
#
#
# s G
# ----
# iter 100, loss: 106.001534
# ----
#   v  sv .Btn,neh3
#  e
# ui.e td r dAtP   ao mo'',, h,  mo.ane tpce tr,aununnrmcudnitn3 ci nTt roth PrsmAttdv sa.
# cg ,,gttmdv
# . imbahhtbau,eotch d nr.
#  sw, nn
# p un ,  c,mt
# d A
#  e
# dea hh. itner.o SPn,hu
# n
# ----
# iter 200, loss: 104.104046
# ----
#   hRh feheylesne ene rythee anreeh ne nneithMerbsaietVeha i  nCssss
#  Maaeo senwnnwe i,qeosT uTe gamee on n aes wun it nuehk T
# eeshcB Veel sceeneleenheyheps  e uu skc  ehnsneehsRfsb  nnutpo  rhe se  Tde
# ----
# iter 300, loss: 101.920801
# ----
#   The wu
# mesuutr
# noohun u c moy h
# utnA u ,nou
# wh
# i
# ou y,nsr
# tNoitin rsioo n recb
# we,Les  euPur M o ateee t,lhuc
# n o Bue t nw truiwmieuy lietna rco itlnthaq lh ou t,omama
#  cut,u
# Binileopucinr tnuruheiel
# ----
# iter 400, loss: 99.698635
# ----
#   uumimn vnlH mhepb.
# wo,o,aiyedoadramonesounm meeoaeocngware whrcnaude someoaun:an sl humaitTeeowranud t
#  sseoci r mhe huicerimann Ko Na,,
# In th nolninh d
# u, meise mAtne a
# ein a mnnmmthdhy.c Ir.dne sam
# ----
# iter 500, loss: 97.543351
# ----
#  hh
# oMo
# seaswiKherm t thohm mEohoW  ght t ituWoIhe th r , w' AWnths thsh wooyt,
# ohl g,ron h t ehesodosll iyap.t ou Mht Fh bh.pto no sity woh, wwt
# rh W.r
# no'aw td Ih
#  theoiy,s thehurL e th fhl
# thMs trd
# ----
# iter 600, loss: 95.242993
# ----
#  erelaee bansasahT buime retreh lesgy mp debhr tudtndWtheeuaandohaupein rltoyrenleyint caBdrt uasondatt uury wfrr Mm meeham caos., dathrTIuhdd hrot hinOueneasangee rrd Iidideersef Ao ,
# a
# rarer dirrfeap
# ----
# iter 700, loss: 93.243230
# ----
#  eeNindeAand t' logl psfofenAliacyee,
# c e  .iso, iielWheigaitpeCtipo bieeaeDSaoeelll ofd fe Iue ln.lHefeafVrotllraclepn
# AWirt Afale wa,hst,
# tet AihlC mehan iileuroee, clly iief, ieer,, Litioyease Cee
# e
# ----
# iter 800, loss: 91.236688
# ----
#  nd cseVoaW' rosssiOaporg eog whaceeekerello
# beeet.
# can t netoy sat otos lelohlc.Nitt hnsloh? thip basrle 'e, rosylt sr
# s'dtl tar der I. tat
# ls ticn
# s opneitb lop,
# b?srapeor
# s yt det
# io.cetSIeldetrar
# n
# ----
# iter 900, loss: 89.265311
# ----
#  s se becwe woloosse:sore ithandenessuAanoh wid He orn i.'on tfe, w th lth iu seln saIa?e Mumg, Sn ons th: )hee hugBoo To ohosor Bondeoaforso
# rg'e seror wet r:thoe
# loif,
# Ohs the BiSsly. Efehye' Bo.es
# ----
# iter 1000, loss: 87.398142
# ----
#  e Ae, ohos  W mur aldeer he oianmemgroh vnory meathai
# cafe,
# thatoiuI SMe me  sh thets
# herd
# dMo  haC thacb the t I
# tor: Mame y gio MaurehAs Me gake vaet Dhichoueu touBt cp
# mauenathoe,
# eay  hee s b:
# th
# ----
# iter 1100, loss: 85.543160
# ----
#  hord
# Kf SGorethechouu ritke schofeo'e mWe cnuse Khee
# coy
# woKBr ld
# ca Painnd ouetherthatmretho,
# DCe 'r Arurofe theoKakacb  youl skot k coiwouinont ohatir't spareear' ghouesslneane thi gg thofniuenueexc
# ----
# iter 1200, loss: 84.002041
# ----
#  Kacohes seld
#  sher
# deel natndar  ne wo to
#
# Kax,
# sares Li.a'waaois
# cbresrdundose,seachtho ke: o wulas Maros,
# Tht NSucimed  Heleple  iout keresiEriwo
#
# Sheid'had Eme AluaTeuuse woueheued Kendie hy
# ore
# ----
# iter 1300, loss: 82.521994
# ----
#  MalI Vme mr?
#  p n pi  thee , pryffrn plle,
# Pi, Anis Iuwbusr, Mole  Nhale: oSlme  machfr
# int,
# p:tTrrlaineao.
# ,tOuinlin naNing Le ce siianLet Ye ooy s Sutretwer Halle HaltsingFlm, meinde eemst n Hotnt w
# ----
# iter 1400, loss: 81.122812
# ----
#  tein'gs,,oeaoheuasiagse,
# cyeant, ing,,
#  seee'thon,
# Athers, a
# toaln inmeast,
# ea'ts's cin tont wtsec( taseeaz,
# t't'utsnemaedthandeantonceemletntnd tangre,
# deindeauntsotate,
# at .ouaog,
# .Ferandan. anpease
# ----
# iter 1500, loss: 79.770475
# ----
#
# eI  faklt.
#  hosthisrout
# . Wiuthiy,
# wueuss iumd tont gt Torr lws
# fas,
# tousreofe be erad mot ts For  Mour tua. Qiusseacq aa'wre wbr'srrrli mon Iamiw  errle
#
# Mrestoa F Mu' hor G trou..
#  Lntre
#  inary in
# ----
# iter 1600, loss: 78.512396
# ----
#  anqv uadi'mSt oueewceiss hg GrecBan hhungisheuep
# cf
#
# vath.oI Whithse, coh it Dondethi d Kh me tofiks,
# shathey
# thy poud,
# Sny yirWh mf, whiucdthlit'tithen fouy
# cinchit  h scutd
# Wh Hobashot The Whar thes
# ----
# iter 1700, loss: 77.211723
# ----
#  tsthoy ome po shetIs t. thotricht thithiBt td thil  LyeW Soither, wuthul Gr h pPreyy wip tor thin:odlt.
#  'd somtr see wurel, boucbes Fand foot am vungran C ha.'.
# .
#
#  fath o thed al, Thad , corgy afa S
# ----
# iter 1800, loss: 76.110914
# ----
#  's thin. sorot almyoutbBa Bne nW cu'
# ror ir. Ssant s icl the s muces Bnf rely gif the,
# Fmeqe'tir Mh,
# Mo toyt arars Nic Torttst.es
#  Wof Nos Wheroune noune dalr was, Wh mfe,
# Hun:Ho Sor aHettrene ware n
# ----
# iter 1900, loss: 75.086783
# ----
#  he ne imr oSse coraduOch. Hlrerre
#
# Hathcake  Sse dinf. the t Mlther wencme ylr thomer wes enthem Sfanireef pe'yeith thetf tinepnbesle foentinssye Foathe S.
# myere Fir bettes Mat  weane tore Tep. Her. f
# ----
# iter 2000, loss: 74.219716
# ----
#  kscily  foul po: s an hhtr ho d d cort R x. nle,
# Aimo her in ake oroly Youmltd, ik ghy Lmc cf that y
#  le hab,
# alsh a dis Me
#  W,  Oi.  ome, f the v wot oke, b I mome . a  por th  ch pe thol  b'g, a.
# ----
# iter 2100, loss: 73.283051
# ----
#  ime ore tme
#
# Tam s Woithes gaYbesse
# nd rountare. rep' A krus,
#   an'pe Laketom wop theataee  Wir tou peigthin gebt, , ber Lome mo Giribed
#  tin tithe wocw'ale fosfi ,
# mer to duekimeseoke, bang Whantamle
# ----
# iter 2200, loss: 72.407213
# ----
#  t ro;
# 1ird,six Ilenothe alnd outnow ooathofthts  rocoofe An hourtand;tismactuooce
# parerif Ipatnar. marele Wcu
# Aide
# p'le VArgorthend, In
# prar gopre trotpour hNonouthe Wh.the o trst Ware or uud Vhind
# ----
# iter 2300, loss: 71.634270
# ----
#  s  ytulwos
#
# this hiF t) bent of ewe Los  fn le sislle
#
# of Nout nd thy, ont nle the cy Lerlitsttole Sas' hou mr core'aA be Me thisches Skos sar? enapwudsad dee, aDd  moul He fke Na lauh, Alghetues, Ont
# ----
# iter 2400, loss: 70.994055
# ----
#  v d Dacbue ind Fichakegiofof itade oues,
# a TheoTbely. The wou, Bycu nke thr.
# sous
#  HesgiCend Whacbod sllg: Leakatdos pedos thig Hobe foelflithog Cwueigly Meotg,
#  Mu e t lt s unde gograwe,  thinde Til.
# ----
# iter 2500, loss: 70.402547
# ----
#  eln
# C Thont The togw. nimny and ou
# se   Ht Maclon
# Sfous Lant knt Cuunse. hese
#  ko thedken And posiAsng, all.
# y  Ant?onlande, 'w  sny, yolds hexnoumllds Lond  s yond sius wumeme m ( Tuorlurd
#  inthes. e
# ----
# iter 2600, loss: 69.828160
# ----
#   Male  Add.
# Hhe
#
# me Iutee mat andafe Lo.
# Hfe Gos se b. Lhe Eutin foulpape on. ame Handng. mxt Cor'd:
# mls: Men antan i then, ons d if vnf He Wh's : magh dFte
#
#  hine ey mee: be:
#
# ni. ans nous sow,shaine
# ----
# iter 2700, loss: 69.109620
# ----
#  .
#  so  ne Bane Sle onee are. ozey aoe thosdeonens it Shor direat,
# Wele
#
# , Wue, ane?
# paweson eouriend doaoe wiwees. Fouti.menet thorref
#
# ongs hong  Sorla.  finonee.
#    W Sheet,
# A ooune thow inee norleo
# ----
# iter 2800, loss: 68.277040
# ----
#  out wondeot he anou himtesrercheu Dergrame: Mese I cope fhoue bius suewe Mo ouurc!
#  ne I Mayaactat
# I wsadoclao ehy kaact, Be be   Matnitg. gacoctue tiles
#
# Hoyt lraclacu hdeethemou  vng woeg tiglgede
#
# ----
# iter 2900, loss: 67.722292
# ----
#  ssep Nml mos
#
#
# Aps Les's
# Ine ghes Fisl.
#
# Mact, I yAsV,
# wDt Latcle,
# ifems Irof gisest.
# thes:
# tores
#  Lon thisn,
# foone foumery toithoumere,.
# shedss
#
#  yols, Iueus: snet Ixarssseeu'ttesni histheche so gor
# ----
# iter 3000, loss: 67.194954
# ----
#  d no Feldnet theise wir bfows Fafe
# Weebe, I walFde donfene capon andeintese
# Sl' Soy hones
#  of sed oee teewe tNer, Willeape, yot thicbeth, in im Aeg, thr sools te wellree vI bed his Whofafeace Voenl F
# ----
# iter 3100, loss: 66.877577
# ----
#   teons a aout
# NouacR. sisd, ance tirs
#   otoucr
#  whed Mecbendasith hee
# Enr Hey told I Whid Wemy yotidt The Horcelth. aSoe Torcathe therem folt Vnon noncertholpe Thane bouey
# wut
#  Wescar tood fout Worg
# ----
# iter 3200, loss: 66.430105
# ----
#
#  Diune Of haldiee tongnhicbe sounerilds siws, 1 syle tidiCbougre:
# Tamy
# wireweaou. heaod Fethoud,
#  Mit No  Benles Cithy srrir hamer,  Rounding weurfe,
# donouthinle thoun ono me Dowe tuuech. Bin awe lla
# ----
# iter 3300, loss: 65.886557
# ----
#  t,  it sho
# nfand skeo[ ne wathat. ohouethatat lase't s'ss?
# y whes Yonealtt. sig macat arlehee s'fe thad eone woweat Fenes. Kat voce lat
#  v thilbess hhe hakeonsh, anhathswine, pit hasse , s ohaead nt
# ----
# iter 3400, loss: 65.482122
# ----
#   nowin with
#
#  mle wo Ye, oh
# Ma bi Hecir'Thou'd thicwe'HoY heoy afou guund'n I  I Mo s. NoughoSthie lbathe: ly spot ge Me b N wa bl m. hy mine
#    wo ce h heun W wo tous  mo me ot now thour whe-Thees
# M
# ----
# iter 3500, loss: 65.175752
# ----
#  re inisdot inore Poune  wome to Let tontuele sorle
#
#   incoutht't wit'sow fot wowor,
# EkF muutnghet nou Pastincehrow wit hot med tou Ththison,
# llee.
#  Acbicboull s   by The Oe ctnos
# Minthe
#
# Ml Make, firl
# ----
# iter 3600, loss: 64.823627
# ----
#  mere weranh me haly
#   W ry'd hhiey
#    oflre,
# Ard
# shee ghye, a thig Inneerew id Bacendeaxeusne Maceran, than ttald: Titnen core, almes
# seuery Nortont, of et,
#   N more Me oren oke . Ly. sbor ein Macbe T
# ----
# iter 3700, loss: 64.449982
# ----
#   Mathtnath wfaft'is cath Hces Seln: Alle pee
#  nockehew bemetsnly, Woethowh FaHam cofath. cx. mant-oy pit
#
# ket'bit Be Bacte Laxe vrft Ma wir Cearegomteub mlSt thincr. Blith, Noteisuengaacaof treen Igan
# ----
# iter 3800, loss: 64.253480
# ----
#  loker, lell fasade v that iI I wichn,
# My
# Tbeme tis,
#   Alues Thin on mee tomd C me macbus bo thep bretcall  vst has
# bne vngt Snot   b  inch.
# I Sowre, inn harbs arkmere wh
# uusabe thcracf And
#  art. the
# ----
# iter 3900, loss: 63.933642
# ----
#  he ch be aaf bras,
# T hells,
# I. oher nouch. Heluser sictor ne, me thal shesr:
#  in bef Tirestarunracchitrey v Kino se homf Iouele-shaupu Sor Ef wiokre my Sees. Auoud Keode tharscroll a
#
# Kerdn ther herld
# ----
# iter 4000, loss: 63.553633
# ----
#  e's thes, rars Canq,
# Kakenneingingsibi sineen,  And thi marristiVathy Rnaolelkan pacmand auebfandish thiegus cacbr wiskethmenor
# SDing Sacwighutho he gos't,
# Kounaracb: Ath,gfifasase Bunlpane,
# Wh noushi
# ----
# iter 4100, loss: 63.549248
# ----
#   Thal hat ance: So no Go puy Sew Whe ofeaw Shales
#   Ba sipelehe areR1n hike Coulk.
#
# The thePs hhe thad heir St shes
#
#   I ohe.
#
#  we Rors the Kime thir thaun hes -ne The I Chep. Be Th
#  Romansune:
# Enqs.
# ----
# iter 4200, loss: 63.338487
# ----
#  Thounayre,
# a 'ase te  t? se ooxe Cort tot shuea, ands sort ve ame  e woth, are th. beact af moden, Re buthachee:
# He were eot tere or sinqeto?
# sh, Saltt: at thoushy amy, angondeet  or of thone,
# Tte. ae
# ----
# iter 4300, loss: 62.917499
# ----
#  htes It tor
# seince gamame srselluthaketesthes
#
#   Threll thistes
# yoy Perkin trounHes v soust ter Iryet orruin withKimstnesdace hagf Nueerreth, Fusthilehegmy
#
#   A thy sttrringaspig  Riuy Nooses, Fo thy
# ----
# iter 4400, loss: 62.626487
# ----
#  O
#  h neeut oond srt s  Bnor thim Lat Tor tun tiur od thee, th han wsaf, ine fomthe th
#  Het yos searo soo
#
# MDrbe Houe snye;e Hle Olt; anot Mase no Lacer besobr, on poule hat,
#   Oonghaone Tie Kerdrall L
# ----
# iter 4500, loss: 62.310223
# ----
#    hif yolle stor Got mar dut wkand ildws b  p mandiy fo thicey se thape's Scald wir Whoud I cuoT whof, A vnot be cuigh'twer vml.
#  thind. Toughrut An hano be   Gy hares Gor nt Fatiin alses wt thald if,
# ----
# iter 4600, loss: 61.978308
# ----
#  loscarcenbes,
# T thlt asce vsticath Stisp hnacg bath. Bicbre vs eseste theresseangerns augh,
# Thertesb'tinfeinr matfalngase vnts p Fis tlt atr. put then whrase snt:
# Theng actntemet sepune ofre buss. fak
# ----
# iter 4700, loss: 61.787768
# ----
#  reore Sfuat girke, nuf sing'd thtingtrureE Con, ounde fils thare geingow sems she thyeand ange ciod oneeendasd Sadede Feele GeelandesteteacingaTut inglikts
#  Mled Dacgeres thonisher. Hicos tinereelttit
# ----
# iter 4800, loss: 61.669834
# ----
#  l bisgerd on sis cinsertinipungtoopnce igaof  Hald
# Houlkie Homesthid Dous loult douenoung hang thall.
# sietod tuusealed pare chifasickuod tht thouttee ifael toche SSare-hault.
# Houscoumwiist iue  pilpe
# ----
# iter 4900, loss: 61.456851
# ----
#  eter, Irthe ve vthees Del faep.  hit He The. The, as er ghe t throm fonn. Ile eolind fow sis mptme wart
# saui'f
#
# Gin, ande Came, the sfescat waser tos me is bs nem., auy the
# Macd on she the
#
# Sepinsigh
# ----
# iter 5000, loss: 61.196661
# ----
#  e and the hade moorn. Asbeme sithe  snin por  'f d thard, artard angid dase Oth'ald shir vrreugh' Orer e Nocccyee  lond, Mes
#
#
# Thon : ee maths'retiny  Met Doith, thes theh then O. Lindiame Nere Ankere
# ----
# iter 5100, loss: 60.992749
# ----
#  t.
#
# thadkerce. thens,
#
# Knon, bughan.
#  P thisce.
#
#  Boucd thon pem.
#
# woen.
#  Klls. Wikb.
#
# Yon g nof tow Knky hose Go chan theftng, Kfock. wht: :rire.  KyenK Hort more Pone
#
# Viidles: mbo
# .
# Kf
# Ire. Whouek
# ----
# iter 5200, loss: 60.863644
# ----
#  .
# Me thet my in shacbiussece: paiciee.
#  hiou nlicg: dot Drkawewir ho we Sice iock. A bne heou: at it galriim thot dumues I. Pakl tha Dad hyele. Mais if t'd Nourf tht.
#  hakeais hhis Ls sot
#
# thoubpem Mu
# ----
# iter 5300, loss: 60.820195
# ----
#  ram, Thau Co tfero therethe I ho se Lokl'd sow wuot welderind'd thee. whas wolot, and bett,
# Lot, atigham no sourt a
#   Het, aanee dLude'dE wiss.
#
#  Me'd hath  Gen:
# Tot Hadbur,
# Whattills'd ohers, Bacbs w
# ----
# iter 5400, loss: 60.714348
# ----
#  al Of vne :t No
# fot worrtts Tis ao the ing sere dey. tha. a e path
#   fruir be me indee d  rain arit Nor't, Ene qaccorop'd Reen  shis
#  Ang,
# I mes, a. of angisur on sings mino Spoet
#
# Allese bincser Hay
# ----
# iter 5500, loss: 60.626329
# ----
#   ld ar thes.
#  h cas gagbes so
#      Whenr.
#
#
#
# e anre yind,
# ay chencang in Pukse tof ee
#     vnos haFf Fcic'e  e'svs threstin walmespops thyer'd
#
# Alke vn  are  War ig Raed. Ba be'grengesker. dut.
#
# sel t
# ----
# iter 5600, loss: 60.475657
# ----
#   Femthee thee gomane ant hit,
# In
#
# Sornointeme,
# Foteneaue 'I Khein't Kudthase Dapon thigost peres te theny thof Vattol in,
# Thee, asne m my Mlunh mot case Crmme thse,
# Wetot Vape sron my a thoyret,
# Oue
#
#
# ----
# iter 5700, loss: 60.359142
# ----
#  Wirs in hocoue th huekene.
#   yolle, daslithllily it Goanqigplaife
#
# mordpes
#  Haa'd bacf Afba
# Enthak; our aou, tod and Ciee youse, of cot mos Lerichey
# B walase Iryne mittorthall Dibe thy lacbcin e hil
# ----
# iter 5800, loss: 60.200111
# ----
#  t.
#
#  La. I my a Sofr:
#  iy et in soun whacdeinqt inPth
#
# Ensmengtue aE  Molton Me:
# Rre, th hange,
# Bns beilcke.
#
#   cue the Noorthang
#  oncos: oBang fe the nnrt,
# 'se Poet Wifd:  hant wicle bny mase's:
# T:
# ----
# iter 5900, loss: 60.090655
# ----
#   Dorde,
# The red'd
# Le Hid eng sehaclerte thide gore?
#
# Ecbondeg. Oe Poome, Sn, doolp. A
#  wit dny ser, ancund in obe toweenQ.
# Whousoay arw. Thente'n Shkewsars theu? wirrtell harm Swoanceneded gory a pad,
# ----
# iter 6000, loss: 60.056040
# ----
#  r Larase,
# Why.
#
# Wers in incas a erkot m till tuaciry
#
#   allt os Scad  axe Hemfead them if the?
# m of inqyryre Lalenetesths'ste
#
#
# wund ay
# Wily, w iste?
# W thescorghes eulle ghins.  Rocbpame bind Ceghlnd
# ----
# iter 6100, loss: 59.829096
# ----
#  ne:
# I pigh An Lond. Ie worntouarpt our I. Wescicbeder nd Lach.
# thamy Pre in inee fy he i'd
#  nouant
#
#
# Care ertus'se neaee thdoaly) werbundeender Matby A, ooullld dId ftrmare warbineall an vnouTheacare
# ----
# iter 6200, loss: 59.688937
# ----
#  y this so kelm, whle nou cory,
# Ance hatt.
#
#   yourishs?
#
#   muun sinfe oud'd cuacbe:
# Wicked thwes therees the Math, our youghel,
# And andnhale owth
#
# Chod, he igans writd and young of Hor Sowe, thay: Sic
# ----
# iter 6300, loss: 59.544450
# ----
#  ayot gaine tead doul toMe dout fle wlobetore trou Ououds,
# Soy sit coul sere Tonkebte douyton Norye tor:
# Tougo pomos of coubuamesheracbn,
# Tos,
# whis
#
# bus (Thes,
# Wiso? )Ey poorema)du, bos Woone Be Theer
#
# ----
# iter 6400, loss: 59.610166
# ----
#  s,
# Tomen o cak?thtten, llit &uicealncurch wit b thes
#
# lu: gt wand 2, moat & BEnn thceckou
# ce &o Hell: Fat ther 2oing,
#
# Exor  Macb. Hicb. to Ticbe: Gs sighis-dricergenyts,
# Os Bathe.
#
#  Fat:
#    a Macfors
# ----
# iter 6500, loss: 59.677437
# ----
#  ,
# Tish, Dad dith sres the, ieparmowingbye
# Acpoll Fithe aad yit faoleue
# Ros-all Hod)Haall, lis vf that Tofne Bacee hinathound vhrou hapreld, nomegdoipthtiren,
# Hrind cuowle of ve mer Fas tho twusdou
# Bil
# ----
# iter 6600, loss: 59.610528
# ----
#  echigame will;. A So fowe a'd tue no Minqor shems
# Esiles thinreiang inetan  Lor oogs'ghy ime dowghacksses Ir'Mls 't   Row.
#
# non tMe on'whlish, Loul. Thithe of be ile Houle gome noidiy Nof'ibis bn ifeg
# ----
# iter 6700, loss: 59.451229
# ----
#  t be. Soy loag, kaware arunat.
# Woon tre Renr frel. Whes and Rerss toll wlt Coni. Thtbe,
# Thad shig ary, thizep?
#  fanoole, Wisind.
#  Leyt tou er thonotles a Woo tare & annie of zerons 2  Lathit Whyood, C
# ----
# iter 6800, loss: 59.165169
# ----
#  yre fitgyse3 'r eEke tue nram, e'es vndiye becheldsre you, a, andeanoy kiungun out seshe, Art anceel. Wigren Dare:
# Wheacdlon foror. suuer, I mee). wene youy. Foundacdurne?
# reake hamoo
#   shee oan higdt
# ----
# iter 6900, loss: 59.073815
# ----
#  y ryease gayionnereos,
# Whe yos, of euud in Sind thir sou Youmytug bMacy
# By Thad bp ang fea yer tounis Mealleuy nos Hathrapeouep of anP Bauat, yos pelltor'o the Riillall yod it yon beou parpenet you to
# ----
# iter 7000, loss: 58.933813
# ----
#   aill Frane Welle dent,
# make rous vnis tillat Hamaly vare
#
#  islomes creras torod my Come Ot anew patzoin now soume, hot FiS serles noway elIeat,
#   Tor pace you toure,
#
#    m vme, Fas set ther't too in
# ----
# iter 7100, loss: 59.031788
# ----
#  t the, mun ton now nes anct?
#   Ilt Cake. Baky see, ine wunest, ane hecw bem and vw.
# R pes ande all Whare seises cestt byexet,
# A heis Kace
# Wtose a dor'n afb. Wir heane. weee tow ow. Fine.
#   Meacdaub
# ----
# iter 7200, loss: 58.941887
# ----
#  t itlacdete merthensegall trithdustor ole heek semy: all oxlyte It sow. Iisgune ey wart
#   the-pere
#     a    hathan touth theang
#
# I yot tictr'k,
# By thes thegh wende  Meat: kriffe-ong: a nouthat ingre t
# ----
# iter 7300, loss: 58.726175
# ----
#  owthe Let th: Lath?
#    it : Ler toW mt oo
#          Mt!th? what ig pothioct:
# Gtss yond:     sit Kare in
#
#   rld sounes v now hewilt: muol and?
# En yow po no    matt alle serefh
# Oh
#        ytee: astors yow
# ----
# iter 7400, loss: 58.715027
# ----
#  murt o melt be heios oisss:
# Sous hes s wifhilaching: oleleacet, hird, Toue os D werl thit Soml't syru. Neise hawsor Thou hooucheralomo Mrol it Go Dar sieree
#
# Sis le-or, nou the
# Nold if fithe aue
#
#   yn
# ----
# iter 7500, loss: 58.715698
# ----
#  ol Lis fy thetom'd kiaky,
# Ankieseeke, eumyos: Ror Nousd
#
# theyre mfeazch and   1 Mpighe werl'd
#
#
# Lecs tor souenceingor?
# Ferdancalchick. Iy Deaserot,
# Not'd theace some ind eweng, tur
# mlered domlert mer
# ----
# iter 7600, loss: 58.612513
# ----
#  The
# Scalc tound Qud thon tht pauMeers. Willishelen: coutht, thirs La ille to and me seulr,
# Whase to ooce Che lges and ce thon whe:
#    Baod hohgholrith. This wacouls tubly thousstrlath
# Whilw macb. Vpor
# ----
# iter 7700, loss: 58.554499
# ----
#   sorthe vr Sot bouthe toue
# reluind wayde a e  Som:
# Yone olde good the Ale tou:
# Angurteerne Bats al. Whtn
# Ane me the winouatce, Weene
# I Por Co'ghy the Borg,
# Arele By.
# Tordire
# the  and arker: I Micdnow
# ----
# iter 7800, loss: 58.508422
# ----
#  ee
#  comat shay the Alis tird, Shulerour bingnes,
# E mee, womd Fa thawsur we.  Mo wimasue.
# Hoy. Theat nee thes ouofeuyes I allane mare, Mic thed, ar id Layddancorl ateandte. Fointh,
# . peeane ine tlee,
# T
# ----
# iter 7900, loss: 58.477505
# ----
#  e Hitidilasough
#  noneind Dame Cirle malch d acbeblane if here ane Mes whill. Ros oofald fyoud  ing ey mee Rerd Mret ofmine Lanbish,
# And mpesse
#
# Held ar? and surfings. Mith wwoul,
# 3 Kipe Withe thim se:
# ----
# iter 8000, loss: 58.212215
# ----
#  gere mang, hauwenuet alueniting Stas Macderest. Thot senfiolr macos Cing bnes thamemthindnet, all vport:
# Antemhingaot:
# Houchn'n nound Semt Hittinkenses le?
#
# R he Alli)
# Hord oe fim famt to Etht inte?
#
#
# ----
# iter 8100, loss: 58.420518
# ----
#  I
#
# Nonllat Iloud Rore ms werd thimepe gastome sly; wtoue,
# Be to2
#    They. I that orticrt?
# Whath til'd, Athit mur ne vlge,
# Aslly ine grming soldelod moet Poy Icoulleit tuner
# thoul the Wall,
# In hepos to
# ----
# iter 8200, loss: 58.465228
# ----
#  tut  Malder leacned hangphe,
# Whaoctue Sill bacblachsi, Caobet, hefche, ano yos wsyamwo) Yre BMe sers,
# In simth Anqepert gont:
# GMa
# ner bales,
# Heake shawnanead,
# Naby
# He Speas Gooch asnts
#
#  Mou kar ere'd
# ----
# iter 8300, loss: 58.263324
# ----
#  . N ht I of 3hangming that tastend in thllpningoouthe wilbdistost, hau haydal's Mach it. Toushes, the surwuont ly llushenghth, whrilld she sith Mon tuu.
# Thour. Mallemsvshe lliesndol theleiy weirewe pi
# ----
# iter 8400, loss: 58.059880
# ----
#  ny, Mulu Kit our Qt a:
# ytou Hid dow R. Thlyots whoud Cay mirt,
# Thand FadSyeag,
# Tire fus a flind aicuer.    irtunt Bewis, arneer stisdttsest:
# Ie she pors wiys
# Henear,
# Thaudue Kithst,
# Astowint I not:
# By
# ----
# iter 8500, loss: 57.953810
# ----
#  er Latresiroyceint, anot?
# re toy annat that be: Porel, cuechhre Itiuust willt is et'tthot
#     I that
# Whefhe, Broues
#
#   Mingris mumtoi,
# Aet, all whoy
# Thyeat ofrod bute Go thiuterow, hs thowstisist eu w
# ----
# iter 8600, loss: 57.787267
# ----
#  eimeiy gowhacke tha. Lasgam  Lae euaclyead and vuy yod Loed Nacbipidl thy bag't oce that and
# Tiigher Miul. Thacdef Ind, Laml.
# T sithe,
# Grchifbred't wpue
# Tores wirulaticeick. SpoughExbenfe, wo cars. Si
# ----
# iter 8700, loss: 57.631342
# ----
#  xall I:  nes cegtande hane cauishinoug the tu'd ouuplriss mye, anu:
# Wus houe me the Cis puereel  noul thy thoerdead ing goug   Spichs is ors acuig CouMeeds he, Drn an'ous his ilute seisn and cold wiul
# ----
# iter 8800, loss: 57.628812
# ----
#
# Hit in cor'd Care the of noo thate efe,
# Wignewto tune and ofe'd shiecauu ble,
# Brown hene Bye
# Waor mawese,
# An Hes
#
#    stued'd thelourrelu-pin sfane go vshekds,
# I exeny,
# Mage,
# Whas
#
# Dou. Isire
# whtuedra
# ----
# iter 8900, loss: 57.502364
# ----
#  he ald ald heilke to Nay. Br peme?
# Stiso
#    Macw, he fs Shesse vnor ttoweng, qhat seis Gen me):
# ykake Pant thei me,
# Axake blist thosser,
# Wiigh
#
# He Sye Mach Pould st.
#
# my mrht forle behame,
# Whe rer ber
# ----
# iter 9000, loss: 57.384970
# ----
#  r whee Ware aruld.
#  LMide ala toels. Sneleape chthare: a thet care
# tho kille bires meocdor.
#
#      Thaaot teo hrues thingt Maime ixikbit see?
# A enges
#  hyelee, Icu.   rey soulle:
# Hetungh
#
# Mu rodesease i
# ----
# iter 9100, loss: 57.329693
# ----
#  Wher thcene Mnt ouy
#  Dattay Foue towe doy silnt noke go tno de bnst
# in of sow: moll t. sougher thecoot is wo de sting'e. A coycegrly yot to sauecsy sint crounor k? Cochint on theesti. Gou?
# Yoyre v bl
# ----
# iter 9200, loss: 57.222287
# ----
#   woy worrhe
#
#  Korunit that apocr
#
# Ki dyindis En anrs
# Ey thu w. Mut loum yor maccit, yre Fa
#    Thy hocmim ws thimm Hatra. Matimm.
#
#    BKlt ct that I hin Iread alad irounot cos m that mm thit mus los
#
#
# ----
# iter 9300, loss: 57.313758
# ----
#  ng keroo pay trouthe, Is totnt sh thell?
#
# Lat Dordan in Met,
# Wan hist And sfapen tpomeaf cs,
# Anf to hpest,
# A d the masnese:
# Thinte't foare
#
# Eng, yrire Lert Are:
# The lr. Min het?
# Hotan,
# y. Anto:
# Ang. A
# ----
# iter 9400, loss: 57.279199
# ----
#  Oriwh, icbe, Duid the ve Dul arteedo the   Yeureln.
#
#  efter E and if
# De and im Thacker sine
#
#   w tfole
#
#   Sfacoesmy if weack. E thy
# Ween,
# An pisss Bruet, I. On b. mane' Rort, v gut inr wiit Paw Thet
# ----
# iter 9500, loss: 57.243177
# ----
#  r, anly, whano on y wheust Mamwepl if the doWpery whefe,
# Fs woll b wid tnepwer? and mo reuad nee' vare the ep. p thoomt ha it Mal he mus do mor fo sith band noul?
# Eo tham saad Song and, ar thous thama
# ----
# iter 9600, loss: 57.161561
# ----
#  les. vnd, al mus vnd seund Ang: Remand int nearuet hoocning ore Duune of beren't's face u bacbeme ong vnle weind hith in wet fueth,
# The fopor nemut and Sbraine of tocee non make,
# Ae Lied
#
#    Maldeen t
# ----
# iter 9700, loss: 57.117856
# ----
#  e, ofs the
# Ang thous. Angwee
#
# I be, ife
#
# Macdret misiss tory coid Inl: oif Nour,
# And Macder,
# Burd al Gouz will muatones thoende'rur Maod to for,
# Ans silnou,
# Matit I sser, Hesuenst daidre snoulw Base n
# ----
# iter 9800, loss: 57.021952
# ----
#  ele ane racuase
#  nu, tit otes e weforghnes yous soles ine Toughre:
# Therdis yents seattitseeror mifes
#   Marling,
# Toune Sir,
# Homely.
# In merese, eelle, Bag-of: (ios ofe, at, at, Leunsergege his wut: suie
# ----
# iter 9900, loss: 56.940572
# ----
#  I onr'''one
#
# ExinseP. Hot bes Arol nouee it Nis i Kou Gayst Ely,
# Four heoll,
# Tonoile tatle. Theeres.
# Se Dei. Olye alm,
# Lo me,
# A yet helme wefe vn Lang   Gey to dlens eLefing sore,
# Boone, 3 f2gacb. Are
# ----
# iter 10000, loss: 56.935002
# ----
#  somid I cwoy sir your oz wherith Roactilasce:
# T2ourpe arbuel:
# Migafnsthacbour Feasy ow fapeel the This.
#
#    nop the
#  ssey s a are s'ssent
#
#    Macbnl bress s art. fy
#     Haan le, Calyfe that elal. Namb
# ----
# iter 10100, loss: 56.799974
# ----
#  eebet, ard?
#
#   NTous Bidt a bald ele To hes
#
#   Macb.
# e tis: dor set simt'sestattiuitheangossetoThe ous
#      Mureeruth. ore Theres a belochye Ceis feste: me bloweachieke is they and bnos Loretougaoo th
# ----
# iter 10200, loss: 56.592573
# ----
#
# Tomaak'd faldicealders. allonckprang, weactighs:
# Our Madeuchntanat thom worere.:
# Roon pror of ste,
# An I 1. Goreseper hild, anf Mand bles
#
#   Macacor-Wickransee Alfeer tpichriy incbem. To dyoury oll Ai
# ----
# iter 10300, loss: 56.533048
# ----
#  ou thount the sompetrerhin twind
# Thes File
# ss Balwauouy  pamm.
# Ius Hring ben?
# Su woon hyuxsh; Fuecwt mNow thouest shat the neades sere
# Shiunses
# BouTiss muenees Stor The by one I Dy turseent Haasesy ha
# ----
# iter 10400, loss: 56.658280
# ----
#   py'd e ke'be Taanm goucoe,
# Cafie,
# Come, sar'tioned.
# Ald Engeradad aled, and ofre, Ch, andinlelWhe, thow withe,
# D Crol yod bathe thougaonlee:  Mat Wiud theag, tin theeat thengueb ouud Donde, deeblet t
# ----
# iter 10500, loss: 56.838413
# ----
#   a &pres:
# Aad ine:
# We enes thatks And is fe whiues, and sled, aller:
# Bly, elle fo thime
# . fouscaarqoortu Macbat oritst: owrafynor, lror
# Theen?
# Therr, all hawersof: Macend the on ailpow.
#
#    not thase,
# ----
# iter 10600, loss: 56.789331
# ----
#  bne-cuenchind mut a. 'ldt me hill gatt. Weed quy?stost
# Ant en Hot Mise athe Nes.
#   3oure thet seudt?
# En you diest.
#    Macealesere Loy Twer, gowms Co is the met
#  d hie gomme Mand mit Lere bindntl count
# ----
# iter 10700, loss: 56.700045
# ----
#  fothe ne you   nou hist headl the risay Elle you blathe?
#
#     So go rers thy Kis fne Wyill,
# Sit nose, Pieke Pou he dore the Bat thaen,
# d
# Muoce fod. I onow. Wha  Roll herte o' sie, and Fine
#
# ye I the f
# ----
# iter 10800, loss: 56.539683
# ----
#  Mat ounde do sous. Tonles Thoe'cer,
# Whe 'thy Goa:
# I meale Sce & He teald de hat Soy anqos tf eles Melbs I ase e ast sits, Ma
#   Pace, domed seacb. I s I
# I hitibes s tarlr seill;
# Wue a Sify mes, eaod wh
# ----
# iter 10900, loss: 56.452794
# ----
#  erllustod. Muttey so of lrome Boer,
# I
# Acorthatnen
# Bnt Fartousy snow Toacaudmacus or wakewerlestale I yeu aniuestaod due Des Wandly:
# Eng fyot oor thoushet So tit
# Thetneprere
#   thisn,
# Whate. fhes tho fa
# ----
# iter 11000, loss: 56.356328
# ----
#  d ery,
# I thus haare. T bes
#
#
# Ton. Sne me peeb'de Nou the fold fou ald,
# The, hhoot yot munde she of soue  Gptld
# you theurs boureemmake hous youthe fou ste Slleles vaceree: het buese our Atfe, all Pren
# ----
# iter 11100, loss: 56.476968
# ----
#   Wes irts. Mare. Aler me and weaue,
# Pstite that tht meead a  Rolane
# Flow.
# Es hea kite
#
# A nris helrysesse, antes set, in ir;
# F'd. Mene kall Deoch. Macdeme:
# Mush
#       Make wer finm: Bathingase a not Co
# ----
# iter 11200, loss: 56.502689
# ----
#  Wyr Mill
#
#   Mang thes
#
#    ily umy?
#   What ped?
# df aon Molpimlare hiue eofe Gou wyame sist
# Ans Make Call po uy weys, Suneereat, hiss'de'diow, celyre? ill coray ke.
# Thor icout. That all
#
# d moult pishe
# T
# ----
# iter 11300, loss: 56.290049
# ----
#  ser; thessime
#
#  Eorist. Wose cont, tor Lerkes Merg ouod tht fotcweth hansille Derd Gan hey mlokesel. Mer thot thow me:
# Tiame. Fot thet be apous Youd ther wirett. Thare,
# And Lat.,
# One repwer. Oet.
#    y
# ----
# iter 11400, loss: 56.368544
# ----
#  r. Wee, thaactist
#
#   SMe?
#  nos
# Wpor
# Fead:
# A the here if paldsse
#
#    Mamefelnt
#
#    Ssat Doin hat'. vullownaname,
# d forth,
# Sheunt, as mire
#
# Gtitt
#  Dole Wimbrerss mense thef
# rath oaad thiithile haltle ee
# ----
# iter 11500, loss: 56.310691
# ----
#  ende. muts foatos,
# Hot ood cere mlokeacd;
# Blelytayt, and tist. Deine Bere
#
# End, I dre kpee. Ech,
# Ferfes,
# The, vprare? Mood not?
#  clane fo the mptue citf, ath,
# Tht- pe, thet shasiense prthi. Soy'ct yru
# ----
# iter 11600, loss: 56.315946
# ----
#  weust in sowis:
# Hewtude fisf and
# s,
# Iue shatseille,
# I thistst Thaught perimtacedoure
#  mtinaui, thaad payst, peactule Doyruerte les
# Speade, in
#
# d theafe ouott: arcine thauine mome, Sou, arthisor a acou
# ----
# iter 11700, loss: 56.344267
# ----
#  we cigh,
# Araues, ot Fa. Eth.
#
# Rownoyss,
# Hare
# Ene lat moen, brou Nrerlare. Ant:
# Wy'd,
# Ill slcens'I of pighe, SheumFrim's sher.
# To ke Ant notiety worl. Anbe, wartr reacd. I seot ming Simdes. fnind Cing,
# ----
# iter 11800, loss: 56.271830
# ----
#  ws Mand Losnd Seid I beecthald fey yos hall vuatueneale vpire. Bery. W.  not hile vs a cuat cit or int thely
# All bered Seind me fuacb. and Waue nellot
# To
#   Mayeshe ee a cocd.   ]heile.
# Nates
# Is a one
# ----
# iter 11900, loss: 56.235402
# ----
#  rd a mris hry fard'semour wher. Thrw,
# Annay by Hondh,
# Hoor hame:
#   Brer. I dorre themanc, hor threferild Dorr. Torchid Tores,
# shatr gach homr, elr daing was vnd waon marau
# Shet, besto. seed,
# rer,
# Eshe
# ----
# iter 12000, loss: 56.007041
# ----
#  Macaaldnate Whad ; that it thele Therine: in tose hin a beand Gacbicyrerytncous Siing thisue bang:
# sell) wicille buenome tough
#
# A in haartiml)seiret me sist Vtius wie  bee tares (Me gpeargeln broke me
# ----
# iter 12100, loss: 56.201953
# ----
#  d me Leee,
# Tht then hent he, mt Rores.  Khest
#
#   Mocure d1 dorgh: Vine a one,
# I hise:
# And o' he, Sdr, Fird braknrt.
# Thil, Fath. Angy hye, ath'd yot Choust,
# Cotssy the Eth Get muth?
#
#     Lound Slathili
# ----
# iter 12200, loss: 56.328492
# ----
#   lrou, Rimbe dewand that buoud vt not Kand ande hithy st morfer dles.
#
#      2oune
#
# D, ip Aee sowcors, Make will gpoun syor no fo Noe her way
#    rountray, yo fe,
# Bnoun thony
# He west bat.   2  Mactumche
# ----
# iter 12300, loss: 56.075316
# ----
#  e deffenterrenuestanBimaes) loorreue thingt. Tasost
#
# I serincooghs elobe sishitwe?
#
#    Cone Manor sindine nim cesse ,
# The on hist ateser?
#
#   Goindaowede, my wacb. shat  not Com a Sort The wamaf sey we
# ----
# iter 12400, loss: 55.884917
# ----
#  hss withe Thist is thauadod gonden,
# Why sporthaur Collorninc'sse,
# Fonqy gocbome,
# Thatle, d macbningn
# Spen. Intsene do sheade shounot Hald wan ise hironst?
#
#  Rortastorsindesne keatione,
# Ben,
# Thee,
# Ar G
# ----
# iter 12500, loss: 55.893809
# ----
#  od.
# I hy. Hum: thou wing thas hamfeld.
# Tom that no.
#
#    And ton ife tnit 'nt Solly, wiis mins, ang thel sifh coytere'duesemishy is Cauchre macbencertee the whigeine steane thenrare thelltet isef thet
# ----
# iter 12600, loss: 55.739182
# ----
#  s ey shestere: ther ney orce Lich
# Leakale and parder walus to manquediee no prem, warem, Malle,
# On omoy ptacr simp weate wireer, feane ffenouene, Laalysey,
# Nome Kane the, be manges mat. Bue moChe oLak
# ----
